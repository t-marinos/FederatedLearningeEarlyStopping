# %%
import pandas as pd
import numpy as np
import random
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.utils.vis_utils import plot_model
from tensorflow.keras.layers import LSTM, Dense, Input, add, concatenate
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K

RANDOM_SEED = 42
random.seed(RANDOM_SEED)
# Out:
# c:\Users\Theo\AppData\Local\Programs\Python\Python37\lib\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# c:\Users\Theo\AppData\Local\Programs\Python\Python37\lib\site-packages\numpy\.libs\libopenblas.IPBC74C7KURV7CB2PKT5Z5FNR3SIBV4J.gfortran-win_amd64.dll
# c:\Users\Theo\AppData\Local\Programs\Python\Python37\lib\site-packages\numpy\.libs\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll
#   stacklevel=1)

# %%
vitals = pd.read_csv('vitals.csv')  
labs = pd.read_csv('labs.csv')

# %% [markdown]
# Changing the date to datetime variable and setting indexes

# %%
vitals['charttime'] = pd.to_datetime(vitals['charttime'] , infer_datetime_format=True)
labs['charttime'] = pd.to_datetime(labs['charttime'] , infer_datetime_format=True)

# %%
vitals_48hours_grouped = vitals.groupby('icustay_id').tail(48)

# %%
labs_48hours_grouped = labs.groupby('icustay_id').tail(6)

# %%
print((vitals_48hours_grouped.icustay_id.value_counts() == 48).sum() == len(vitals_48hours_grouped) /48)
print((labs_48hours_grouped.icustay_id.value_counts() == 6).sum() == len(labs_48hours_grouped) /6)
# Out:
# True
# True

# %%
vitals_48hours_grouped = vitals_48hours_grouped.drop(['icustay_id','charttime'], axis=1)
labs_48hours_grouped = labs_48hours_grouped.drop(['icustay_id','charttime'], axis=1)

# %%
vitals_features = vitals_48hours_grouped.iloc[:,:-1]
vitals_labels = vitals_48hours_grouped.iloc[:,-1:].to_numpy().tolist()

# %%
labs_features = labs_48hours_grouped.iloc[:,:-1]
labs_labels = labs_48hours_grouped.iloc[:,-1:].to_numpy().tolist()

# %% [markdown]
# # Federated Learning Setup

# %%
def create_clients(labs_data, vitals_data, label_list, num_clients=4, initial='clients'):
    ''' return: a dictionary with keys clients' names and value as 
                data shards - tuple of images and label lists.
        args: 
            image_list: a list of numpy arrays of training images
            label_list:a list of binarized labels for each image
            num_client: number of fedrated members (clients)
            initials: the clients'name prefix, e.g, clients_1 
            
    '''

    #create a list of client names
    client_names = ['{}_{}'.format(initial, i+1) for i in range(num_clients)]

    #randomize the data
    data = list(zip(labs_data, vitals_data))
    data = list(zip(data, label_list))
    random.shuffle(data)

    #shard data and place at each client
    size = len(data)//num_clients
    shards = [data[i:i + size] for i in range(0, size*num_clients, size)]

    #number of clients must equal number of shards
    assert(len(shards) == len(client_names))
    
    return  {client_names[i] : shards[i] for i in range(len(client_names))}

# %% [markdown]
# ## Reshaping data and preparing them for cross validation

# %%
vitals_labels = np.array(vitals_labels)
labs_labels = np.array(labs_labels)


labs_labels_reshaped = np.reshape(labs_labels, (19414,6))
labs_labels_reshaped = np.amax(labs_labels_reshaped, axis=1)

vitals_labels_reshaped = np.reshape(vitals_labels, (19414,48))
vitals_labels_reshaped = np.amax(vitals_labels_reshaped, axis=1)
print(labs_labels_reshaped.shape)
print(vitals_labels_reshaped.shape)
# Out:
# (19414,)
# (19414,)

# %%
vitals_features_reshaped = np.reshape(vitals_features.values, (19414,48,7))
print(vitals_features_reshaped.shape)
labs_features_reshaped = np.reshape(labs_features.values, (19414,6,16))
print(labs_features_reshaped.shape)
# Out:
# (19414, 48, 7)
# (19414, 6, 16)

# %% [markdown]
# ### Batching clients and test data

# %%
def batch_data(data_shard, bs=64):
    '''Takes in a clients data shard and create a tfds object off it
    args:
        shard: a data, label constituting a client's data shard
        bs:batch size
    return:
        tfds object'''
    #seperate shard into data and labels lists
    data, label = zip(*data_shard)
    dataset = []
    X_train, X_test, y_train, y_test = train_test_split(data, label, test_size=0.15, random_state=RANDOM_SEED, stratify=label)
    X_labs_train , X_vitals_train = zip(*X_train)
    X_labs_test , X_vitals_test = zip(*X_test)

    #Reshaping to standardize the laboratory values
    X_labs_train = np.array(X_labs_train)
    X_labs_test = np.array(X_labs_test)
    samples_train, groupedBy_train, sample_values_train = X_labs_train.shape
    samples_test, groupedBy_test, sample_values_test = X_labs_test.shape
    X_labs_train_reshaped = np.reshape(X_labs_train, (samples_train*groupedBy_train, sample_values_train))
    X_labs_test_reshaped = np.reshape(X_labs_test, (samples_test*groupedBy_test, sample_values_test))
    #Standardizing the laboratory values
    scaler_labs = StandardScaler()
    scaler_labs = scaler_labs.fit(X_labs_train_reshaped)
    X_labs_train_reshaped = scaler_labs.transform(X_labs_train_reshaped)
    X_labs_test_reshaped = scaler_labs.transform(X_labs_test_reshaped)
    #Reshaping again
    X_labs_train = np.reshape(X_labs_train_reshaped,  (samples_train, groupedBy_train, sample_values_train))
    X_labs_test = np.reshape(X_labs_test_reshaped, (samples_test, groupedBy_test, sample_values_test))

    #Reshaping to standardize the laboratory values
    X_vitals_train = np.array(X_vitals_train)
    X_vitals_test = np.array(X_vitals_test)
    samples_train, groupedBy_train, sample_values_train = X_vitals_train.shape
    samples_test, groupedBy_test, sample_values_test = X_vitals_test.shape
    X_vitals_train_reshaped = np.reshape(X_vitals_train, (samples_train*groupedBy_train, sample_values_train))
    X_vitals_test_reshaped = np.reshape(X_vitals_test, (samples_test*groupedBy_test, sample_values_test))
    #Standardizing the laboratory values
    scaler_vitals = StandardScaler()
    scaler_vitals = scaler_vitals.fit(X_vitals_train_reshaped)
    X_vitals_train_reshaped = scaler_vitals.transform(X_vitals_train_reshaped)
    X_vitals_test_reshaped = scaler_vitals.transform(X_vitals_test_reshaped)
    #Reshaping again
    X_vitals_train = np.reshape(X_vitals_train_reshaped,  (samples_train, groupedBy_train, sample_values_train))
    X_vitals_test = np.reshape(X_vitals_test_reshaped, (samples_test, groupedBy_test, sample_values_test))

    combinedDatasetTraining = tf.data.Dataset.from_tensor_slices(({"Input_1": list(X_labs_train), "Input_2": list(X_vitals_train)}, list(y_train)))
    combinedDatasetTraining = combinedDatasetTraining.shuffle(len(y_train)).batch(bs)
    combinedDatasetTesting = tf.data.Dataset.from_tensor_slices(({"Input_1": list(X_labs_test), "Input_2": list(X_vitals_test)}, list(y_test)))
    combinedDatasetTesting = combinedDatasetTesting.shuffle(len(y_test)).batch(bs)
    
    dataset.append(combinedDatasetTraining)
    dataset.append(combinedDatasetTesting)
    return dataset

def batch_data_last(data_shard, bs=64):
    '''Takes in a clients data shard and create a tfds object off it
    args:
        shard: a data, label constituting a client's data shard
        bs:batch size
    return:
        tfds object'''
    #seperate shard into data and labels lists
    data, label = zip(*data_shard)
    dataset = []
    X_train, y_train = data, label
    X_labs_train , X_vitals_train = zip(*X_train)
    #Reshaping to standardize the laboratory values
    X_labs_train = np.array(X_labs_train)
    samples_train, groupedBy_train, sample_values_train = X_labs_train.shape
    X_labs_train_reshaped = np.reshape(X_labs_train, (samples_train*groupedBy_train, sample_values_train))
    #Standardizing the laboratory values
    scaler_labs = StandardScaler()
    scaler_labs = scaler_labs.fit(X_labs_train_reshaped)
    X_labs_train_reshaped = scaler_labs.transform(X_labs_train_reshaped)
    #Reshaping again
    X_labs_train = np.reshape(X_labs_train_reshaped,  (samples_train, groupedBy_train, sample_values_train))

    #Reshaping to standardize the laboratory values
    X_vitals_train = np.array(X_vitals_train)
    samples_train, groupedBy_train, sample_values_train = X_vitals_train.shape
    X_vitals_train_reshaped = np.reshape(X_vitals_train, (samples_train*groupedBy_train, sample_values_train))
    #Standardizing the laboratory values
    scaler_vitals = StandardScaler()
    scaler_vitals = scaler_vitals.fit(X_vitals_train_reshaped)
    X_vitals_train_reshaped = scaler_vitals.transform(X_vitals_train_reshaped)
    #Reshaping again
    X_vitals_train = np.reshape(X_vitals_train_reshaped,  (samples_train, groupedBy_train, sample_values_train))
    combinedDatasetTraining = tf.data.Dataset.from_tensor_slices(({"Input_1": list(X_labs_train), "Input_2": list(X_vitals_train)}, list(y_train)))
    combinedDatasetTraining = combinedDatasetTraining.shuffle(len(y_train)).batch(bs)
    
    dataset.append(combinedDatasetTraining)
    return dataset

# %% [markdown]
# ### Creating the Model

# %%
class RNNModel:
    @staticmethod
    def build():
     input1 = Input(shape=(6,16), name='Input_1')
     fe1 = LSTM(16, input_shape= (6,16), return_sequences=True)(input1)
     fe2 = LSTM(16, return_sequences=True)(fe1)
     fe3 = LSTM(16)(fe2)
#sequence model
     input2 = Input(shape=(48,7), name='Input_2')
     se1 = LSTM(16, input_shape= (48,7), return_sequences=True)(input2)
     se2 = LSTM(16, return_sequences=True)(se1)
     se3 = LSTM(16)(se2)
#decoder model
     decoder1 = concatenate([fe3, se3])
     decoder2 = Dense(16, activation='relu')(decoder1)
     decoder3 = Dense(16, activation='relu')(decoder2)
     output = Dense(1, activation='sigmoid')(decoder3)
#connecting the two models
     model = Model(inputs=[input1, input2], outputs=output)
     return model

# %% [markdown]
# ### Federated Averaging

# %%
def weight_scalling_factor(clients_trn_data, client_name):
    '''Gets batch size and calculates total datapoints and how many data points the client has to scale it'''
    client_names = list(clients_trn_data.keys())
    #get the bs
    bs = list(clients_trn_data[client_name][0])[0][0]['Input_1'].shape[0]
    #first calculate the total training data points across clinets
    global_count = sum([tf.data.experimental.cardinality(clients_trn_data[client_name][0]).numpy() for client_name in client_names])*bs
    # get the total number of data points held by a client
    local_count = tf.data.experimental.cardinality(clients_trn_data[client_name][0]).numpy()*bs
    return local_count/global_count


def scale_model_weights(weight, scalar):
    '''function for scaling a models weights'''
    weight_final = []
    steps = len(weight)
    for i in range(steps):
        weight_final.append(scalar * weight[i])
    return weight_final



def sum_scaled_weights(scaled_weight_list):
    '''Return the sum of the listed scaled weights. The is equivalent to scaled avg of the weights'''
    avg_grad = list()
    #get the average grad accross all client gradients
    for grad_list_tuple in zip(*scaled_weight_list):
        layer_mean = tf.math.reduce_sum(grad_list_tuple, axis=0)
        avg_grad.append(layer_mean)
        
    return avg_grad


def test_model(X_test, Y_test,  model, comm_round):
    cce = tf.keras.losses.BinaryCrossentropy(from_logits=True)
    #logits = model.predict(X_test, batch_size=100)
    logits = model.predict(X_test)
    Y_test = np.reshape(Y_test, (len(Y_test),1))
    loss = cce(Y_test, logits)
    logits = np.where(logits > 0.5, 1, 0)
    f1_score_acc = f1_score(Y_test.max(axis=1), logits.max(axis=1), average='macro')
    print('comm_round: {} | f1_score: {:.3%} | global_loss: {}'.format(comm_round, f1_score_acc, loss))
    return f1_score_acc, loss

def evaluating_model_own_validation_data(model, val_data):
    cce = tf.keras.losses.BinaryCrossentropy(from_logits=True)
    logits = model.predict(val_data)
    y_true = np.concatenate([y for x, y in val_data], axis=0)
    y_true = np.reshape(y_true, (len(y_true),1))
    loss = cce(y_true, logits)
    logits = np.where(logits > 0.5, 1, 0)
    print("Loss: " , loss)
    return loss, loss

# %%
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=RANDOM_SEED)
skf.get_n_splits(vitals_features_reshaped, vitals_labels_reshaped)
# Out:
# 5

# %% [markdown]
# ### Training the model - Each client validate on their own data

# %%
from tensorflow.keras import backend as K

loss_CV = []
acc_CV = []
val_loss_values_averages_all = []
loss_values_averages_all = []
clients_number = 4
patience = 10
best_models = []
early_stopping_applied = []
test_batches_CV = []
for train_index, test_index in skf.split(vitals_features_reshaped, vitals_labels_reshaped):
    print("TRAIN:", train_index, "TEST:", test_index)
    X_train_vitals, X_test_vitals = vitals_features_reshaped[train_index], vitals_features_reshaped[test_index]
    X_train_labs, X_test_labs = labs_features_reshaped[train_index], labs_features_reshaped[test_index]
    y_train, y_test = vitals_labels_reshaped[train_index], vitals_labels_reshaped[test_index]

    clients = create_clients(X_train_labs, X_train_vitals ,y_train, num_clients=clients_number, initial='client')
    #process and batch the training data for each client
    clients_batched = dict()
    client_counter = 0
    for (client_name, data) in clients.items():
        if client_counter == 3:
            clients_batched[client_name] = batch_data_last(data)
        else:
            clients_batched[client_name] = batch_data(data)
        client_counter = client_counter + 1
     #Standardizing the testing set based on all training data
    X_train_labs = np.array(X_train_labs)
    samples_train, groupedBy_train, sample_values_train = X_train_labs.shape
    X_train_labs = np.reshape(X_train_labs, (samples_train*groupedBy_train,sample_values_train))
    samples_test, groupedBy_test, sample_values_test = X_test_labs.shape
    X_test_labs = np.reshape(X_test_labs, (samples_test*groupedBy_test,sample_values_test))
    scaler_labs = StandardScaler()
    scaler_labs = scaler_labs.fit(X_train_labs)
    X_test_labs = scaler_labs.transform(X_test_labs)
    X_test_labs = np.reshape(X_test_labs, (samples_test,groupedBy_test,sample_values_test))


    X_train_vitals = np.array(X_train_vitals)
    samples_train, groupedBy_train, sample_values_train = X_train_vitals.shape
    X_train_vitals = np.reshape(X_train_vitals, (samples_train*groupedBy_train,sample_values_train))
    samples_test, groupedBy_test, sample_values_test = X_test_vitals.shape
    X_test_vitals = np.reshape(X_test_vitals, (samples_test*groupedBy_test,sample_values_test))
    scaler_labs = StandardScaler()
    scaler_labs = scaler_labs.fit(X_train_vitals)
    X_test_vitals = scaler_labs.transform(X_test_vitals)
    X_test_vitals = np.reshape(X_test_vitals, (samples_test,groupedBy_test,sample_values_test))
    
    #process and batch the test set  
    test_batched = tf.data.Dataset.from_tensor_slices(({"Input_1": list(X_test_labs), 
    "Input_2": list(X_test_vitals)}, list(y_test))).batch(len(y_test))
    test_batches_CV.append(test_batched)
       #randomize client data - using keys
    client_names= list(clients_batched.keys())
    #random.shuffle(client_names)
    #initialize global model
    val_loss_values_averages = []
    loss_values_averages = []
    models_CV = []
    best_score = 0
    rounds_worse_than_before = 0    
    rnn_global = RNNModel()
    global_model = rnn_global.build()
    comms_round = 300
    loss = 'binary_crossentropy'
    metrics = ['accuracy']
    global_loss = []
    global_acc = []
    learning_rate = 0.01
    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
    counter = 0
    #commence global training loop
    for comm_round in range(comms_round):
        if comm_round % 5 == 0 and comm_round > 0:
            learning_rate = learning_rate * 0.5
            optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
        # get the global model's weights - will serve as the initial weights for all local models
        global_weights = global_model.get_weights()
        
        #initial list to collect local model weights after scalling
        scaled_local_weight_list = list()

        #loop through each client and create new local model
        for client in client_names[:-1]:
            rnn_local = RNNModel()
            local_model = rnn_local.build()
            local_model.compile(loss=loss, 
                        optimizer=optimizer, 
                        metrics=metrics)
            
            #set local model weight to the weight of the global model
            local_model.set_weights(global_weights)

            #fit local model with client's data
            local_model.fit(clients_batched[client][0], epochs=3, verbose=0 , validation_data=clients_batched[client][1])
            
            #scale the model weights and add to list
            scaling_factor = weight_scalling_factor(clients_batched, client)
            scaled_weights = scale_model_weights(local_model.get_weights(), scaling_factor)
            scaled_local_weight_list.append(scaled_weights)
            print(client, "Finished")
            #clear session to free memory after each communication round
            K.clear_session()
            
        #to get the average over all the local model, we simply take the sum of the scaled weights
        average_weights = sum_scaled_weights(scaled_local_weight_list)
        
        #update global model 
        global_model.set_weights(average_weights)

        #evaluating the current global model against each clients validation data
        val_loss_values = 0
        loss_values = 0
        rnn_local = RNNModel()
        local_model = rnn_local.build()
        local_model.compile(loss=loss, 
                        optimizer=optimizer, 
                        metrics=metrics)     
            #set local model weight to the weight of the global model
        local_model.set_weights(global_weights)
        val_loss_value, loss_value = evaluating_model_own_validation_data(local_model, clients_batched[client_names[-1]][0])
        print(client_names[-1], ":", val_loss_value)
        val_loss_values += val_loss_value
        loss_values += loss_value
        print("F1 Score average for round {} = {}, Loss: {}".format(comm_round, val_loss_values, loss_values))
        models_CV.append(global_model)
        val_loss_values_averages.append(val_loss_values)
        loss_values_averages.append(loss_values)
        if  len(val_loss_values_averages) == 1:
            best_score = val_loss_values_averages[0]
        #checks for early stopping according to f1 score and patience
        if len(val_loss_values_averages) > 1:
            if val_loss_values_averages[-1] >= best_score:
                rounds_worse_than_before += 1
            else:
                rounds_worse_than_before = 0
                best_score = val_loss_values_averages[-1]
        if rounds_worse_than_before == patience:
            break
        #test global model and print out metrics after each communications round
        #for(X_test, Y_test) in test_batched:
            #global_f1_acc, global_model_loss = test_model(X_test, Y_test, global_model, comm_round)
            #global_loss.append(global_model_loss)
            #global_acc.append(global_f1_acc)
    if rounds_worse_than_before == patience:
        val_loss_values_averages_all.append(val_loss_values_averages[:-patience])
        loss_values_averages_all.append(loss_values_averages[:-patience])
        best_models.append(models_CV[:-patience])
        early_stopping_applied.append(True)
    else:
        val_loss_values_averages_all.append(val_loss_values_averages_all)
        loss_values_averages_all.append(loss_values_averages)
        best_models.append(models_CV) 
        early_stopping_applied.append(False)
    #models_CV.append(global_model)
    #loss_CV.append(global_loss)
    #acc_CV.append(global_acc)
    print("CV Round complete")
# Out:
# TRAIN: [    0     1     3 ... 19410 19411 19413] TEST: [    2     4    17 ... 19399 19400 19412]
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.9274395, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.9274395, shape=(), dtype=float32)
# F1 Score average for round 0 = 0.9274395108222961, Loss: 0.9274395108222961
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.79405695, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.79405695, shape=(), dtype=float32)
# F1 Score average for round 1 = 0.7940569519996643, Loss: 0.7940569519996643
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.79087466, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.79087466, shape=(), dtype=float32)
# F1 Score average for round 2 = 0.7908746600151062, Loss: 0.7908746600151062
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.77853274, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.77853274, shape=(), dtype=float32)
# F1 Score average for round 3 = 0.7785327434539795, Loss: 0.7785327434539795
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7755003, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.7755003, shape=(), dtype=float32)
# F1 Score average for round 4 = 0.7755002975463867, Loss: 0.7755002975463867
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.77694345, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.77694345, shape=(), dtype=float32)
# F1 Score average for round 5 = 0.7769434452056885, Loss: 0.7769434452056885
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7725428, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.7725428, shape=(), dtype=float32)
# F1 Score average for round 6 = 0.7725427746772766, Loss: 0.7725427746772766
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.77078605, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.77078605, shape=(), dtype=float32)
# F1 Score average for round 7 = 0.7707860469818115, Loss: 0.7707860469818115
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.76819026, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.76819026, shape=(), dtype=float32)
# F1 Score average for round 8 = 0.7681902647018433, Loss: 0.7681902647018433
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.77456003, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.77456003, shape=(), dtype=float32)
# F1 Score average for round 9 = 0.7745600342750549, Loss: 0.7745600342750549
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7589233, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.7589233, shape=(), dtype=float32)
# F1 Score average for round 10 = 0.7589232921600342, Loss: 0.7589232921600342
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7791809, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.7791809, shape=(), dtype=float32)
# F1 Score average for round 11 = 0.7791808843612671, Loss: 0.7791808843612671
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7862979, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.7862979, shape=(), dtype=float32)
# F1 Score average for round 12 = 0.7862979173660278, Loss: 0.7862979173660278
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7844225, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.7844225, shape=(), dtype=float32)
# F1 Score average for round 13 = 0.7844225168228149, Loss: 0.7844225168228149
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.793925, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.793925, shape=(), dtype=float32)
# F1 Score average for round 14 = 0.7939249873161316, Loss: 0.7939249873161316
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7848675, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.7848675, shape=(), dtype=float32)
# F1 Score average for round 15 = 0.784867525100708, Loss: 0.784867525100708
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7975089, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.7975089, shape=(), dtype=float32)
# F1 Score average for round 16 = 0.7975088953971863, Loss: 0.7975088953971863
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.81044, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.81044, shape=(), dtype=float32)
# F1 Score average for round 17 = 0.8104400038719177, Loss: 0.8104400038719177
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.8019977, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.8019977, shape=(), dtype=float32)
# F1 Score average for round 18 = 0.801997721195221, Loss: 0.801997721195221
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.79221374, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.79221374, shape=(), dtype=float32)
# F1 Score average for round 19 = 0.7922137379646301, Loss: 0.7922137379646301
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.808889, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.808889, shape=(), dtype=float32)
# F1 Score average for round 20 = 0.8088889718055725, Loss: 0.8088889718055725
# CV Round complete
# TRAIN: [    1     2     4 ... 19410 19412 19413] TEST: [    0     3    15 ... 19405 19408 19411]
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.92114013, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.92114013, shape=(), dtype=float32)
# F1 Score average for round 0 = 0.9211401343345642, Loss: 0.9211401343345642
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.8241652, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.8241652, shape=(), dtype=float32)
# F1 Score average for round 1 = 0.8241652250289917, Loss: 0.8241652250289917
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7993753, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.7993753, shape=(), dtype=float32)
# F1 Score average for round 2 = 0.7993752956390381, Loss: 0.7993752956390381
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7993245, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.7993245, shape=(), dtype=float32)
# F1 Score average for round 3 = 0.7993245124816895, Loss: 0.7993245124816895
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7792061, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.7792061, shape=(), dtype=float32)
# F1 Score average for round 4 = 0.7792060971260071, Loss: 0.7792060971260071
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7629228, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.7629228, shape=(), dtype=float32)
# F1 Score average for round 5 = 0.7629228234291077, Loss: 0.7629228234291077
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.78056043, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.78056043, shape=(), dtype=float32)
# F1 Score average for round 6 = 0.7805604338645935, Loss: 0.7805604338645935
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.77319074, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.77319074, shape=(), dtype=float32)
# F1 Score average for round 7 = 0.7731907367706299, Loss: 0.7731907367706299
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.76989734, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.76989734, shape=(), dtype=float32)
# F1 Score average for round 8 = 0.7698973417282104, Loss: 0.7698973417282104
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.77920645, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.77920645, shape=(), dtype=float32)
# F1 Score average for round 9 = 0.7792064547538757, Loss: 0.7792064547538757
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.76752996, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.76752996, shape=(), dtype=float32)
# F1 Score average for round 10 = 0.7675299644470215, Loss: 0.7675299644470215
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7808985, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.7808985, shape=(), dtype=float32)
# F1 Score average for round 11 = 0.7808985114097595, Loss: 0.7808985114097595
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.78103375, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.78103375, shape=(), dtype=float32)
# F1 Score average for round 12 = 0.7810337543487549, Loss: 0.7810337543487549
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.78327566, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.78327566, shape=(), dtype=float32)
# F1 Score average for round 13 = 0.7832756638526917, Loss: 0.7832756638526917
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7807962, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.7807962, shape=(), dtype=float32)
# F1 Score average for round 14 = 0.7807961702346802, Loss: 0.7807961702346802
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7770505, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.7770505, shape=(), dtype=float32)
# F1 Score average for round 15 = 0.7770504951477051, Loss: 0.7770504951477051
# CV Round complete
# TRAIN: [    0     1     2 ... 19411 19412 19413] TEST: [    6     7     8 ... 19391 19398 19401]
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.9325476, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.9325476, shape=(), dtype=float32)
# F1 Score average for round 0 = 0.9325476288795471, Loss: 0.9325476288795471
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7950619, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.7950619, shape=(), dtype=float32)
# F1 Score average for round 1 = 0.7950618863105774, Loss: 0.7950618863105774
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.78837156, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.78837156, shape=(), dtype=float32)
# F1 Score average for round 2 = 0.7883715629577637, Loss: 0.7883715629577637
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7750715, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.7750715, shape=(), dtype=float32)
# F1 Score average for round 3 = 0.7750715017318726, Loss: 0.7750715017318726
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7784714, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.7784714, shape=(), dtype=float32)
# F1 Score average for round 4 = 0.7784714102745056, Loss: 0.7784714102745056
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7740444, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.7740444, shape=(), dtype=float32)
# F1 Score average for round 5 = 0.774044394493103, Loss: 0.774044394493103
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7741689, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.7741689, shape=(), dtype=float32)
# F1 Score average for round 6 = 0.7741689085960388, Loss: 0.7741689085960388
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7810217, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.7810217, shape=(), dtype=float32)
# F1 Score average for round 7 = 0.7810217142105103, Loss: 0.7810217142105103
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7712669, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.7712669, shape=(), dtype=float32)
# F1 Score average for round 8 = 0.7712668776512146, Loss: 0.7712668776512146
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7722537, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.7722537, shape=(), dtype=float32)
# F1 Score average for round 9 = 0.772253692150116, Loss: 0.772253692150116
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7756177, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.7756177, shape=(), dtype=float32)
# F1 Score average for round 10 = 0.7756177186965942, Loss: 0.7756177186965942
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.78861624, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.78861624, shape=(), dtype=float32)
# F1 Score average for round 11 = 0.7886162400245667, Loss: 0.7886162400245667
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7794598, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.7794598, shape=(), dtype=float32)
# F1 Score average for round 12 = 0.7794597744941711, Loss: 0.7794597744941711
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7870131, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.7870131, shape=(), dtype=float32)
# F1 Score average for round 13 = 0.7870131134986877, Loss: 0.7870131134986877
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7767113, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.7767113, shape=(), dtype=float32)
# F1 Score average for round 14 = 0.7767112851142883, Loss: 0.7767112851142883
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.77068585, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.77068585, shape=(), dtype=float32)
# F1 Score average for round 15 = 0.7706858515739441, Loss: 0.7706858515739441
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7951541, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.7951541, shape=(), dtype=float32)
# F1 Score average for round 16 = 0.7951540946960449, Loss: 0.7951540946960449
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.79847455, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.79847455, shape=(), dtype=float32)
# F1 Score average for round 17 = 0.7984745502471924, Loss: 0.7984745502471924
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7935107, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.7935107, shape=(), dtype=float32)
# F1 Score average for round 18 = 0.7935106754302979, Loss: 0.7935106754302979
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.8025831, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.8025831, shape=(), dtype=float32)
# F1 Score average for round 19 = 0.8025830984115601, Loss: 0.8025830984115601
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.78878033, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.78878033, shape=(), dtype=float32)
# F1 Score average for round 20 = 0.7887803316116333, Loss: 0.7887803316116333
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.8335381, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.8335381, shape=(), dtype=float32)
# F1 Score average for round 21 = 0.8335381150245667, Loss: 0.8335381150245667
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.83457464, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.83457464, shape=(), dtype=float32)
# F1 Score average for round 22 = 0.8345746397972107, Loss: 0.8345746397972107
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.83951116, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.83951116, shape=(), dtype=float32)
# F1 Score average for round 23 = 0.8395111560821533, Loss: 0.8395111560821533
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.82494664, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.82494664, shape=(), dtype=float32)
# F1 Score average for round 24 = 0.8249466419219971, Loss: 0.8249466419219971
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.8231664, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.8231664, shape=(), dtype=float32)
# F1 Score average for round 25 = 0.8231663703918457, Loss: 0.8231663703918457
# CV Round complete
# TRAIN: [    0     1     2 ... 19411 19412 19413] TEST: [   37    40    52 ... 19407 19409 19410]
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.9253204, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.9253204, shape=(), dtype=float32)
# F1 Score average for round 0 = 0.9253203868865967, Loss: 0.9253203868865967
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.839253, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.839253, shape=(), dtype=float32)
# F1 Score average for round 1 = 0.8392530083656311, Loss: 0.8392530083656311
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7864371, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.7864371, shape=(), dtype=float32)
# F1 Score average for round 2 = 0.7864370942115784, Loss: 0.7864370942115784
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.794049, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.794049, shape=(), dtype=float32)
# F1 Score average for round 3 = 0.7940490245819092, Loss: 0.7940490245819092
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.77691895, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.77691895, shape=(), dtype=float32)
# F1 Score average for round 4 = 0.7769189476966858, Loss: 0.7769189476966858
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7666192, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.7666192, shape=(), dtype=float32)
# F1 Score average for round 5 = 0.7666192054748535, Loss: 0.7666192054748535
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7990015, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.7990015, shape=(), dtype=float32)
# F1 Score average for round 6 = 0.7990015149116516, Loss: 0.7990015149116516
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7799826, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.7799826, shape=(), dtype=float32)
# F1 Score average for round 7 = 0.7799826264381409, Loss: 0.7799826264381409
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.77390295, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.77390295, shape=(), dtype=float32)
# F1 Score average for round 8 = 0.773902952671051, Loss: 0.773902952671051
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.769689, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.769689, shape=(), dtype=float32)
# F1 Score average for round 9 = 0.7696890234947205, Loss: 0.7696890234947205
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.78055155, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.78055155, shape=(), dtype=float32)
# F1 Score average for round 10 = 0.780551552772522, Loss: 0.780551552772522
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.78462076, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.78462076, shape=(), dtype=float32)
# F1 Score average for round 11 = 0.7846207618713379, Loss: 0.7846207618713379
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.78229034, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.78229034, shape=(), dtype=float32)
# F1 Score average for round 12 = 0.7822903394699097, Loss: 0.7822903394699097
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7822273, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.7822273, shape=(), dtype=float32)
# F1 Score average for round 13 = 0.7822272777557373, Loss: 0.7822272777557373
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.77582204, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.77582204, shape=(), dtype=float32)
# F1 Score average for round 14 = 0.7758220434188843, Loss: 0.7758220434188843
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.77494425, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.77494425, shape=(), dtype=float32)
# F1 Score average for round 15 = 0.7749442458152771, Loss: 0.7749442458152771
# CV Round complete
# TRAIN: [    0     2     3 ... 19410 19411 19412] TEST: [    1     5    11 ... 19404 19406 19413]
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.93046415, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.93046415, shape=(), dtype=float32)
# F1 Score average for round 0 = 0.9304641485214233, Loss: 0.9304641485214233
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.83749354, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.83749354, shape=(), dtype=float32)
# F1 Score average for round 1 = 0.8374935388565063, Loss: 0.8374935388565063
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7874057, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.7874057, shape=(), dtype=float32)
# F1 Score average for round 2 = 0.7874057292938232, Loss: 0.7874057292938232
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7915548, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.7915548, shape=(), dtype=float32)
# F1 Score average for round 3 = 0.7915548086166382, Loss: 0.7915548086166382
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.782311, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.782311, shape=(), dtype=float32)
# F1 Score average for round 4 = 0.7823110222816467, Loss: 0.7823110222816467
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7777889, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.7777889, shape=(), dtype=float32)
# F1 Score average for round 5 = 0.7777888774871826, Loss: 0.7777888774871826
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7865205, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.7865205, shape=(), dtype=float32)
# F1 Score average for round 6 = 0.7865204811096191, Loss: 0.7865204811096191
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.77647734, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.77647734, shape=(), dtype=float32)
# F1 Score average for round 7 = 0.7764773368835449, Loss: 0.7764773368835449
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.78735775, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.78735775, shape=(), dtype=float32)
# F1 Score average for round 8 = 0.787357747554779, Loss: 0.787357747554779
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.77277946, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.77277946, shape=(), dtype=float32)
# F1 Score average for round 9 = 0.7727794647216797, Loss: 0.7727794647216797
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.78064644, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.78064644, shape=(), dtype=float32)
# F1 Score average for round 10 = 0.7806464433670044, Loss: 0.7806464433670044
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7879576, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.7879576, shape=(), dtype=float32)
# F1 Score average for round 11 = 0.7879576086997986, Loss: 0.7879576086997986
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7840138, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.7840138, shape=(), dtype=float32)
# F1 Score average for round 12 = 0.7840138077735901, Loss: 0.7840138077735901
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7790617, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.7790617, shape=(), dtype=float32)
# F1 Score average for round 13 = 0.7790616750717163, Loss: 0.7790616750717163
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.78673923, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.78673923, shape=(), dtype=float32)
# F1 Score average for round 14 = 0.7867392301559448, Loss: 0.7867392301559448
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.78206956, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.78206956, shape=(), dtype=float32)
# F1 Score average for round 15 = 0.7820695638656616, Loss: 0.7820695638656616
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.8071626, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.8071626, shape=(), dtype=float32)
# F1 Score average for round 16 = 0.8071625828742981, Loss: 0.8071625828742981
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.80408853, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.80408853, shape=(), dtype=float32)
# F1 Score average for round 17 = 0.8040885329246521, Loss: 0.8040885329246521
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.79930127, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.79930127, shape=(), dtype=float32)
# F1 Score average for round 18 = 0.799301266670227, Loss: 0.799301266670227
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7979181, shape=(), dtype=float32)
# client_4 : tf.Tensor(0.7979181, shape=(), dtype=float32)
# F1 Score average for round 19 = 0.7979180812835693, Loss: 0.7979180812835693
# CV Round complete

# %% [markdown]
# # Results for Early Stopping when monitoring the average F1 Score value of all the clients using their own validation data

# %%
plt.subplot(2,1,1)
for i in range(len(loss_values_averages_all)):
    plt.plot(loss_values_averages_all[i])
plt.title('models\' loss')
plt.ylabel('loss')
plt.xlabel('Communication rounds')
plt.legend(['fold1', 'fold2','fold3', 'fold4', 'fold5'], loc='lower right')
plt.savefig("Model's Validation loss vs Communication Rounds - Third technique with validation loss - 10 patience")

# %%
from sklearn.metrics import classification_report
average_f1_score = 0
#Confution Matrix and Classification Report
for i in range(len(best_models)):
    Y_pred = best_models[i][-1].predict(test_batches_CV[i])
    y_pred = np.where(Y_pred > 0.5, 1, 0)
    print('Confusion Matrix')
    y_pred = y_pred.max(axis=1)
    y_true = np.concatenate([y for x, y in test_batches_CV[i]], axis=0)
    print(confusion_matrix(y_true, y_pred, labels=[True, False]))
    f1_score_acc = f1_score(y_true, y_pred, average='macro')
    average_f1_score += f1_score_acc
    print("F1 Score: {}".format(f1_score_acc))
    print(classification_report(y_true, y_pred, target_names=['Class 0', 'Class 1']))
average_f1_score = average_f1_score / len(best_models)
print("Average F1 Score: {}".format(average_f1_score))
# Out:
# Confusion Matrix
# [[ 277  101]
#  [  23 3482]]
# F1 Score: 0.8998073939418153
#               precision    recall  f1-score   support
#
#      Class 0       0.97      0.99      0.98      3505
#      Class 1       0.92      0.73      0.82       378
#
#     accuracy                           0.97      3883
#    macro avg       0.95      0.86      0.90      3883
# weighted avg       0.97      0.97      0.97      3883
#
# Confusion Matrix
# [[ 284   94]
#  [  18 3487]]
# F1 Score: 0.9097441516826883
#               precision    recall  f1-score   support
#
#      Class 0       0.97      0.99      0.98      3505
#      Class 1       0.94      0.75      0.84       378
#
#     accuracy                           0.97      3883
#    macro avg       0.96      0.87      0.91      3883
# weighted avg       0.97      0.97      0.97      3883
#
# Confusion Matrix
# [[ 246  133]
#  [  22 3482]]
# F1 Score: 0.869330022863691
#               precision    recall  f1-score   support
#
#      Class 0       0.96      0.99      0.98      3504
#      Class 1       0.92      0.65      0.76       379
#
#     accuracy                           0.96      3883
#    macro avg       0.94      0.82      0.87      3883
# weighted avg       0.96      0.96      0.96      3883
#
# WARNING:tensorflow:5 out of the last 65 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001FE1EB31378> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Confusion Matrix
# [[ 271  108]
#  [  24 3480]]
# F1 Score: 0.8927708907600155
#               precision    recall  f1-score   support
#
#      Class 0       0.97      0.99      0.98      3504
#      Class 1       0.92      0.72      0.80       379
#
#     accuracy                           0.97      3883
#    macro avg       0.94      0.85      0.89      3883
# weighted avg       0.96      0.97      0.96      3883
#
# WARNING:tensorflow:6 out of the last 66 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001FE21FEC6A8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Confusion Matrix
# [[ 240  138]
#  [  13 3491]]
# F1 Score: 0.8697640461745291
#               precision    recall  f1-score   support
#
#      Class 0       0.96      1.00      0.98      3504
#      Class 1       0.95      0.63      0.76       378
#
#     accuracy                           0.96      3882
#    macro avg       0.96      0.82      0.87      3882
# weighted avg       0.96      0.96      0.96      3882
#
# Average F1 Score: 0.8882833010845479

# %%
import sklearn.metrics as metrics

for i in range(len(best_models)):
    Y_pred = best_models[i][-1].predict(test_batches_CV[i])
    y_pred = np.where(Y_pred > 0.5, 1, 0)
    y_pred = y_pred.max(axis=1)
    y_true = np.concatenate([y for x, y in test_batches_CV[i]], axis=0)
    fpr, tpr, threshold = metrics.roc_curve(y_true, y_pred)
    roc_auc = metrics.auc(fpr, tpr)
    print("FPR: ", fpr)
    print("TPR: ", tpr)
    # method I: plt
    plt.title('Receiver Operating Characteristic')
    plt.plot(fpr, tpr, 'b', label = 'AUC = %0.4f' % roc_auc)
    plt.legend(loc = 'lower right')
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([0, 1])
    plt.ylim([0, 1])
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()
# Out:
# FPR:  [0.         0.00656205 1.        ]
# TPR:  [0.         0.73280423 1.        ]
# FPR:  [0.         0.00513552 1.        ]
# TPR:  [0.         0.75132275 1.        ]
# FPR:  [0.         0.00627854 1.        ]
# TPR:  [0.         0.64907652 1.        ]
# FPR:  [0.         0.00684932 1.        ]
# TPR:  [0.         0.71503958 1.        ]
# FPR:  [0.         0.00371005 1.        ]
# TPR:  [0.         0.63492063 1.        ]

# %%
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import auc

for i in range(len(best_models)):
    Y_pred = best_models[i][-1].predict(test_batches_CV[i])
    y_pred = np.where(Y_pred > 0.5, 1, 0)
    y_pred = y_pred.max(axis=1)
    y_true = np.concatenate([y for x, y in test_batches_CV[i]], axis=0)
    lr_precision, lr_recall, _ = precision_recall_curve(y_true, y_pred)
    lr_f1, lr_auc = f1_score(y_true, y_pred, average='macro'), auc(lr_recall, lr_precision)
    # summarize scores
    print("Precision: ", lr_precision)
    print("Recall: ", lr_recall)
    print('Logistic: f1=%.3f auc=%.3f' % (lr_f1, lr_auc))
    # plot the precision-recall curves
    no_skill = len(y_true[y_true==1]) / len(y_true)
    plt.plot([0, 1], [no_skill, no_skill], linestyle='--')
    plt.plot(lr_recall, lr_precision, marker='.', label = 'AUC = %0.4f' % lr_auc)
    # axis labels
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    # show the legend
    plt.legend()
    # show the plot
    plt.show()
# Out:
# Precision:  [0.09734741 0.92333333 1.        ]
# Recall:  [1.         0.73280423 0.        ]
# Logistic: f1=0.900 auc=0.841
# Precision:  [0.09734741 0.94039735 1.        ]
# Recall:  [1.         0.75132275 0.        ]
# Logistic: f1=0.910 auc=0.858
# Precision:  [0.09760494 0.91791045 1.        ]
# Recall:  [1.         0.64907652 0.        ]
# Logistic: f1=0.869 auc=0.801
# Precision:  [0.09760494 0.91864407 1.        ]
# Recall:  [1.         0.71503958 0.        ]
# Logistic: f1=0.893 auc=0.831
# Precision:  [0.09737249 0.9486166  1.        ]
# Recall:  [1.         0.63492063 0.        ]
# Logistic: f1=0.870 auc=0.810
