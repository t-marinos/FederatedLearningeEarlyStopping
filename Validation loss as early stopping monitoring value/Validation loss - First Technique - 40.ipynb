# %%
import pandas as pd
import numpy as np
import random
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.utils.vis_utils import plot_model
from tensorflow.keras.layers import LSTM, Dense, Input, add, concatenate
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K

RANDOM_SEED = 42
random.seed(RANDOM_SEED)
# Out:
# c:\Users\Theo\AppData\Local\Programs\Python\Python37\lib\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# c:\Users\Theo\AppData\Local\Programs\Python\Python37\lib\site-packages\numpy\.libs\libopenblas.IPBC74C7KURV7CB2PKT5Z5FNR3SIBV4J.gfortran-win_amd64.dll
# c:\Users\Theo\AppData\Local\Programs\Python\Python37\lib\site-packages\numpy\.libs\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll
#   stacklevel=1)

# %%
vitals = pd.read_csv('vitals.csv')  
labs = pd.read_csv('labs.csv')

# %% [markdown]
# Changing the date to datetime variable and setting indexes

# %%
vitals['charttime'] = pd.to_datetime(vitals['charttime'] , infer_datetime_format=True)
labs['charttime'] = pd.to_datetime(labs['charttime'] , infer_datetime_format=True)

# %%
vitals_48hours_grouped = vitals.groupby('icustay_id').tail(48)

# %%
labs_48hours_grouped = labs.groupby('icustay_id').tail(6)

# %%
print((vitals_48hours_grouped.icustay_id.value_counts() == 48).sum() == len(vitals_48hours_grouped) /48)
print((labs_48hours_grouped.icustay_id.value_counts() == 6).sum() == len(labs_48hours_grouped) /6)
# Out:
# True
# True

# %%
vitals_48hours_grouped = vitals_48hours_grouped.drop(['icustay_id','charttime'], axis=1)
labs_48hours_grouped = labs_48hours_grouped.drop(['icustay_id','charttime'], axis=1)

# %%
vitals_features = vitals_48hours_grouped.iloc[:,:-1]
vitals_labels = vitals_48hours_grouped.iloc[:,-1:].to_numpy().tolist()

# %%
labs_features = labs_48hours_grouped.iloc[:,:-1]
labs_labels = labs_48hours_grouped.iloc[:,-1:].to_numpy().tolist()

# %% [markdown]
# # Federated Learning Setup

# %%
def create_clients(labs_data, vitals_data, label_list, num_clients=4, initial='clients'):
    ''' return: a dictionary with keys clients' names and value as 
                data shards - tuple of images and label lists.
        args: 
            image_list: a list of numpy arrays of training images
            label_list:a list of binarized labels for each image
            num_client: number of fedrated members (clients)
            initials: the clients'name prefix, e.g, clients_1 
            
    '''

    #create a list of client names
    client_names = ['{}_{}'.format(initial, i+1) for i in range(num_clients)]

    #randomize the data
    data = list(zip(labs_data, vitals_data))
    data = list(zip(data, label_list))
    random.shuffle(data)

    #shard data and place at each client
    size = len(data)//num_clients
    shards = [data[i:i + size] for i in range(0, size*num_clients, size)]

    #number of clients must equal number of shards
    assert(len(shards) == len(client_names))
    
    return  {client_names[i] : shards[i] for i in range(len(client_names))}

# %% [markdown]
# ## Reshaping data and preparing them for cross validation

# %%
vitals_labels = np.array(vitals_labels)
labs_labels = np.array(labs_labels)


labs_labels_reshaped = np.reshape(labs_labels, (19414,6))
labs_labels_reshaped = np.amax(labs_labels_reshaped, axis=1)

vitals_labels_reshaped = np.reshape(vitals_labels, (19414,48))
vitals_labels_reshaped = np.amax(vitals_labels_reshaped, axis=1)
print(labs_labels_reshaped.shape)
print(vitals_labels_reshaped.shape)
# Out:
# (19414,)
# (19414,)

# %%
vitals_features_reshaped = np.reshape(vitals_features.values, (19414,48,7))
print(vitals_features_reshaped.shape)
labs_features_reshaped = np.reshape(labs_features.values, (19414,6,16))
print(labs_features_reshaped.shape)
# Out:
# (19414, 48, 7)
# (19414, 6, 16)

# %% [markdown]
# ### Batching clients and test data

# %%
def batch_data(data_shard, bs=64):
    '''Takes in a clients data shard and create a tfds object off it
    args:
        shard: a data, label constituting a client's data shard
        bs:batch size
    return:
        tfds object'''
    #seperate shard into data and labels lists
    data, label = zip(*data_shard)
    dataset = []
    X_train, X_test, y_train, y_test = train_test_split(data, label, test_size=0.15, random_state=RANDOM_SEED, stratify=label)
    X_labs_train , X_vitals_train = zip(*X_train)
    X_labs_test , X_vitals_test = zip(*X_test)

    #Reshaping to standardize the laboratory values
    X_labs_train = np.array(X_labs_train)
    X_labs_test = np.array(X_labs_test)
    samples_train, groupedBy_train, sample_values_train = X_labs_train.shape
    samples_test, groupedBy_test, sample_values_test = X_labs_test.shape
    X_labs_train_reshaped = np.reshape(X_labs_train, (samples_train*groupedBy_train, sample_values_train))
    X_labs_test_reshaped = np.reshape(X_labs_test, (samples_test*groupedBy_test, sample_values_test))
    #Standardizing the laboratory values
    scaler_labs = StandardScaler()
    scaler_labs = scaler_labs.fit(X_labs_train_reshaped)
    X_labs_train_reshaped = scaler_labs.transform(X_labs_train_reshaped)
    X_labs_test_reshaped = scaler_labs.transform(X_labs_test_reshaped)
    #Reshaping again
    X_labs_train = np.reshape(X_labs_train_reshaped,  (samples_train, groupedBy_train, sample_values_train))
    X_labs_test = np.reshape(X_labs_test_reshaped, (samples_test, groupedBy_test, sample_values_test))

    #Reshaping to standardize the laboratory values
    X_vitals_train = np.array(X_vitals_train)
    X_vitals_test = np.array(X_vitals_test)
    samples_train, groupedBy_train, sample_values_train = X_vitals_train.shape
    samples_test, groupedBy_test, sample_values_test = X_vitals_test.shape
    X_vitals_train_reshaped = np.reshape(X_vitals_train, (samples_train*groupedBy_train, sample_values_train))
    X_vitals_test_reshaped = np.reshape(X_vitals_test, (samples_test*groupedBy_test, sample_values_test))
    #Standardizing the laboratory values
    scaler_vitals = StandardScaler()
    scaler_vitals = scaler_vitals.fit(X_vitals_train_reshaped)
    X_vitals_train_reshaped = scaler_vitals.transform(X_vitals_train_reshaped)
    X_vitals_test_reshaped = scaler_vitals.transform(X_vitals_test_reshaped)
    #Reshaping again
    X_vitals_train = np.reshape(X_vitals_train_reshaped,  (samples_train, groupedBy_train, sample_values_train))
    X_vitals_test = np.reshape(X_vitals_test_reshaped, (samples_test, groupedBy_test, sample_values_test))

    combinedDatasetTraining = tf.data.Dataset.from_tensor_slices(({"Input_1": list(X_labs_train), "Input_2": list(X_vitals_train)}, list(y_train)))
    combinedDatasetTraining = combinedDatasetTraining.shuffle(len(y_train)).batch(bs)
    combinedDatasetTesting = tf.data.Dataset.from_tensor_slices(({"Input_1": list(X_labs_test), "Input_2": list(X_vitals_test)}, list(y_test)))
    combinedDatasetTesting = combinedDatasetTesting.shuffle(len(y_test)).batch(bs)
    
    dataset.append(combinedDatasetTraining)
    dataset.append(combinedDatasetTesting)
    return dataset

# %% [markdown]
# ### Creating the Model

# %%
class RNNModel:
    @staticmethod
    def build():
     input1 = Input(shape=(6,16), name='Input_1')
     fe1 = LSTM(16, input_shape= (6,16), return_sequences=True)(input1)
     fe2 = LSTM(16, return_sequences=True)(fe1)
     fe3 = LSTM(16)(fe2)
#sequence model
     input2 = Input(shape=(48,7), name='Input_2')
     se1 = LSTM(16, input_shape= (48,7), return_sequences=True)(input2)
     se2 = LSTM(16, return_sequences=True)(se1)
     se3 = LSTM(16)(se2)
#decoder model
     decoder1 = concatenate([fe3, se3])
     decoder2 = Dense(16, activation='relu')(decoder1)
     decoder3 = Dense(16, activation='relu')(decoder2)
     output = Dense(1, activation='sigmoid')(decoder3)
#connecting the two models
     model = Model(inputs=[input1, input2], outputs=output)
     return model

# %% [markdown]
# ### Federated Averaging

# %%
def weight_scalling_factor(clients_trn_data, client_name):
    '''Gets batch size and calculates total datapoints and how many data points the client has to scale it'''
    client_names = list(clients_trn_data.keys())
    #get the bs
    bs = list(clients_trn_data[client_name][0])[0][0]['Input_1'].shape[0]
    #first calculate the total training data points across clinets
    global_count = sum([tf.data.experimental.cardinality(clients_trn_data[client_name][0]).numpy() for client_name in client_names])*bs
    # get the total number of data points held by a client
    local_count = tf.data.experimental.cardinality(clients_trn_data[client_name][0]).numpy()*bs
    return local_count/global_count


def scale_model_weights(weight, scalar):
    '''function for scaling a models weights'''
    weight_final = []
    steps = len(weight)
    for i in range(steps):
        weight_final.append(scalar * weight[i])
    return weight_final



def sum_scaled_weights(scaled_weight_list):
    '''Return the sum of the listed scaled weights. The is equivalent to scaled avg of the weights'''
    avg_grad = list()
    #get the average grad accross all client gradients
    for grad_list_tuple in zip(*scaled_weight_list):
        layer_mean = tf.math.reduce_sum(grad_list_tuple, axis=0)
        avg_grad.append(layer_mean)
        
    return avg_grad


def test_model(X_test, Y_test,  model, comm_round):
    cce = tf.keras.losses.BinaryCrossentropy(from_logits=True)
    #logits = model.predict(X_test, batch_size=100)
    logits = model.predict(X_test)
    Y_test = np.reshape(Y_test, (len(Y_test),1))
    loss = cce(Y_test, logits)
    logits = np.where(logits > 0.5, 1, 0)
    f1_score_acc = f1_score(Y_test.max(axis=1), logits.max(axis=1), average='macro')
    print('comm_round: {} | f1_score: {:.3%} | global_loss: {}'.format(comm_round, f1_score_acc, loss))
    return f1_score_acc, loss

def evaluating_model_own_validation_data(model, val_data):
    cce = tf.keras.losses.BinaryCrossentropy(from_logits=True)
    logits = model.predict(val_data)
    y_true = np.concatenate([y for x, y in val_data], axis=0)
    y_true = np.reshape(y_true, (len(y_true),1))
    loss = cce(y_true, logits)
    logits = np.where(logits > 0.5, 1, 0)
    print("Loss: " , loss)
    return loss

# %%
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=RANDOM_SEED)
skf.get_n_splits(vitals_features_reshaped, vitals_labels_reshaped)
# Out:
# 5

# %% [markdown]
# ### Training the model - Each client validate on their own data

# %%
loss_CV = []
acc_CV = []
loss_validation_averages_all = []
loss_values_averages_all = []
clients_number = 4
patience = 40
best_models = []
early_stopping_applied = []
test_batches_CV = []
for train_index, test_index in skf.split(vitals_features_reshaped, vitals_labels_reshaped):
    print("TRAIN:", train_index, "TEST:", test_index)
    X_train_vitals, X_test_vitals = vitals_features_reshaped[train_index], vitals_features_reshaped[test_index]
    X_train_labs, X_test_labs = labs_features_reshaped[train_index], labs_features_reshaped[test_index]
    y_train, y_test = vitals_labels_reshaped[train_index], vitals_labels_reshaped[test_index]
    clients = create_clients(X_train_labs, X_train_vitals ,y_train, num_clients=clients_number, initial='client')
    #process and batch the training data for each client
    clients_batched = dict()
    for (client_name, data) in clients.items():
        clients_batched[client_name] = batch_data(data)
    #Standardizing the testing set based on all training data
    X_train_labs = np.array(X_train_labs)
    samples_train, groupedBy_train, sample_values_train = X_train_labs.shape
    X_train_labs = np.reshape(X_train_labs, (samples_train*groupedBy_train,sample_values_train))
    samples_test, groupedBy_test, sample_values_test = X_test_labs.shape
    X_test_labs = np.reshape(X_test_labs, (samples_test*groupedBy_test,sample_values_test))
    scaler_labs = StandardScaler()
    scaler_labs = scaler_labs.fit(X_train_labs)
    X_test_labs = scaler_labs.transform(X_test_labs)
    X_test_labs = np.reshape(X_test_labs, (samples_test,groupedBy_test,sample_values_test))


    X_train_vitals = np.array(X_train_vitals)
    samples_train, groupedBy_train, sample_values_train = X_train_vitals.shape
    X_train_vitals = np.reshape(X_train_vitals, (samples_train*groupedBy_train,sample_values_train))
    samples_test, groupedBy_test, sample_values_test = X_test_vitals.shape
    X_test_vitals = np.reshape(X_test_vitals, (samples_test*groupedBy_test,sample_values_test))
    scaler_labs = StandardScaler()
    scaler_labs = scaler_labs.fit(X_train_vitals)
    X_test_vitals = scaler_labs.transform(X_test_vitals)
    X_test_vitals = np.reshape(X_test_vitals, (samples_test,groupedBy_test,sample_values_test))

    #process and batch the test set  
    test_batched = tf.data.Dataset.from_tensor_slices(({"Input_1": list(X_test_labs), 
    "Input_2": list(X_test_vitals)}, list(y_test))).batch(len(y_test))
    test_batches_CV.append(test_batched)
    #initialize global model
    loss_validation_averages = []
    loss_values_averages = []
    models_CV = []
    best_score = 0
    rounds_worse_than_before = 0    
    rnn_global = RNNModel()
    global_model = rnn_global.build()
    comms_round = 300
    loss = 'binary_crossentropy'
    metrics = ['accuracy']
    global_loss = []
    global_acc = []
    learning_rate = 0.01
    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
    counter = 0
    #commence global training loop
    for comm_round in range(comms_round):
        if comm_round % 5 == 0 and comm_round > 0:
            learning_rate = learning_rate * 0.5
            optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
        # get the global model's weights - will serve as the initial weights for all local models
        global_weights = global_model.get_weights()
        
        #initial list to collect local model weights after scalling
        scaled_local_weight_list = list()

        #randomize client data - using keys
        client_names= list(clients_batched.keys())
        random.shuffle(client_names)
        
        #loop through each client and create new local model
        for client in client_names:
            rnn_local = RNNModel()
            local_model = rnn_local.build()
            local_model.compile(loss=loss, 
                        optimizer=optimizer, 
                        metrics=metrics)
            
            #set local model weight to the weight of the global model
            local_model.set_weights(global_weights)

            #fit local model with client's data
            local_model.fit(clients_batched[client][0], epochs=3, verbose=0, validation_data=clients_batched[client][1])
            
            #scale the model weights and add to list
            scaling_factor = weight_scalling_factor(clients_batched, client)
            scaled_weights = scale_model_weights(local_model.get_weights(), scaling_factor)
            scaled_local_weight_list.append(scaled_weights)
            
            #clear session to free memory after each communication round
            K.clear_session()
            
        #to get the average over all the local model, we simply take the sum of the scaled weights
        average_weights = sum_scaled_weights(scaled_local_weight_list)
        
        #update global model 
        global_model.set_weights(average_weights)

        #evaluating the current global model against each clients validation data
        loss_validation_scores = 0
        loss_values = 0
        for client in client_names:
            rnn_local = RNNModel()
            local_model = rnn_local.build()
            local_model.compile(loss=loss, 
                        optimizer=optimizer, 
                        metrics=metrics)     
            #set local model weight to the weight of the global model
            local_model.set_weights(global_weights)
            loss_value = evaluating_model_own_validation_data(local_model, clients_batched[client][1])
            loss_validation_scores += loss_value
            loss_values += loss_value
        loss_validation_scores = loss_validation_scores / clients_number
        loss_values = loss_values / clients_number
        print("F1 Score average for round {} = {}, Loss: {}".format(comm_round, loss_validation_scores, loss_values))
        models_CV.append(global_model)
        loss_validation_averages.append(loss_validation_scores)
        loss_values_averages.append(loss_values)
        if  len(loss_validation_averages) == 1:
            best_score = loss_validation_averages[0]
        #checks for early stopping according to f1 score and patience
        if len(loss_validation_averages) > 1:
            if loss_validation_averages[-1] >= best_score:
                rounds_worse_than_before += 1
            else:
                rounds_worse_than_before = 0
                best_score = loss_validation_averages[-1]
        if rounds_worse_than_before == patience:
            break

    if rounds_worse_than_before == patience:
        loss_validation_averages_all.append(loss_validation_averages[:-patience])
        loss_values_averages_all.append(loss_values_averages[:-patience])
        best_models.append(models_CV[:-patience])
        early_stopping_applied.append(True)
    else:
        loss_validation_averages_all.append(loss_validation_averages)
        loss_values_averages_all.append(loss_values_averages)
        best_models.append(models_CV) 
        early_stopping_applied.append(False)
    print("CV Round complete")
# Out:
# TRAIN: [    0     1     3 ... 19410 19411 19413] TEST: [    2     4    17 ... 19399 19400 19412]
# Loss:  tf.Tensor(0.9277446, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.93097466, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.92749935, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.9276747, shape=(), dtype=float32)
# F1 Score average for round 0 = 0.9284733533859253, Loss: 0.9284733533859253
# Loss:  tf.Tensor(0.7424565, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7422185, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7406343, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7472014, shape=(), dtype=float32)
# F1 Score average for round 1 = 0.743127703666687, Loss: 0.743127703666687
# Loss:  tf.Tensor(0.743791, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73889387, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.738814, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73472077, shape=(), dtype=float32)
# F1 Score average for round 2 = 0.7390549182891846, Loss: 0.7390549182891846
# Loss:  tf.Tensor(0.73444504, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7406295, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73980284, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7337407, shape=(), dtype=float32)
# F1 Score average for round 3 = 0.737154483795166, Loss: 0.737154483795166
# Loss:  tf.Tensor(0.7470624, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73956573, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7393672, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7430587, shape=(), dtype=float32)
# F1 Score average for round 4 = 0.7422634959220886, Loss: 0.7422634959220886
# Loss:  tf.Tensor(0.735602, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73652947, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73350734, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74210656, shape=(), dtype=float32)
# F1 Score average for round 5 = 0.7369363307952881, Loss: 0.7369363307952881
# Loss:  tf.Tensor(0.7390564, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7378956, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7352149, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7402314, shape=(), dtype=float32)
# F1 Score average for round 6 = 0.7380995750427246, Loss: 0.7380995750427246
# Loss:  tf.Tensor(0.73658764, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73639417, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7388085, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73430675, shape=(), dtype=float32)
# F1 Score average for round 7 = 0.7365242838859558, Loss: 0.7365242838859558
# Loss:  tf.Tensor(0.73774576, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7341306, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74360657, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7427106, shape=(), dtype=float32)
# F1 Score average for round 8 = 0.73954838514328, Loss: 0.73954838514328
# Loss:  tf.Tensor(0.7342794, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7470063, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7434407, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73754966, shape=(), dtype=float32)
# F1 Score average for round 9 = 0.740568995475769, Loss: 0.740568995475769
# Loss:  tf.Tensor(0.7398731, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7353755, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74081, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74200183, shape=(), dtype=float32)
# F1 Score average for round 10 = 0.7395150661468506, Loss: 0.7395150661468506
# Loss:  tf.Tensor(0.73998016, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74735445, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74059904, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7387592, shape=(), dtype=float32)
# F1 Score average for round 11 = 0.7416732311248779, Loss: 0.7416732311248779
# Loss:  tf.Tensor(0.7317028, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7434011, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7426666, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74189943, shape=(), dtype=float32)
# F1 Score average for round 12 = 0.739917516708374, Loss: 0.739917516708374
# Loss:  tf.Tensor(0.74757254, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74288964, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7326527, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.739536, shape=(), dtype=float32)
# F1 Score average for round 13 = 0.7406627535820007, Loss: 0.7406627535820007
# Loss:  tf.Tensor(0.7333587, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73868924, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7413125, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7473221, shape=(), dtype=float32)
# F1 Score average for round 14 = 0.7401705980300903, Loss: 0.7401705980300903
# Loss:  tf.Tensor(0.7395496, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73515236, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74624467, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74329, shape=(), dtype=float32)
# F1 Score average for round 15 = 0.7410591244697571, Loss: 0.7410591244697571
# Loss:  tf.Tensor(0.7432387, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73262167, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7390375, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7415274, shape=(), dtype=float32)
# F1 Score average for round 16 = 0.739106297492981, Loss: 0.739106297492981
# Loss:  tf.Tensor(0.7418142, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7361702, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7352074, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73463494, shape=(), dtype=float32)
# F1 Score average for round 17 = 0.7369566559791565, Loss: 0.7369566559791565
# Loss:  tf.Tensor(0.73918796, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7393006, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7464205, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7376394, shape=(), dtype=float32)
# F1 Score average for round 18 = 0.7406371235847473, Loss: 0.7406371235847473
# Loss:  tf.Tensor(0.7301787, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.742719, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7336681, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7350814, shape=(), dtype=float32)
# F1 Score average for round 19 = 0.7354118227958679, Loss: 0.7354118227958679
# Loss:  tf.Tensor(0.738676, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7342432, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7428414, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7454853, shape=(), dtype=float32)
# F1 Score average for round 20 = 0.7403115034103394, Loss: 0.7403115034103394
# Loss:  tf.Tensor(0.7421236, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7435343, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7383179, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74112076, shape=(), dtype=float32)
# F1 Score average for round 21 = 0.7412741780281067, Loss: 0.7412741780281067
# Loss:  tf.Tensor(0.7419331, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7403378, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7452353, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7407527, shape=(), dtype=float32)
# F1 Score average for round 22 = 0.7420647144317627, Loss: 0.7420647144317627
# Loss:  tf.Tensor(0.7395964, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7437325, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7499993, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74061775, shape=(), dtype=float32)
# F1 Score average for round 23 = 0.7434865236282349, Loss: 0.7434865236282349
# Loss:  tf.Tensor(0.7402821, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74288315, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74565434, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74474376, shape=(), dtype=float32)
# F1 Score average for round 24 = 0.7433908581733704, Loss: 0.7433908581733704
# Loss:  tf.Tensor(0.7418077, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7416627, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7409232, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7355769, shape=(), dtype=float32)
# F1 Score average for round 25 = 0.739992618560791, Loss: 0.739992618560791
# Loss:  tf.Tensor(0.74539435, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7456508, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74002975, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7464283, shape=(), dtype=float32)
# F1 Score average for round 26 = 0.7443758249282837, Loss: 0.7443758249282837
# Loss:  tf.Tensor(0.7446012, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7415516, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74281746, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7435676, shape=(), dtype=float32)
# F1 Score average for round 27 = 0.7431344985961914, Loss: 0.7431344985961914
# Loss:  tf.Tensor(0.74530953, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74597, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74012643, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74421775, shape=(), dtype=float32)
# F1 Score average for round 28 = 0.7439059019088745, Loss: 0.7439059019088745
# Loss:  tf.Tensor(0.7447912, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7408405, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7490188, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7419413, shape=(), dtype=float32)
# F1 Score average for round 29 = 0.7441479563713074, Loss: 0.7441479563713074
# Loss:  tf.Tensor(0.7385979, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7466375, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7425942, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73871833, shape=(), dtype=float32)
# F1 Score average for round 30 = 0.7416369915008545, Loss: 0.7416369915008545
# Loss:  tf.Tensor(0.7496204, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74554586, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7464871, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7472747, shape=(), dtype=float32)
# F1 Score average for round 31 = 0.7472320199012756, Loss: 0.7472320199012756
# Loss:  tf.Tensor(0.74623835, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7475679, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7345081, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.737748, shape=(), dtype=float32)
# F1 Score average for round 32 = 0.7415156364440918, Loss: 0.7415156364440918
# Loss:  tf.Tensor(0.74882036, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7419881, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7500044, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7463123, shape=(), dtype=float32)
# F1 Score average for round 33 = 0.7467812895774841, Loss: 0.7467812895774841
# Loss:  tf.Tensor(0.7479414, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7440949, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74652237, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74421024, shape=(), dtype=float32)
# F1 Score average for round 34 = 0.745692253112793, Loss: 0.745692253112793
# Loss:  tf.Tensor(0.7469207, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7413291, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7516091, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7494547, shape=(), dtype=float32)
# F1 Score average for round 35 = 0.7473284006118774, Loss: 0.7473284006118774
# Loss:  tf.Tensor(0.7442477, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7427353, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74870074, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7378048, shape=(), dtype=float32)
# F1 Score average for round 36 = 0.7433722019195557, Loss: 0.7433722019195557
# Loss:  tf.Tensor(0.7496356, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74695194, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7428264, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74824816, shape=(), dtype=float32)
# F1 Score average for round 37 = 0.7469155192375183, Loss: 0.7469155192375183
# Loss:  tf.Tensor(0.7394913, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7464478, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74376804, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7481814, shape=(), dtype=float32)
# F1 Score average for round 38 = 0.744472086429596, Loss: 0.744472086429596
# Loss:  tf.Tensor(0.7449756, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7407334, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75201964, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74312687, shape=(), dtype=float32)
# F1 Score average for round 39 = 0.7452138662338257, Loss: 0.7452138662338257
# Loss:  tf.Tensor(0.73595226, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74453884, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75262374, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74308693, shape=(), dtype=float32)
# F1 Score average for round 40 = 0.7440505027770996, Loss: 0.7440505027770996
# Loss:  tf.Tensor(0.744142, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74066544, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7422298, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7406475, shape=(), dtype=float32)
# F1 Score average for round 41 = 0.7419212460517883, Loss: 0.7419212460517883
# Loss:  tf.Tensor(0.7427882, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7468754, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7378579, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74854165, shape=(), dtype=float32)
# F1 Score average for round 42 = 0.7440157532691956, Loss: 0.7440157532691956
# Loss:  tf.Tensor(0.74965686, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74463797, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74238586, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7434495, shape=(), dtype=float32)
# F1 Score average for round 43 = 0.745032548904419, Loss: 0.745032548904419
# Loss:  tf.Tensor(0.74980086, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7485669, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74125475, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7426151, shape=(), dtype=float32)
# F1 Score average for round 44 = 0.7455594539642334, Loss: 0.7455594539642334
# Loss:  tf.Tensor(0.7472175, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7409871, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75122523, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74462587, shape=(), dtype=float32)
# F1 Score average for round 45 = 0.7460139393806458, Loss: 0.7460139393806458
# Loss:  tf.Tensor(0.7503763, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7443253, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7462535, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7414051, shape=(), dtype=float32)
# F1 Score average for round 46 = 0.745590090751648, Loss: 0.745590090751648
# Loss:  tf.Tensor(0.74092185, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74755466, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7404799, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7461029, shape=(), dtype=float32)
# F1 Score average for round 47 = 0.7437648773193359, Loss: 0.7437648773193359
# Loss:  tf.Tensor(0.7390601, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7419811, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74219286, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7461912, shape=(), dtype=float32)
# F1 Score average for round 48 = 0.7423563599586487, Loss: 0.7423563599586487
# Loss:  tf.Tensor(0.7488789, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7436213, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74554896, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74260616, shape=(), dtype=float32)
# F1 Score average for round 49 = 0.7451637983322144, Loss: 0.7451637983322144
# Loss:  tf.Tensor(0.7436988, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74630964, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7444253, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74819374, shape=(), dtype=float32)
# F1 Score average for round 50 = 0.7456568479537964, Loss: 0.7456568479537964
# Loss:  tf.Tensor(0.744762, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7516298, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74392855, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7397208, shape=(), dtype=float32)
# F1 Score average for round 51 = 0.745010256767273, Loss: 0.745010256767273
# Loss:  tf.Tensor(0.7492897, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7424589, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7418235, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7368195, shape=(), dtype=float32)
# F1 Score average for round 52 = 0.7425978779792786, Loss: 0.7425978779792786
# Loss:  tf.Tensor(0.74854606, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7442445, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7517133, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7298387, shape=(), dtype=float32)
# F1 Score average for round 53 = 0.7435857057571411, Loss: 0.7435857057571411
# Loss:  tf.Tensor(0.7474859, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7435397, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7424403, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7451638, shape=(), dtype=float32)
# F1 Score average for round 54 = 0.7446573972702026, Loss: 0.7446573972702026
# Loss:  tf.Tensor(0.741164, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7521089, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74005145, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74033463, shape=(), dtype=float32)
# F1 Score average for round 55 = 0.7434147596359253, Loss: 0.7434147596359253
# Loss:  tf.Tensor(0.74438757, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7441761, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73852646, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7444601, shape=(), dtype=float32)
# F1 Score average for round 56 = 0.742887556552887, Loss: 0.742887556552887
# Loss:  tf.Tensor(0.7491534, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7440168, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7360473, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73908937, shape=(), dtype=float32)
# F1 Score average for round 57 = 0.7420767545700073, Loss: 0.7420767545700073
# Loss:  tf.Tensor(0.7451168, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7368738, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74758625, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7444455, shape=(), dtype=float32)
# F1 Score average for round 58 = 0.743505597114563, Loss: 0.743505597114563
# Loss:  tf.Tensor(0.7384887, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7443411, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7406825, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73874253, shape=(), dtype=float32)
# F1 Score average for round 59 = 0.740563690662384, Loss: 0.740563690662384
# CV Round complete
# TRAIN: [    1     2     4 ... 19410 19412 19413] TEST: [    0     3    15 ... 19405 19408 19411]
# Loss:  tf.Tensor(0.92387724, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.92692953, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.92342854, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.9290025, shape=(), dtype=float32)
# F1 Score average for round 0 = 0.9258094429969788, Loss: 0.9258094429969788
# Loss:  tf.Tensor(0.75691175, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7565301, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7586946, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75891083, shape=(), dtype=float32)
# F1 Score average for round 1 = 0.7577618360519409, Loss: 0.7577618360519409
# Loss:  tf.Tensor(0.73874813, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7371252, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73703295, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7313404, shape=(), dtype=float32)
# F1 Score average for round 2 = 0.736061692237854, Loss: 0.736061692237854
# Loss:  tf.Tensor(0.7404002, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73155856, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74395245, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7336957, shape=(), dtype=float32)
# F1 Score average for round 3 = 0.7374017238616943, Loss: 0.7374017238616943
# Loss:  tf.Tensor(0.73692495, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7399844, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7323107, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73115855, shape=(), dtype=float32)
# F1 Score average for round 4 = 0.7350946664810181, Loss: 0.7350946664810181
# Loss:  tf.Tensor(0.7308621, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.72811407, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7300231, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7352263, shape=(), dtype=float32)
# F1 Score average for round 5 = 0.7310563325881958, Loss: 0.7310563325881958
# Loss:  tf.Tensor(0.7315131, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73749197, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7456259, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7284061, shape=(), dtype=float32)
# F1 Score average for round 6 = 0.7357592582702637, Loss: 0.7357592582702637
# Loss:  tf.Tensor(0.74522567, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74044496, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.733663, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73882765, shape=(), dtype=float32)
# F1 Score average for round 7 = 0.7395403385162354, Loss: 0.7395403385162354
# Loss:  tf.Tensor(0.74178374, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73793036, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7338621, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7389341, shape=(), dtype=float32)
# F1 Score average for round 8 = 0.738127589225769, Loss: 0.738127589225769
# Loss:  tf.Tensor(0.7374002, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7384778, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74388665, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7351409, shape=(), dtype=float32)
# F1 Score average for round 9 = 0.7387263774871826, Loss: 0.7387263774871826
# Loss:  tf.Tensor(0.73716366, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74256545, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7374175, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74263525, shape=(), dtype=float32)
# F1 Score average for round 10 = 0.7399454712867737, Loss: 0.7399454712867737
# Loss:  tf.Tensor(0.74439335, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7376566, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73883384, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7422688, shape=(), dtype=float32)
# F1 Score average for round 11 = 0.7407881617546082, Loss: 0.7407881617546082
# Loss:  tf.Tensor(0.74322957, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73836595, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7371879, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74074036, shape=(), dtype=float32)
# F1 Score average for round 12 = 0.7398809194564819, Loss: 0.7398809194564819
# Loss:  tf.Tensor(0.73952514, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73893744, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73995817, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73488885, shape=(), dtype=float32)
# F1 Score average for round 13 = 0.7383273839950562, Loss: 0.7383273839950562
# Loss:  tf.Tensor(0.7407283, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74248743, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74356073, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7409253, shape=(), dtype=float32)
# F1 Score average for round 14 = 0.7419254779815674, Loss: 0.7419254779815674
# Loss:  tf.Tensor(0.7424654, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74321437, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7429648, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73495466, shape=(), dtype=float32)
# F1 Score average for round 15 = 0.7408998012542725, Loss: 0.7408998012542725
# Loss:  tf.Tensor(0.7441048, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7455962, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7427634, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7310984, shape=(), dtype=float32)
# F1 Score average for round 16 = 0.7408906817436218, Loss: 0.7408906817436218
# Loss:  tf.Tensor(0.73696464, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74566543, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7397306, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.736239, shape=(), dtype=float32)
# F1 Score average for round 17 = 0.7396498918533325, Loss: 0.7396498918533325
# Loss:  tf.Tensor(0.73691064, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74975616, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7391399, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7342914, shape=(), dtype=float32)
# F1 Score average for round 18 = 0.7400245070457458, Loss: 0.7400245070457458
# Loss:  tf.Tensor(0.7421505, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7451345, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7422533, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74732035, shape=(), dtype=float32)
# F1 Score average for round 19 = 0.744214653968811, Loss: 0.744214653968811
# Loss:  tf.Tensor(0.7450044, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7395409, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7381474, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7391555, shape=(), dtype=float32)
# F1 Score average for round 20 = 0.7404620051383972, Loss: 0.7404620051383972
# Loss:  tf.Tensor(0.7419475, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73767173, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7381578, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75334823, shape=(), dtype=float32)
# F1 Score average for round 21 = 0.7427812814712524, Loss: 0.7427812814712524
# Loss:  tf.Tensor(0.7493722, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74268633, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7408081, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74019957, shape=(), dtype=float32)
# F1 Score average for round 22 = 0.7432665824890137, Loss: 0.7432665824890137
# Loss:  tf.Tensor(0.7437358, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.742912, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73813313, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74943066, shape=(), dtype=float32)
# F1 Score average for round 23 = 0.7435529232025146, Loss: 0.7435529232025146
# Loss:  tf.Tensor(0.74682033, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7416438, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7420613, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7415872, shape=(), dtype=float32)
# F1 Score average for round 24 = 0.7430281639099121, Loss: 0.7430281639099121
# Loss:  tf.Tensor(0.751107, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74255174, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73816925, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7410087, shape=(), dtype=float32)
# F1 Score average for round 25 = 0.743209183216095, Loss: 0.743209183216095
# Loss:  tf.Tensor(0.7440873, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74714506, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74463534, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74656457, shape=(), dtype=float32)
# F1 Score average for round 26 = 0.7456080913543701, Loss: 0.7456080913543701
# Loss:  tf.Tensor(0.7447438, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7508783, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73553133, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74467295, shape=(), dtype=float32)
# F1 Score average for round 27 = 0.7439566254615784, Loss: 0.7439566254615784
# Loss:  tf.Tensor(0.7487269, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7446468, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74441403, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75080097, shape=(), dtype=float32)
# F1 Score average for round 28 = 0.7471472024917603, Loss: 0.7471472024917603
# Loss:  tf.Tensor(0.74610174, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74310726, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.745664, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7509817, shape=(), dtype=float32)
# F1 Score average for round 29 = 0.7464636564254761, Loss: 0.7464636564254761
# Loss:  tf.Tensor(0.7455554, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.749211, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7537951, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74386936, shape=(), dtype=float32)
# F1 Score average for round 30 = 0.7481077313423157, Loss: 0.7481077313423157
# Loss:  tf.Tensor(0.7400261, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7425968, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7495997, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74379134, shape=(), dtype=float32)
# F1 Score average for round 31 = 0.7440034747123718, Loss: 0.7440034747123718
# Loss:  tf.Tensor(0.74983853, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.742984, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74482286, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7524953, shape=(), dtype=float32)
# F1 Score average for round 32 = 0.7475351691246033, Loss: 0.7475351691246033
# Loss:  tf.Tensor(0.7466953, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7431271, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74137044, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7482126, shape=(), dtype=float32)
# F1 Score average for round 33 = 0.7448513507843018, Loss: 0.7448513507843018
# Loss:  tf.Tensor(0.749635, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74842316, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74100536, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.746828, shape=(), dtype=float32)
# F1 Score average for round 34 = 0.7464728951454163, Loss: 0.7464728951454163
# Loss:  tf.Tensor(0.7444521, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74247223, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74520195, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74592936, shape=(), dtype=float32)
# F1 Score average for round 35 = 0.7445138692855835, Loss: 0.7445138692855835
# Loss:  tf.Tensor(0.7410931, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74216044, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.740707, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75012803, shape=(), dtype=float32)
# F1 Score average for round 36 = 0.7435221076011658, Loss: 0.7435221076011658
# Loss:  tf.Tensor(0.7411484, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7520741, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73932815, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7480621, shape=(), dtype=float32)
# F1 Score average for round 37 = 0.7451531887054443, Loss: 0.7451531887054443
# Loss:  tf.Tensor(0.7438851, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74921244, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75057226, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.741207, shape=(), dtype=float32)
# F1 Score average for round 38 = 0.7462191581726074, Loss: 0.7462191581726074
# Loss:  tf.Tensor(0.74618155, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7373499, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75032204, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74299186, shape=(), dtype=float32)
# F1 Score average for round 39 = 0.7442113757133484, Loss: 0.7442113757133484
# Loss:  tf.Tensor(0.7479358, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7395298, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75038415, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74245936, shape=(), dtype=float32)
# F1 Score average for round 40 = 0.7450772523880005, Loss: 0.7450772523880005
# Loss:  tf.Tensor(0.7504687, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7428853, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75134075, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73931664, shape=(), dtype=float32)
# F1 Score average for round 41 = 0.7460028529167175, Loss: 0.7460028529167175
# Loss:  tf.Tensor(0.7424602, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7421087, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7468715, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7529788, shape=(), dtype=float32)
# F1 Score average for round 42 = 0.7461047768592834, Loss: 0.7461047768592834
# Loss:  tf.Tensor(0.74223024, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7420191, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7460306, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75158525, shape=(), dtype=float32)
# F1 Score average for round 43 = 0.7454662919044495, Loss: 0.7454662919044495
# Loss:  tf.Tensor(0.7425515, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7444374, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7521436, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73971707, shape=(), dtype=float32)
# F1 Score average for round 44 = 0.7447123527526855, Loss: 0.7447123527526855
# Loss:  tf.Tensor(0.75281656, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74879116, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7341756, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7434368, shape=(), dtype=float32)
# F1 Score average for round 45 = 0.7448050379753113, Loss: 0.7448050379753113
# CV Round complete
# TRAIN: [    0     1     2 ... 19411 19412 19413] TEST: [    6     7     8 ... 19391 19398 19401]
# Loss:  tf.Tensor(0.92766327, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.9232517, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.9234471, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.9265383, shape=(), dtype=float32)
# F1 Score average for round 0 = 0.9252250790596008, Loss: 0.9252250790596008
# Loss:  tf.Tensor(0.7570098, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75882846, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7625722, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.76138103, shape=(), dtype=float32)
# F1 Score average for round 1 = 0.7599478960037231, Loss: 0.7599478960037231
# Loss:  tf.Tensor(0.74387974, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7524524, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.76148087, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7483867, shape=(), dtype=float32)
# F1 Score average for round 2 = 0.7515498995780945, Loss: 0.7515498995780945
# Loss:  tf.Tensor(0.73885053, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7445616, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7546528, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7455353, shape=(), dtype=float32)
# F1 Score average for round 3 = 0.7459000945091248, Loss: 0.7459000945091248
# Loss:  tf.Tensor(0.7330538, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7453339, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7413871, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73528534, shape=(), dtype=float32)
# F1 Score average for round 4 = 0.7387650012969971, Loss: 0.7387650012969971
# Loss:  tf.Tensor(0.72998655, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73342574, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73100275, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7436196, shape=(), dtype=float32)
# F1 Score average for round 5 = 0.7345086932182312, Loss: 0.7345086932182312
# Loss:  tf.Tensor(0.74058104, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73935664, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74458, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75094754, shape=(), dtype=float32)
# F1 Score average for round 6 = 0.7438662648200989, Loss: 0.7438662648200989
# Loss:  tf.Tensor(0.7311613, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7387977, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7393617, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73827016, shape=(), dtype=float32)
# F1 Score average for round 7 = 0.7368977069854736, Loss: 0.7368977069854736
# Loss:  tf.Tensor(0.73901707, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7347575, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7334044, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7453409, shape=(), dtype=float32)
# F1 Score average for round 8 = 0.7381299734115601, Loss: 0.7381299734115601
# Loss:  tf.Tensor(0.73766583, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74619156, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73580986, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7395863, shape=(), dtype=float32)
# F1 Score average for round 9 = 0.7398133873939514, Loss: 0.7398133873939514
# Loss:  tf.Tensor(0.7478963, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73699194, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7377652, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74017483, shape=(), dtype=float32)
# F1 Score average for round 10 = 0.7407070398330688, Loss: 0.7407070398330688
# Loss:  tf.Tensor(0.74241924, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7527522, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74151987, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7342939, shape=(), dtype=float32)
# F1 Score average for round 11 = 0.7427462935447693, Loss: 0.7427462935447693
# Loss:  tf.Tensor(0.74062586, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7337635, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7503981, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7377865, shape=(), dtype=float32)
# F1 Score average for round 12 = 0.7406435012817383, Loss: 0.7406435012817383
# Loss:  tf.Tensor(0.7331042, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7443109, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73975664, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7521782, shape=(), dtype=float32)
# F1 Score average for round 13 = 0.7423374652862549, Loss: 0.7423374652862549
# Loss:  tf.Tensor(0.7417493, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7485215, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73582417, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.72827876, shape=(), dtype=float32)
# F1 Score average for round 14 = 0.7385934591293335, Loss: 0.7385934591293335
# Loss:  tf.Tensor(0.7449938, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7408448, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75511754, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7390317, shape=(), dtype=float32)
# F1 Score average for round 15 = 0.7449970245361328, Loss: 0.7449970245361328
# Loss:  tf.Tensor(0.7518164, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7381554, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73913753, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7392386, shape=(), dtype=float32)
# F1 Score average for round 16 = 0.7420870065689087, Loss: 0.7420870065689087
# Loss:  tf.Tensor(0.73465264, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7470476, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7387057, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73727995, shape=(), dtype=float32)
# F1 Score average for round 17 = 0.7394214272499084, Loss: 0.7394214272499084
# Loss:  tf.Tensor(0.74306756, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75288594, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74161375, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74185485, shape=(), dtype=float32)
# F1 Score average for round 18 = 0.7448555827140808, Loss: 0.7448555827140808
# Loss:  tf.Tensor(0.7455398, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7525918, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7398267, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7365864, shape=(), dtype=float32)
# F1 Score average for round 19 = 0.7436361312866211, Loss: 0.7436361312866211
# Loss:  tf.Tensor(0.74365824, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7406859, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7508136, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7412053, shape=(), dtype=float32)
# F1 Score average for round 20 = 0.744090735912323, Loss: 0.744090735912323
# Loss:  tf.Tensor(0.7503369, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7479607, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7488714, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7343967, shape=(), dtype=float32)
# F1 Score average for round 21 = 0.7453914284706116, Loss: 0.7453914284706116
# Loss:  tf.Tensor(0.7338925, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7468416, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74785733, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7348198, shape=(), dtype=float32)
# F1 Score average for round 22 = 0.7408528327941895, Loss: 0.7408528327941895
# Loss:  tf.Tensor(0.75434786, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74055713, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7372764, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7401804, shape=(), dtype=float32)
# F1 Score average for round 23 = 0.7430903911590576, Loss: 0.7430903911590576
# Loss:  tf.Tensor(0.73512644, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74047875, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7394333, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7581147, shape=(), dtype=float32)
# F1 Score average for round 24 = 0.7432882785797119, Loss: 0.7432882785797119
# Loss:  tf.Tensor(0.73478115, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74128217, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73811376, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7518996, shape=(), dtype=float32)
# F1 Score average for round 25 = 0.7415192127227783, Loss: 0.7415192127227783
# Loss:  tf.Tensor(0.7403811, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75210536, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7476873, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7330323, shape=(), dtype=float32)
# F1 Score average for round 26 = 0.743301510810852, Loss: 0.743301510810852
# Loss:  tf.Tensor(0.7401104, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74249077, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75857943, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7381828, shape=(), dtype=float32)
# F1 Score average for round 27 = 0.7448408603668213, Loss: 0.7448408603668213
# Loss:  tf.Tensor(0.7360546, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75694686, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7467981, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7428467, shape=(), dtype=float32)
# F1 Score average for round 28 = 0.7456615567207336, Loss: 0.7456615567207336
# Loss:  tf.Tensor(0.7345205, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7639192, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.746143, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7434123, shape=(), dtype=float32)
# F1 Score average for round 29 = 0.7469987273216248, Loss: 0.7469987273216248
# Loss:  tf.Tensor(0.7462816, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74206704, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75532794, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.742609, shape=(), dtype=float32)
# F1 Score average for round 30 = 0.74657142162323, Loss: 0.74657142162323
# Loss:  tf.Tensor(0.7472091, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7353428, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74897283, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74256325, shape=(), dtype=float32)
# F1 Score average for round 31 = 0.7435219883918762, Loss: 0.7435219883918762
# Loss:  tf.Tensor(0.7427864, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7575187, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7370423, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.735373, shape=(), dtype=float32)
# F1 Score average for round 32 = 0.7431801557540894, Loss: 0.7431801557540894
# Loss:  tf.Tensor(0.74297553, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74622464, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7539772, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7401463, shape=(), dtype=float32)
# F1 Score average for round 33 = 0.7458308935165405, Loss: 0.7458308935165405
# Loss:  tf.Tensor(0.73690164, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7583694, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7388283, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.744351, shape=(), dtype=float32)
# F1 Score average for round 34 = 0.7446125745773315, Loss: 0.7446125745773315
# Loss:  tf.Tensor(0.73748887, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7421442, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75519496, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7394661, shape=(), dtype=float32)
# F1 Score average for round 35 = 0.7435735464096069, Loss: 0.7435735464096069
# Loss:  tf.Tensor(0.74086004, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7374156, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7426842, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75483996, shape=(), dtype=float32)
# F1 Score average for round 36 = 0.7439499497413635, Loss: 0.7439499497413635
# Loss:  tf.Tensor(0.7569541, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74145055, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7488637, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73761916, shape=(), dtype=float32)
# F1 Score average for round 37 = 0.7462218403816223, Loss: 0.7462218403816223
# Loss:  tf.Tensor(0.75339174, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7417771, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7356458, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7467791, shape=(), dtype=float32)
# F1 Score average for round 38 = 0.7443984746932983, Loss: 0.7443984746932983
# Loss:  tf.Tensor(0.74161774, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74104655, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74170256, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7566543, shape=(), dtype=float32)
# F1 Score average for round 39 = 0.7452552914619446, Loss: 0.7452552914619446
# Loss:  tf.Tensor(0.73655033, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7401909, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75158906, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7381368, shape=(), dtype=float32)
# F1 Score average for round 40 = 0.7416167855262756, Loss: 0.7416167855262756
# Loss:  tf.Tensor(0.7387036, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7401234, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.741466, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.746377, shape=(), dtype=float32)
# F1 Score average for round 41 = 0.7416675090789795, Loss: 0.7416675090789795
# Loss:  tf.Tensor(0.73517174, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.758416, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74724966, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73350227, shape=(), dtype=float32)
# F1 Score average for round 42 = 0.7435848712921143, Loss: 0.7435848712921143
# Loss:  tf.Tensor(0.74384725, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7481908, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7385372, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7484335, shape=(), dtype=float32)
# F1 Score average for round 43 = 0.7447521686553955, Loss: 0.7447521686553955
# Loss:  tf.Tensor(0.7419898, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7363784, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7454565, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7515136, shape=(), dtype=float32)
# F1 Score average for round 44 = 0.7438346147537231, Loss: 0.7438346147537231
# Loss:  tf.Tensor(0.75608075, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74222, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7474784, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73762244, shape=(), dtype=float32)
# F1 Score average for round 45 = 0.7458504438400269, Loss: 0.7458504438400269
# CV Round complete
# TRAIN: [    0     1     2 ... 19411 19412 19413] TEST: [   37    40    52 ... 19407 19409 19410]
# Loss:  tf.Tensor(0.9306738, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.92585194, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.92961013, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.92970467, shape=(), dtype=float32)
# F1 Score average for round 0 = 0.9289600849151611, Loss: 0.9289600849151611
# Loss:  tf.Tensor(0.75795454, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75669754, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7566025, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7580027, shape=(), dtype=float32)
# F1 Score average for round 1 = 0.7573143243789673, Loss: 0.7573143243789673
# Loss:  tf.Tensor(0.73734874, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7447267, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7337439, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73994386, shape=(), dtype=float32)
# F1 Score average for round 2 = 0.7389408349990845, Loss: 0.7389408349990845
# Loss:  tf.Tensor(0.7365887, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74647975, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73439646, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74075216, shape=(), dtype=float32)
# F1 Score average for round 3 = 0.7395542860031128, Loss: 0.7395542860031128
# Loss:  tf.Tensor(0.7370679, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73487467, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7314149, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7450527, shape=(), dtype=float32)
# F1 Score average for round 4 = 0.7371025085449219, Loss: 0.7371025085449219
# Loss:  tf.Tensor(0.7351366, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7383258, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73072445, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7379439, shape=(), dtype=float32)
# F1 Score average for round 5 = 0.7355327010154724, Loss: 0.7355327010154724
# Loss:  tf.Tensor(0.74636567, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73244905, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7334802, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7416972, shape=(), dtype=float32)
# F1 Score average for round 6 = 0.7384980916976929, Loss: 0.7384980916976929
# Loss:  tf.Tensor(0.7489677, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73945445, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73088294, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7372971, shape=(), dtype=float32)
# F1 Score average for round 7 = 0.7391505241394043, Loss: 0.7391505241394043
# Loss:  tf.Tensor(0.7380018, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7349405, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.72905797, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.72873765, shape=(), dtype=float32)
# F1 Score average for round 8 = 0.7326844930648804, Loss: 0.7326844930648804
# Loss:  tf.Tensor(0.7437234, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7383377, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73980963, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.72902036, shape=(), dtype=float32)
# F1 Score average for round 9 = 0.7377228140830994, Loss: 0.7377228140830994
# Loss:  tf.Tensor(0.7338245, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7484696, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73033357, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7350332, shape=(), dtype=float32)
# F1 Score average for round 10 = 0.7369152307510376, Loss: 0.7369152307510376
# Loss:  tf.Tensor(0.74197817, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75276625, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7306629, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7408572, shape=(), dtype=float32)
# F1 Score average for round 11 = 0.7415661215782166, Loss: 0.7415661215782166
# ...
# Loss:  tf.Tensor(0.7391295, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74509585, shape=(), dtype=float32)
# F1 Score average for round 39 = 0.7469698190689087, Loss: 0.7469698190689087
# Loss:  tf.Tensor(0.74769974, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7358209, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7406535, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7442015, shape=(), dtype=float32)
# F1 Score average for round 40 = 0.7420938611030579, Loss: 0.7420938611030579
# Loss:  tf.Tensor(0.75092036, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7390954, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74388057, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7413675, shape=(), dtype=float32)
# F1 Score average for round 41 = 0.7438159584999084, Loss: 0.7438159584999084
# Loss:  tf.Tensor(0.74280643, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7425798, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75088066, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73588866, shape=(), dtype=float32)
# F1 Score average for round 42 = 0.7430388927459717, Loss: 0.7430388927459717
# Loss:  tf.Tensor(0.7425746, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7511134, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7388712, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7507348, shape=(), dtype=float32)
# F1 Score average for round 43 = 0.7458235025405884, Loss: 0.7458235025405884
# Loss:  tf.Tensor(0.7426557, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7519294, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7454223, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74462044, shape=(), dtype=float32)
# F1 Score average for round 44 = 0.7461569309234619, Loss: 0.7461569309234619
# Loss:  tf.Tensor(0.7568802, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.752651, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74244016, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74485177, shape=(), dtype=float32)
# F1 Score average for round 45 = 0.7492058277130127, Loss: 0.7492058277130127
# Loss:  tf.Tensor(0.74999225, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7419594, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7426081, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74469805, shape=(), dtype=float32)
# F1 Score average for round 46 = 0.7448144555091858, Loss: 0.7448144555091858
# Loss:  tf.Tensor(0.74374515, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74545896, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7425823, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7467649, shape=(), dtype=float32)
# F1 Score average for round 47 = 0.7446378469467163, Loss: 0.7446378469467163
# Loss:  tf.Tensor(0.7412418, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74709845, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7571811, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73240894, shape=(), dtype=float32)
# F1 Score average for round 48 = 0.7444825768470764, Loss: 0.7444825768470764
# CV Round complete
# TRAIN: [    0     2     3 ... 19410 19411 19412] TEST: [    1     5    11 ... 19404 19406 19413]
# Loss:  tf.Tensor(0.91642505, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.9207303, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.91900915, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.92047703, shape=(), dtype=float32)
# F1 Score average for round 0 = 0.9191603660583496, Loss: 0.9191603660583496
# Loss:  tf.Tensor(0.7544291, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75196433, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75563323, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75126404, shape=(), dtype=float32)
# F1 Score average for round 1 = 0.7533227205276489, Loss: 0.7533227205276489
# Loss:  tf.Tensor(0.7423427, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7369391, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7359995, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7427598, shape=(), dtype=float32)
# F1 Score average for round 2 = 0.7395102977752686, Loss: 0.7395102977752686
# Loss:  tf.Tensor(0.73764724, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73248917, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73245305, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74269474, shape=(), dtype=float32)
# F1 Score average for round 3 = 0.7363210916519165, Loss: 0.7363210916519165
# Loss:  tf.Tensor(0.73218316, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73885924, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7396213, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.730994, shape=(), dtype=float32)
# F1 Score average for round 4 = 0.735414445400238, Loss: 0.735414445400238
# Loss:  tf.Tensor(0.73174465, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7401887, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73398435, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74346864, shape=(), dtype=float32)
# F1 Score average for round 5 = 0.7373466491699219, Loss: 0.7373466491699219
# Loss:  tf.Tensor(0.7372921, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7449855, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7363242, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.730735, shape=(), dtype=float32)
# F1 Score average for round 6 = 0.7373341917991638, Loss: 0.7373341917991638
# Loss:  tf.Tensor(0.7385305, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7475356, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7430433, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7380698, shape=(), dtype=float32)
# F1 Score average for round 7 = 0.741794764995575, Loss: 0.741794764995575
# Loss:  tf.Tensor(0.73488885, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7384786, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7427244, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74165386, shape=(), dtype=float32)
# F1 Score average for round 8 = 0.7394364476203918, Loss: 0.7394364476203918
# Loss:  tf.Tensor(0.7380284, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7324019, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74708056, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74985623, shape=(), dtype=float32)
# F1 Score average for round 9 = 0.7418417930603027, Loss: 0.7418417930603027
# Loss:  tf.Tensor(0.7338028, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7435088, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7460312, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7408402, shape=(), dtype=float32)
# F1 Score average for round 10 = 0.7410457730293274, Loss: 0.7410457730293274
# Loss:  tf.Tensor(0.73813176, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7394986, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7422943, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74611163, shape=(), dtype=float32)
# F1 Score average for round 11 = 0.7415090799331665, Loss: 0.7415090799331665
# Loss:  tf.Tensor(0.73399407, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7480169, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7377219, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7363243, shape=(), dtype=float32)
# F1 Score average for round 12 = 0.7390142679214478, Loss: 0.7390142679214478
# Loss:  tf.Tensor(0.74915105, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7496839, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7418228, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73989767, shape=(), dtype=float32)
# F1 Score average for round 13 = 0.7451388835906982, Loss: 0.7451388835906982
# Loss:  tf.Tensor(0.7394693, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7434789, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74347824, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7514789, shape=(), dtype=float32)
# F1 Score average for round 14 = 0.744476318359375, Loss: 0.744476318359375
# Loss:  tf.Tensor(0.73605347, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73962945, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7483782, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7490527, shape=(), dtype=float32)
# F1 Score average for round 15 = 0.7432785034179688, Loss: 0.7432785034179688
# Loss:  tf.Tensor(0.74222755, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74807346, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.752421, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7408962, shape=(), dtype=float32)
# F1 Score average for round 16 = 0.7459045648574829, Loss: 0.7459045648574829
# Loss:  tf.Tensor(0.7428503, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7450101, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74399686, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74446553, shape=(), dtype=float32)
# F1 Score average for round 17 = 0.7440807223320007, Loss: 0.7440807223320007
# Loss:  tf.Tensor(0.7475029, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7403416, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74964696, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7525569, shape=(), dtype=float32)
# F1 Score average for round 18 = 0.7475121021270752, Loss: 0.7475121021270752
# Loss:  tf.Tensor(0.74524194, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7562169, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.744573, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7404699, shape=(), dtype=float32)
# F1 Score average for round 19 = 0.7466254234313965, Loss: 0.7466254234313965
# Loss:  tf.Tensor(0.74960035, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7455862, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7360089, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7387037, shape=(), dtype=float32)
# F1 Score average for round 20 = 0.7424747943878174, Loss: 0.7424747943878174
# Loss:  tf.Tensor(0.7550996, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74681216, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7569526, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74288964, shape=(), dtype=float32)
# F1 Score average for round 21 = 0.7504385113716125, Loss: 0.7504385113716125
# Loss:  tf.Tensor(0.7520442, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.744336, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7391072, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7406234, shape=(), dtype=float32)
# F1 Score average for round 22 = 0.7440277338027954, Loss: 0.7440277338027954
# Loss:  tf.Tensor(0.74077284, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7430922, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7503882, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75598294, shape=(), dtype=float32)
# F1 Score average for round 23 = 0.7475590109825134, Loss: 0.7475590109825134
# Loss:  tf.Tensor(0.7460134, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7585697, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7397454, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73652565, shape=(), dtype=float32)
# F1 Score average for round 24 = 0.745213508605957, Loss: 0.745213508605957
# Loss:  tf.Tensor(0.7429575, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75567186, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73992336, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75434965, shape=(), dtype=float32)
# F1 Score average for round 25 = 0.7482255697250366, Loss: 0.7482255697250366
# Loss:  tf.Tensor(0.75363415, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74305296, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.744057, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74467885, shape=(), dtype=float32)
# F1 Score average for round 26 = 0.7463557720184326, Loss: 0.7463557720184326
# Loss:  tf.Tensor(0.7407377, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7389585, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7415659, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75104684, shape=(), dtype=float32)
# F1 Score average for round 27 = 0.7430772185325623, Loss: 0.7430772185325623
# Loss:  tf.Tensor(0.75427526, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7421764, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7410311, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.747891, shape=(), dtype=float32)
# F1 Score average for round 28 = 0.7463434338569641, Loss: 0.7463434338569641
# Loss:  tf.Tensor(0.75588065, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.737941, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7516559, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7449762, shape=(), dtype=float32)
# F1 Score average for round 29 = 0.7476134300231934, Loss: 0.7476134300231934
# Loss:  tf.Tensor(0.7345408, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7558162, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73995787, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7587242, shape=(), dtype=float32)
# F1 Score average for round 30 = 0.747259795665741, Loss: 0.747259795665741
# Loss:  tf.Tensor(0.74528277, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7377299, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74873495, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75185776, shape=(), dtype=float32)
# F1 Score average for round 31 = 0.745901346206665, Loss: 0.745901346206665
# Loss:  tf.Tensor(0.7565238, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74024665, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74921936, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73816, shape=(), dtype=float32)
# F1 Score average for round 32 = 0.746037483215332, Loss: 0.746037483215332
# Loss:  tf.Tensor(0.75287783, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73495626, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7396296, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7565845, shape=(), dtype=float32)
# F1 Score average for round 33 = 0.7460120916366577, Loss: 0.7460120916366577
# Loss:  tf.Tensor(0.74736196, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75143516, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73845255, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74532557, shape=(), dtype=float32)
# F1 Score average for round 34 = 0.7456438541412354, Loss: 0.7456438541412354
# Loss:  tf.Tensor(0.75987476, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75717056, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74881166, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73853505, shape=(), dtype=float32)
# F1 Score average for round 35 = 0.7510980367660522, Loss: 0.7510980367660522
# Loss:  tf.Tensor(0.7485284, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74537486, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7413055, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7499953, shape=(), dtype=float32)
# F1 Score average for round 36 = 0.746300995349884, Loss: 0.746300995349884
# Loss:  tf.Tensor(0.7496109, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74758625, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7529685, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7438737, shape=(), dtype=float32)
# F1 Score average for round 37 = 0.7485098838806152, Loss: 0.7485098838806152
# Loss:  tf.Tensor(0.7324344, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75092477, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74386716, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7598613, shape=(), dtype=float32)
# F1 Score average for round 38 = 0.7467718720436096, Loss: 0.7467718720436096
# Loss:  tf.Tensor(0.74102765, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7550538, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7491264, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73649716, shape=(), dtype=float32)
# F1 Score average for round 39 = 0.7454262375831604, Loss: 0.7454262375831604
# Loss:  tf.Tensor(0.7426311, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75779974, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7485027, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7355371, shape=(), dtype=float32)
# F1 Score average for round 40 = 0.7461176514625549, Loss: 0.7461176514625549
# Loss:  tf.Tensor(0.75209, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7455746, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7403962, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75279003, shape=(), dtype=float32)
# F1 Score average for round 41 = 0.7477126717567444, Loss: 0.7477126717567444
# Loss:  tf.Tensor(0.7499604, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74071735, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.740032, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75082105, shape=(), dtype=float32)
# F1 Score average for round 42 = 0.7453827261924744, Loss: 0.7453827261924744
# Loss:  tf.Tensor(0.7438033, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73974603, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7451831, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7522514, shape=(), dtype=float32)
# F1 Score average for round 43 = 0.7452459931373596, Loss: 0.7452459931373596
# Loss:  tf.Tensor(0.75222754, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7588211, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73747665, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7392521, shape=(), dtype=float32)
# F1 Score average for round 44 = 0.7469443678855896, Loss: 0.7469443678855896
# CV Round complete

# %% [markdown]
# # Results for Early Stopping when monitoring the average F1 Score value of all the clients using their own validation data

# %%
plt.subplot(2,1,1)
for i in range(len(loss_values_averages_all)):
    plt.plot(loss_values_averages_all[i])
plt.title('models\' loss')
plt.ylabel('loss')
plt.xlabel('Communication rounds')
plt.legend(['fold1', 'fold2','fold3', 'fold4', 'fold5'], loc='lower right')
plt.savefig("Model's Validation loss vs Communication Rounds - First technique with validation loss - 40 patience")

# %%
from sklearn.metrics import classification_report
average_f1_score = 0
#Confution Matrix and Classification Report
for i in range(len(best_models)):
    Y_pred = best_models[i][-1].predict(test_batches_CV[i])
    y_pred = np.where(Y_pred > 0.5, 1, 0)
    print('Confusion Matrix')
    y_pred = y_pred.max(axis=1)
    y_true = np.concatenate([y for x, y in test_batches_CV[i]], axis=0)
    print(confusion_matrix(y_true, y_pred, labels=[True, False]))
    f1_score_acc = f1_score(y_true, y_pred, average='macro')
    average_f1_score += f1_score_acc
    print("F1 Score: {}".format(f1_score_acc))
    print(classification_report(y_true, y_pred, target_names=['Class 0', 'Class 1']))
average_f1_score = average_f1_score / len(best_models)
print("Average F1 Score: {}".format(average_f1_score))
# Out:
# Confusion Matrix
# [[ 298   80]
#  [  71 3434]]
# F1 Score: 0.8881725315089488
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.98      0.98      3505
#      Class 1       0.81      0.79      0.80       378
#
#     accuracy                           0.96      3883
#    macro avg       0.89      0.88      0.89      3883
# weighted avg       0.96      0.96      0.96      3883
#
# Confusion Matrix
# [[ 313   65]
#  [  85 3420]]
# F1 Score: 0.8926209017300119
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.98      0.98      3505
#      Class 1       0.79      0.83      0.81       378
#
#     accuracy                           0.96      3883
#    macro avg       0.88      0.90      0.89      3883
# weighted avg       0.96      0.96      0.96      3883
#
# Confusion Matrix
# [[ 298   81]
#  [  92 3412]]
# F1 Score: 0.8751538138303003
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.97      0.98      3504
#      Class 1       0.76      0.79      0.78       379
#
#     accuracy                           0.96      3883
#    macro avg       0.87      0.88      0.88      3883
# weighted avg       0.96      0.96      0.96      3883
#
# WARNING:tensorflow:5 out of the last 14 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002BDE5AE5510> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Confusion Matrix
# [[ 296   83]
#  [  64 3440]]
# F1 Score: 0.8900816163751145
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.98      0.98      3504
#      Class 1       0.82      0.78      0.80       379
#
#     accuracy                           0.96      3883
#    macro avg       0.90      0.88      0.89      3883
# weighted avg       0.96      0.96      0.96      3883
#
# WARNING:tensorflow:6 out of the last 15 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002BDD2D6A730> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Confusion Matrix
# [[ 285   93]
#  [  78 3426]]
# F1 Score: 0.8724411001215785
#               precision    recall  f1-score   support
#
#      Class 0       0.97      0.98      0.98      3504
#      Class 1       0.79      0.75      0.77       378
#
#     accuracy                           0.96      3882
#    macro avg       0.88      0.87      0.87      3882
# weighted avg       0.96      0.96      0.96      3882
#
# Average F1 Score: 0.8836939927131908

# %%
import sklearn.metrics as metrics

for i in range(len(best_models)):
    Y_pred = best_models[i][-1].predict(test_batches_CV[i])
    y_pred = np.where(Y_pred > 0.5, 1, 0)
    y_pred = y_pred.max(axis=1)
    y_true = np.concatenate([y for x, y in test_batches_CV[i]], axis=0)
    fpr, tpr, threshold = metrics.roc_curve(y_true, y_pred)
    roc_auc = metrics.auc(fpr, tpr)
    print("FPR: ", fpr)
    print("TPR: ", tpr)
    # method I: plt
    plt.title('Receiver Operating Characteristic')
    plt.plot(fpr, tpr, 'b', label = 'AUC = %0.4f' % roc_auc)
    plt.legend(loc = 'lower right')
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([0, 1])
    plt.ylim([0, 1])
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()
# Out:
# FPR:  [0.         0.02025678 1.        ]
# TPR:  [0.         0.78835979 1.        ]
# FPR:  [0.         0.02425107 1.        ]
# TPR:  [0.         0.82804233 1.        ]
# FPR:  [0.         0.02625571 1.        ]
# TPR:  [0.         0.78627968 1.        ]
# FPR:  [0.         0.01826484 1.        ]
# TPR:  [0.         0.78100264 1.        ]
# FPR:  [0.         0.02226027 1.        ]
# TPR:  [0.         0.75396825 1.        ]

# %%
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import auc

for i in range(len(best_models)):
    Y_pred = best_models[i][-1].predict(test_batches_CV[i])
    y_pred = np.where(Y_pred > 0.5, 1, 0)
    y_pred = y_pred.max(axis=1)
    y_true = np.concatenate([y for x, y in test_batches_CV[i]], axis=0)
    lr_precision, lr_recall, _ = precision_recall_curve(y_true, y_pred)
    lr_f1, lr_auc = f1_score(y_true, y_pred, average='macro'), auc(lr_recall, lr_precision)
    # summarize scores
    print("Precision: ", lr_precision)
    print("Recall: ", lr_recall)
    print('Logistic: f1=%.3f auc=%.3f' % (lr_f1, lr_auc))
    # plot the precision-recall curves
    no_skill = len(y_true[y_true==1]) / len(y_true)
    plt.plot([0, 1], [no_skill, no_skill], linestyle='--')
    plt.plot(lr_recall, lr_precision, marker='.', label = 'AUC = %0.4f' % lr_auc)
    # axis labels
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    # show the legend
    plt.legend()
    # show the plot
    plt.show()
# Out:
# Precision:  [0.09734741 0.80758808 1.        ]
# Recall:  [1.         0.78835979 0.        ]
# Logistic: f1=0.888 auc=0.808
# Precision:  [0.09734741 0.78643216 1.        ]
# Recall:  [1.         0.82804233 0.        ]
# Logistic: f1=0.893 auc=0.816
# Precision:  [0.09760494 0.76410256 1.        ]
# Recall:  [1.         0.78627968 0.        ]
# Logistic: f1=0.875 auc=0.786
# Precision:  [0.09760494 0.82222222 1.        ]
# Recall:  [1.         0.78100264 0.        ]
# Logistic: f1=0.890 auc=0.812
# Precision:  [0.09737249 0.78512397 1.        ]
# Recall:  [1.         0.75396825 0.        ]
# Logistic: f1=0.872 auc=0.782
