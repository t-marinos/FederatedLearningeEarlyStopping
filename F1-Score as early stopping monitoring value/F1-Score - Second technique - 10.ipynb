# %%
import pandas as pd
import numpy as np
import random
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.utils.vis_utils import plot_model
from tensorflow.keras.layers import LSTM, Dense, Input, add, concatenate
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K

RANDOM_SEED = 42
random.seed(RANDOM_SEED)
# Out:
# c:\Users\Theo\AppData\Local\Programs\Python\Python37\lib\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# c:\Users\Theo\AppData\Local\Programs\Python\Python37\lib\site-packages\numpy\.libs\libopenblas.IPBC74C7KURV7CB2PKT5Z5FNR3SIBV4J.gfortran-win_amd64.dll
# c:\Users\Theo\AppData\Local\Programs\Python\Python37\lib\site-packages\numpy\.libs\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll
#   stacklevel=1)

# %%
vitals = pd.read_csv('vitals.csv')  
labs = pd.read_csv('labs.csv')

# %% [markdown]
# Changing the date to datetime variable and setting indexes

# %%
vitals['charttime'] = pd.to_datetime(vitals['charttime'] , infer_datetime_format=True)
labs['charttime'] = pd.to_datetime(labs['charttime'] , infer_datetime_format=True)

# %%
vitals_48hours_grouped = vitals.groupby('icustay_id').tail(48)

# %%
labs_48hours_grouped = labs.groupby('icustay_id').tail(6)

# %%
print((vitals_48hours_grouped.icustay_id.value_counts() == 48).sum() == len(vitals_48hours_grouped) /48)
print((labs_48hours_grouped.icustay_id.value_counts() == 6).sum() == len(labs_48hours_grouped) /6)
# Out:
# True
# True

# %%
vitals_48hours_grouped = vitals_48hours_grouped.drop(['icustay_id','charttime'], axis=1)
labs_48hours_grouped = labs_48hours_grouped.drop(['icustay_id','charttime'], axis=1)

# %%
vitals_features = vitals_48hours_grouped.iloc[:,:-1]
vitals_labels = vitals_48hours_grouped.iloc[:,-1:].to_numpy().tolist()

# %%
labs_features = labs_48hours_grouped.iloc[:,:-1]
labs_labels = labs_48hours_grouped.iloc[:,-1:].to_numpy().tolist()

# %% [markdown]
# # Federated Learning Setup

# %%
def create_clients(labs_data, vitals_data, label_list, num_clients=4, initial='clients'):
    ''' return: a dictionary with keys clients' names and value as 
                data shards - tuple of images and label lists.
        args: 
            image_list: a list of numpy arrays of training images
            label_list:a list of binarized labels for each image
            num_client: number of fedrated members (clients)
            initials: the clients'name prefix, e.g, clients_1 
            
    '''

    #create a list of client names
    client_names = ['{}_{}'.format(initial, i+1) for i in range(num_clients)]

    #randomize the data
    data = list(zip(labs_data, vitals_data))
    data = list(zip(data, label_list))
    random.shuffle(data)

    #shard data and place at each client
    size = len(data)//num_clients
    shards = [data[i:i + size] for i in range(0, size*num_clients, size)]

    #number of clients must equal number of shards
    assert(len(shards) == len(client_names))
    
    return  {client_names[i] : shards[i] for i in range(len(client_names))}

# %% [markdown]
# ## Reshaping data and preparing them for cross validation

# %%
vitals_labels = np.array(vitals_labels)
labs_labels = np.array(labs_labels)


labs_labels_reshaped = np.reshape(labs_labels, (19414,6))
labs_labels_reshaped = np.amax(labs_labels_reshaped, axis=1)

vitals_labels_reshaped = np.reshape(vitals_labels, (19414,48))
vitals_labels_reshaped = np.amax(vitals_labels_reshaped, axis=1)
print(labs_labels_reshaped.shape)
print(vitals_labels_reshaped.shape)
# Out:
# (19414,)
# (19414,)

# %%
vitals_features_reshaped = np.reshape(vitals_features.values, (19414,48,7))
print(vitals_features_reshaped.shape)
labs_features_reshaped = np.reshape(labs_features.values, (19414,6,16))
print(labs_features_reshaped.shape)
# Out:
# (19414, 48, 7)
# (19414, 6, 16)

# %% [markdown]
# ### Batching clients and test data

# %%
def batch_data(data_shard, bs=64):
    '''Takes in a clients data shard and create a tfds object off it
    args:
        shard: a data, label constituting a client's data shard
        bs:batch size
    return:
        tfds object'''
    #seperate shard into data and labels lists
    data, label = zip(*data_shard)
    dataset = []
    X_train, X_test, y_train, y_test = train_test_split(data, label, test_size=0.15, random_state=RANDOM_SEED, stratify=label)
    X_labs_train , X_vitals_train = zip(*X_train)
    X_labs_test , X_vitals_test = zip(*X_test)

    #Reshaping to standardize the laboratory values
    X_labs_train = np.array(X_labs_train)
    X_labs_test = np.array(X_labs_test)
    samples_train, groupedBy_train, sample_values_train = X_labs_train.shape
    samples_test, groupedBy_test, sample_values_test = X_labs_test.shape
    X_labs_train_reshaped = np.reshape(X_labs_train, (samples_train*groupedBy_train, sample_values_train))
    X_labs_test_reshaped = np.reshape(X_labs_test, (samples_test*groupedBy_test, sample_values_test))
    #Standardizing the laboratory values
    scaler_labs = StandardScaler()
    scaler_labs = scaler_labs.fit(X_labs_train_reshaped)
    X_labs_train_reshaped = scaler_labs.transform(X_labs_train_reshaped)
    X_labs_test_reshaped = scaler_labs.transform(X_labs_test_reshaped)
    #Reshaping again
    X_labs_train = np.reshape(X_labs_train_reshaped,  (samples_train, groupedBy_train, sample_values_train))
    X_labs_test = np.reshape(X_labs_test_reshaped, (samples_test, groupedBy_test, sample_values_test))

    #Reshaping to standardize the laboratory values
    X_vitals_train = np.array(X_vitals_train)
    X_vitals_test = np.array(X_vitals_test)
    samples_train, groupedBy_train, sample_values_train = X_vitals_train.shape
    samples_test, groupedBy_test, sample_values_test = X_vitals_test.shape
    X_vitals_train_reshaped = np.reshape(X_vitals_train, (samples_train*groupedBy_train, sample_values_train))
    X_vitals_test_reshaped = np.reshape(X_vitals_test, (samples_test*groupedBy_test, sample_values_test))
    #Standardizing the laboratory values
    scaler_vitals = StandardScaler()
    scaler_vitals = scaler_vitals.fit(X_vitals_train_reshaped)
    X_vitals_train_reshaped = scaler_vitals.transform(X_vitals_train_reshaped)
    X_vitals_test_reshaped = scaler_vitals.transform(X_vitals_test_reshaped)
    #Reshaping again
    X_vitals_train = np.reshape(X_vitals_train_reshaped,  (samples_train, groupedBy_train, sample_values_train))
    X_vitals_test = np.reshape(X_vitals_test_reshaped, (samples_test, groupedBy_test, sample_values_test))

    combinedDatasetTraining = tf.data.Dataset.from_tensor_slices(({"Input_1": list(X_labs_train), "Input_2": list(X_vitals_train)}, list(y_train)))
    combinedDatasetTraining = combinedDatasetTraining.shuffle(len(y_train)).batch(bs)
    combinedDatasetTesting = tf.data.Dataset.from_tensor_slices(({"Input_1": list(X_labs_test), "Input_2": list(X_vitals_test)}, list(y_test)))
    combinedDatasetTesting = combinedDatasetTesting.shuffle(len(y_test)).batch(bs)
    
    dataset.append(combinedDatasetTraining)
    dataset.append(combinedDatasetTesting)
    return dataset

def batch_data_last(data_shard, bs=64):
    '''Takes in a clients data shard and create a tfds object off it
    args:
        shard: a data, label constituting a client's data shard
        bs:batch size
    return:
        tfds object'''
    #seperate shard into data and labels lists
    data, label = zip(*data_shard)
    dataset = []
    X_train, y_train = data, label
    X_labs_train , X_vitals_train = zip(*X_train)
    #Reshaping to standardize the laboratory values
    X_labs_train = np.array(X_labs_train)
    samples_train, groupedBy_train, sample_values_train = X_labs_train.shape
    X_labs_train_reshaped = np.reshape(X_labs_train, (samples_train*groupedBy_train, sample_values_train))
    #Standardizing the laboratory values
    scaler_labs = StandardScaler()
    scaler_labs = scaler_labs.fit(X_labs_train_reshaped)
    X_labs_train_reshaped = scaler_labs.transform(X_labs_train_reshaped)
    #Reshaping again
    X_labs_train = np.reshape(X_labs_train_reshaped,  (samples_train, groupedBy_train, sample_values_train))

    #Reshaping to standardize the laboratory values
    X_vitals_train = np.array(X_vitals_train)
    samples_train, groupedBy_train, sample_values_train = X_vitals_train.shape
    X_vitals_train_reshaped = np.reshape(X_vitals_train, (samples_train*groupedBy_train, sample_values_train))
    #Standardizing the laboratory values
    scaler_vitals = StandardScaler()
    scaler_vitals = scaler_vitals.fit(X_vitals_train_reshaped)
    X_vitals_train_reshaped = scaler_vitals.transform(X_vitals_train_reshaped)
    #Reshaping again
    X_vitals_train = np.reshape(X_vitals_train_reshaped,  (samples_train, groupedBy_train, sample_values_train))
    combinedDatasetTraining = tf.data.Dataset.from_tensor_slices(({"Input_1": list(X_labs_train), "Input_2": list(X_vitals_train)}, list(y_train)))
    combinedDatasetTraining = combinedDatasetTraining.shuffle(len(y_train)).batch(bs)
    
    dataset.append(combinedDatasetTraining)
    return dataset

# %% [markdown]
# ### Creating the Model

# %%
class RNNModel:
    @staticmethod
    def build():
     input1 = Input(shape=(6,16), name='Input_1')
     fe1 = LSTM(16, input_shape= (6,16), return_sequences=True)(input1)
     fe2 = LSTM(16, return_sequences=True)(fe1)
     fe3 = LSTM(16)(fe2)
#sequence model
     input2 = Input(shape=(48,7), name='Input_2')
     se1 = LSTM(16, input_shape= (48,7), return_sequences=True)(input2)
     se2 = LSTM(16, return_sequences=True)(se1)
     se3 = LSTM(16)(se2)
#decoder model
     decoder1 = concatenate([fe3, se3])
     decoder2 = Dense(16, activation='relu')(decoder1)
     decoder3 = Dense(16, activation='relu')(decoder2)
     output = Dense(1, activation='sigmoid')(decoder3)
#connecting the two models
     model = Model(inputs=[input1, input2], outputs=output)
     return model

# %% [markdown]
# ### Federated Averaging

# %%
def weight_scalling_factor(clients_trn_data, client_name):
    '''Gets batch size and calculates total datapoints and how many data points the client has to scale it'''
    client_names = list(clients_trn_data.keys())
    #get the bs
    bs = list(clients_trn_data[client_name][0])[0][0]['Input_1'].shape[0]
    #first calculate the total training data points across clinets
    global_count = sum([tf.data.experimental.cardinality(clients_trn_data[client_name][0]).numpy() for client_name in client_names])*bs
    # get the total number of data points held by a client
    local_count = tf.data.experimental.cardinality(clients_trn_data[client_name][0]).numpy()*bs
    return local_count/global_count


def scale_model_weights(weight, scalar):
    '''function for scaling a models weights'''
    weight_final = []
    steps = len(weight)
    for i in range(steps):
        weight_final.append(scalar * weight[i])
    return weight_final



def sum_scaled_weights(scaled_weight_list):
    '''Return the sum of the listed scaled weights. The is equivalent to scaled avg of the weights'''
    avg_grad = list()
    #get the average grad accross all client gradients
    for grad_list_tuple in zip(*scaled_weight_list):
        layer_mean = tf.math.reduce_sum(grad_list_tuple, axis=0)
        avg_grad.append(layer_mean)
        
    return avg_grad


def test_model(X_test, Y_test,  model, comm_round):
    cce = tf.keras.losses.BinaryCrossentropy(from_logits=True)
    #logits = model.predict(X_test, batch_size=100)
    logits = model.predict(X_test)
    Y_test = np.reshape(Y_test, (len(Y_test),1))
    loss = cce(Y_test, logits)
    logits = np.where(logits > 0.5, 1, 0)
    f1_score_acc = f1_score(Y_test.max(axis=1), logits.max(axis=1), average='macro')
    print('comm_round: {} | f1_score: {:.3%} | global_loss: {}'.format(comm_round, f1_score_acc, loss))
    return f1_score_acc, loss

def evaluating_model_own_validation_data_F1(model, val_data):
    cce = tf.keras.losses.BinaryCrossentropy(from_logits=True)
    logits = model.predict(val_data)
    y_true = np.concatenate([y for x, y in val_data], axis=0)
    y_true = np.reshape(y_true, (len(y_true),1))
    loss = cce(y_true, logits)
    logits = np.where(logits > 0.5, 1, 0)
    f1_score_acc = f1_score(y_true.max(axis=1), logits.max(axis=1), average='macro')
    print("Loss: " , loss)
    return f1_score_acc, loss

# %%
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=RANDOM_SEED)
skf.get_n_splits(vitals_features_reshaped, vitals_labels_reshaped)
# Out:
# 5

# %% [markdown]
# ### Training the model - Each client validate on their own data

# %%
from tensorflow.keras import backend as K

loss_CV = []
acc_CV = []
f1_scores_averages_all = []
loss_values_averages_all = []
clients_number = 4
patience = 10
best_models = []
early_stopping_applied = []
test_batches_CV = []
for train_index, test_index in skf.split(vitals_features_reshaped, vitals_labels_reshaped):
    print("TRAIN:", train_index, "TEST:", test_index)
    X_train_vitals, X_test_vitals = vitals_features_reshaped[train_index], vitals_features_reshaped[test_index]
    X_train_labs, X_test_labs = labs_features_reshaped[train_index], labs_features_reshaped[test_index]
    y_train, y_test = vitals_labels_reshaped[train_index], vitals_labels_reshaped[test_index]

    clients = create_clients(X_train_labs, X_train_vitals ,y_train, num_clients=clients_number, initial='client')
    #process and batch the training data for each client
    clients_batched = dict()
    client_counter = 0
    for (client_name, data) in clients.items():
        if client_counter == 3:
            clients_batched[client_name] = batch_data_last(data)
        else:
            clients_batched[client_name] = batch_data(data)
        client_counter = client_counter + 1
     #Standardizing the testing set based on all training data
    X_train_labs = np.array(X_train_labs)
    samples_train, groupedBy_train, sample_values_train = X_train_labs.shape
    X_train_labs = np.reshape(X_train_labs, (samples_train*groupedBy_train,sample_values_train))
    samples_test, groupedBy_test, sample_values_test = X_test_labs.shape
    X_test_labs = np.reshape(X_test_labs, (samples_test*groupedBy_test,sample_values_test))
    scaler_labs = StandardScaler()
    scaler_labs = scaler_labs.fit(X_train_labs)
    X_test_labs = scaler_labs.transform(X_test_labs)
    X_test_labs = np.reshape(X_test_labs, (samples_test,groupedBy_test,sample_values_test))


    X_train_vitals = np.array(X_train_vitals)
    samples_train, groupedBy_train, sample_values_train = X_train_vitals.shape
    X_train_vitals = np.reshape(X_train_vitals, (samples_train*groupedBy_train,sample_values_train))
    samples_test, groupedBy_test, sample_values_test = X_test_vitals.shape
    X_test_vitals = np.reshape(X_test_vitals, (samples_test*groupedBy_test,sample_values_test))
    scaler_labs = StandardScaler()
    scaler_labs = scaler_labs.fit(X_train_vitals)
    X_test_vitals = scaler_labs.transform(X_test_vitals)
    X_test_vitals = np.reshape(X_test_vitals, (samples_test,groupedBy_test,sample_values_test))
    
    #process and batch the test set  
    test_batched = tf.data.Dataset.from_tensor_slices(({"Input_1": list(X_test_labs), 
    "Input_2": list(X_test_vitals)}, list(y_test))).batch(len(y_test))
    test_batches_CV.append(test_batched)
       #randomize client data - using keys
    client_names= list(clients_batched.keys())
    #random.shuffle(client_names)
    #initialize global model
    f1_scores_averages = []
    loss_values_averages = []
    models_CV = []
    best_score = 0
    rounds_worse_than_before = 0    
    rnn_global = RNNModel()
    global_model = rnn_global.build()
    comms_round = 300
    loss = 'binary_crossentropy'
    metrics = ['accuracy']
    global_loss = []
    global_acc = []
    learning_rate = 0.01
    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
    counter = 0
    #commence global training loop
    for comm_round in range(comms_round):
        if comm_round % 5 == 0 and comm_round > 0:
            learning_rate = learning_rate * 0.5
            optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
        # get the global model's weights - will serve as the initial weights for all local models
        global_weights = global_model.get_weights()
        
        #initial list to collect local model weights after scalling
        scaled_local_weight_list = list()

        #loop through each client and create new local model
        for client in client_names[:-1]:
            rnn_local = RNNModel()
            local_model = rnn_local.build()
            local_model.compile(loss=loss, 
                        optimizer=optimizer, 
                        metrics=metrics)
            
            #set local model weight to the weight of the global model
            local_model.set_weights(global_weights)

            #fit local model with client's data
            local_model.fit(clients_batched[client][0], epochs=3, verbose=0 , validation_data=clients_batched[client][1])
            
            #scale the model weights and add to list
            scaling_factor = weight_scalling_factor(clients_batched, client)
            scaled_weights = scale_model_weights(local_model.get_weights(), scaling_factor)
            scaled_local_weight_list.append(scaled_weights)
            print(client, "Finished")
            #clear session to free memory after each communication round
            K.clear_session()
            
        #to get the average over all the local model, we simply take the sum of the scaled weights
        average_weights = sum_scaled_weights(scaled_local_weight_list)
        
        #update global model 
        global_model.set_weights(average_weights)

        #evaluating the current global model against each clients validation data
        f1_scores = 0
        loss_values = 0
        rnn_local = RNNModel()
        local_model = rnn_local.build()
        local_model.compile(loss=loss, 
                        optimizer=optimizer, 
                        metrics=metrics)     
            #set local model weight to the weight of the global model
        local_model.set_weights(global_weights)
        f1_score_acc, loss_value = evaluating_model_own_validation_data_F1(local_model, clients_batched[client_names[-1]][0])
        print(client_names[-1], ":", f1_score_acc)
        f1_scores += f1_score_acc
        loss_values += loss_value
        print("F1 Score average for round {} = {}, Loss: {}".format(comm_round, f1_scores, loss_values))
        models_CV.append(global_model)
        f1_scores_averages.append(f1_scores)
        loss_values_averages.append(loss_values)
        if  len(f1_scores_averages) == 1:
            best_score = f1_scores_averages[0]
        #checks for early stopping according to f1 score and patience
        if len(f1_scores_averages) > 1:
            if f1_scores_averages[-1] <= best_score:
                rounds_worse_than_before += 1
            else:
                rounds_worse_than_before = 0
                best_score = f1_scores_averages[-1]
        if rounds_worse_than_before == patience:
            break
        #test global model and print out metrics after each communications round
        #for(X_test, Y_test) in test_batched:
            #global_f1_acc, global_model_loss = test_model(X_test, Y_test, global_model, comm_round)
            #global_loss.append(global_model_loss)
            #global_acc.append(global_f1_acc)
    if rounds_worse_than_before == patience:
        f1_scores_averages_all.append(f1_scores_averages[:-patience])
        loss_values_averages_all.append(loss_values_averages[:-patience])
        best_models.append(models_CV[:-patience])
        early_stopping_applied.append(True)
    else:
        f1_scores_averages_all.append(f1_scores_averages)
        loss_values_averages_all.append(loss_values_averages)
        best_models.append(models_CV) 
        early_stopping_applied.append(False)
    #models_CV.append(global_model)
    #loss_CV.append(global_loss)
    #acc_CV.append(global_acc)
    print("CV Round complete")
# Out:
# TRAIN: [    0     1     3 ... 19410 19411 19413] TEST: [    2     4    17 ... 19399 19400 19412]
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.9142262, shape=(), dtype=float32)
# client_4 : 0.473841149362971
# F1 Score average for round 0 = 0.473841149362971, Loss: 0.9142261743545532
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.816011, shape=(), dtype=float32)
# client_4 : 0.4951687316559602
# F1 Score average for round 1 = 0.4951687316559602, Loss: 0.8160110116004944
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7938036, shape=(), dtype=float32)
# client_4 : 0.5032830272541771
# F1 Score average for round 2 = 0.5032830272541771, Loss: 0.7938035726547241
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.78297615, shape=(), dtype=float32)
# client_4 : 0.5038672321744526
# F1 Score average for round 3 = 0.5038672321744526, Loss: 0.7829761505126953
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.76968175, shape=(), dtype=float32)
# client_4 : 0.5137092405165535
# F1 Score average for round 4 = 0.5137092405165535, Loss: 0.7696817517280579
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.77204037, shape=(), dtype=float32)
# client_4 : 0.4917988798470035
# F1 Score average for round 5 = 0.4917988798470035, Loss: 0.7720403671264648
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7745374, shape=(), dtype=float32)
# client_4 : 0.4994108461101646
# F1 Score average for round 6 = 0.4994108461101646, Loss: 0.7745373845100403
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.77955925, shape=(), dtype=float32)
# client_4 : 0.5032830272541771
# F1 Score average for round 7 = 0.5032830272541771, Loss: 0.7795592546463013
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7788282, shape=(), dtype=float32)
# client_4 : 0.4938803759979397
# F1 Score average for round 8 = 0.4938803759979397, Loss: 0.7788282036781311
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7698161, shape=(), dtype=float32)
# client_4 : 0.49042924899025325
# F1 Score average for round 9 = 0.49042924899025325, Loss: 0.7698161005973816
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7718677, shape=(), dtype=float32)
# client_4 : 0.5005396368821526
# F1 Score average for round 10 = 0.5005396368821526, Loss: 0.7718676924705505
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.78192294, shape=(), dtype=float32)
# client_4 : 0.5076360419574919
# F1 Score average for round 11 = 0.5076360419574919, Loss: 0.7819229364395142
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.78175515, shape=(), dtype=float32)
# client_4 : 0.5018423220777862
# F1 Score average for round 12 = 0.5018423220777862, Loss: 0.7817551493644714
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.78593206, shape=(), dtype=float32)
# client_4 : 0.48819134251863316
# F1 Score average for round 13 = 0.48819134251863316, Loss: 0.7859320640563965
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7837327, shape=(), dtype=float32)
# client_4 : 0.49269169692817627
# F1 Score average for round 14 = 0.49269169692817627, Loss: 0.7837327122688293
# CV Round complete
# TRAIN: [    1     2     4 ... 19410 19412 19413] TEST: [    0     3    15 ... 19405 19408 19411]
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.9242202, shape=(), dtype=float32)
# client_4 : 0.4211321012674516
# F1 Score average for round 0 = 0.4211321012674516, Loss: 0.9242202043533325
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.79232836, shape=(), dtype=float32)
# client_4 : 0.4820796444509909
# F1 Score average for round 1 = 0.4820796444509909, Loss: 0.7923283576965332
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7987971, shape=(), dtype=float32)
# client_4 : 0.49814793621308323
# F1 Score average for round 2 = 0.49814793621308323, Loss: 0.798797070980072
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7879481, shape=(), dtype=float32)
# client_4 : 0.5040994077342933
# F1 Score average for round 3 = 0.5040994077342933, Loss: 0.7879480719566345
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.78461725, shape=(), dtype=float32)
# client_4 : 0.4948461649332257
# F1 Score average for round 4 = 0.4948461649332257, Loss: 0.7846172451972961
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.77244157, shape=(), dtype=float32)
# client_4 : 0.49694533063222074
# F1 Score average for round 5 = 0.49694533063222074, Loss: 0.772441565990448
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.77808917, shape=(), dtype=float32)
# client_4 : 0.5034288114979206
# F1 Score average for round 6 = 0.5034288114979206, Loss: 0.778089165687561
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7669133, shape=(), dtype=float32)
# client_4 : 0.49851503688212445
# F1 Score average for round 7 = 0.49851503688212445, Loss: 0.7669132947921753
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7740459, shape=(), dtype=float32)
# client_4 : 0.4874024180957174
# F1 Score average for round 8 = 0.4874024180957174, Loss: 0.7740458846092224
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7575451, shape=(), dtype=float32)
# client_4 : 0.5059178638104199
# F1 Score average for round 9 = 0.5059178638104199, Loss: 0.7575451135635376
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7692513, shape=(), dtype=float32)
# client_4 : 0.49009195471758926
# F1 Score average for round 10 = 0.49009195471758926, Loss: 0.76925128698349
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7751636, shape=(), dtype=float32)
# client_4 : 0.49972581027412055
# F1 Score average for round 11 = 0.49972581027412055, Loss: 0.7751635909080505
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7808546, shape=(), dtype=float32)
# client_4 : 0.5180366559722682
# F1 Score average for round 12 = 0.5180366559722682, Loss: 0.7808545827865601
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.782891, shape=(), dtype=float32)
# client_4 : 0.4960638532330666
# F1 Score average for round 13 = 0.4960638532330666, Loss: 0.7828909754753113
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7793416, shape=(), dtype=float32)
# client_4 : 0.5077088556206133
# F1 Score average for round 14 = 0.5077088556206133, Loss: 0.7793415784835815
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7808005, shape=(), dtype=float32)
# client_4 : 0.49694533063222074
# F1 Score average for round 15 = 0.49694533063222074, Loss: 0.7808005213737488
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.79717964, shape=(), dtype=float32)
# client_4 : 0.5062047774804243
# F1 Score average for round 16 = 0.5062047774804243, Loss: 0.797179639339447
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.80530083, shape=(), dtype=float32)
# client_4 : 0.49242929585311124
# F1 Score average for round 17 = 0.49242929585311124, Loss: 0.8053008317947388
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.797378, shape=(), dtype=float32)
# client_4 : 0.4928953349888263
# F1 Score average for round 18 = 0.4928953349888263, Loss: 0.7973780035972595
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7998794, shape=(), dtype=float32)
# client_4 : 0.498793281531638
# F1 Score average for round 19 = 0.498793281531638, Loss: 0.7998793721199036
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.79475904, shape=(), dtype=float32)
# client_4 : 0.5083446973054305
# F1 Score average for round 20 = 0.5083446973054305, Loss: 0.7947590351104736
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.8331728, shape=(), dtype=float32)
# client_4 : 0.4897011132322065
# F1 Score average for round 21 = 0.4897011132322065, Loss: 0.8331727981567383
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.82693183, shape=(), dtype=float32)
# client_4 : 0.49797019960640987
# F1 Score average for round 22 = 0.49797019960640987, Loss: 0.8269318342208862
# CV Round complete
# TRAIN: [    0     1     2 ... 19411 19412 19413] TEST: [    6     7     8 ... 19391 19398 19401]
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.93483377, shape=(), dtype=float32)
# client_4 : 0.15005573174167416
# F1 Score average for round 0 = 0.15005573174167416, Loss: 0.9348337650299072
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.79514986, shape=(), dtype=float32)
# client_4 : 0.49502506052754536
# F1 Score average for round 1 = 0.49502506052754536, Loss: 0.7951498627662659
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.8049173, shape=(), dtype=float32)
# client_4 : 0.5006184287089559
# F1 Score average for round 2 = 0.5006184287089559, Loss: 0.8049172759056091
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.78431845, shape=(), dtype=float32)
# client_4 : 0.5062827491478862
# F1 Score average for round 3 = 0.5062827491478862, Loss: 0.7843184471130371
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7858121, shape=(), dtype=float32)
# client_4 : 0.5024686225439448
# F1 Score average for round 4 = 0.5024686225439448, Loss: 0.7858120799064636
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7932657, shape=(), dtype=float32)
# client_4 : 0.5006184287089559
# F1 Score average for round 5 = 0.5006184287089559, Loss: 0.793265700340271
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7821762, shape=(), dtype=float32)
# client_4 : 0.5001481206683709
# F1 Score average for round 6 = 0.5001481206683709, Loss: 0.7821761965751648
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.78866315, shape=(), dtype=float32)
# client_4 : 0.4945121269896015
# F1 Score average for round 7 = 0.4945121269896015, Loss: 0.7886631488800049
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7770286, shape=(), dtype=float32)
# client_4 : 0.49407080642354895
# F1 Score average for round 8 = 0.49407080642354895, Loss: 0.7770286202430725
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.778802, shape=(), dtype=float32)
# client_4 : 0.500486039289653
# F1 Score average for round 9 = 0.500486039289653, Loss: 0.7788019776344299
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7766084, shape=(), dtype=float32)
# client_4 : 0.4864059169887656
# F1 Score average for round 10 = 0.4864059169887656, Loss: 0.776608407497406
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.77538306, shape=(), dtype=float32)
# client_4 : 0.5055393578118776
# F1 Score average for round 11 = 0.5055393578118776, Loss: 0.7753830552101135
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7812856, shape=(), dtype=float32)
# client_4 : 0.49826280675672296
# F1 Score average for round 12 = 0.49826280675672296, Loss: 0.7812855839729309
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7842295, shape=(), dtype=float32)
# client_4 : 0.506881387901917
# F1 Score average for round 13 = 0.506881387901917, Loss: 0.7842295169830322
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.78717977, shape=(), dtype=float32)
# client_4 : 0.5023251344467419
# F1 Score average for round 14 = 0.5023251344467419, Loss: 0.7871797680854797
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.78321064, shape=(), dtype=float32)
# client_4 : 0.4981492892204363
# F1 Score average for round 15 = 0.4981492892204363, Loss: 0.7832106351852417
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.8076475, shape=(), dtype=float32)
# client_4 : 0.4931571852931033
# F1 Score average for round 16 = 0.4931571852931033, Loss: 0.8076475262641907
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.81099033, shape=(), dtype=float32)
# client_4 : 0.5002884483373135
# F1 Score average for round 17 = 0.5002884483373135, Loss: 0.8109903335571289
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.79784393, shape=(), dtype=float32)
# client_4 : 0.5019873112260881
# F1 Score average for round 18 = 0.5019873112260881, Loss: 0.7978439331054688
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7930802, shape=(), dtype=float32)
# client_4 : 0.5013322994878237
# F1 Score average for round 19 = 0.5013322994878237, Loss: 0.79308021068573
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.79898345, shape=(), dtype=float32)
# client_4 : 0.5062941655259167
# F1 Score average for round 20 = 0.5062941655259167, Loss: 0.7989834547042847
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.83669275, shape=(), dtype=float32)
# client_4 : 0.48840413130843785
# F1 Score average for round 21 = 0.48840413130843785, Loss: 0.836692750453949
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.83655834, shape=(), dtype=float32)
# client_4 : 0.5007105611395064
# F1 Score average for round 22 = 0.5007105611395064, Loss: 0.8365583419799805
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.8339392, shape=(), dtype=float32)
# client_4 : 0.5012760529372907
# F1 Score average for round 23 = 0.5012760529372907, Loss: 0.8339391946792603
# CV Round complete
# TRAIN: [    0     1     2 ... 19411 19412 19413] TEST: [   37    40    52 ... 19407 19409 19410]
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.91399014, shape=(), dtype=float32)
# client_4 : 0.4731270358306189
# F1 Score average for round 0 = 0.4731270358306189, Loss: 0.9139901399612427
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.8264872, shape=(), dtype=float32)
# client_4 : 0.4955471986892644
# F1 Score average for round 1 = 0.4955471986892644, Loss: 0.8264871835708618
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7838103, shape=(), dtype=float32)
# client_4 : 0.5127933419445683
# F1 Score average for round 2 = 0.5127933419445683, Loss: 0.7838103175163269
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7728294, shape=(), dtype=float32)
# client_4 : 0.49563196951862154
# F1 Score average for round 3 = 0.49563196951862154, Loss: 0.7728294134140015
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7671528, shape=(), dtype=float32)
# client_4 : 0.5085479695842097
# F1 Score average for round 4 = 0.5085479695842097, Loss: 0.7671527862548828
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7808743, shape=(), dtype=float32)
# client_4 : 0.5057153971471274
# F1 Score average for round 5 = 0.5057153971471274, Loss: 0.7808743119239807
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.78013164, shape=(), dtype=float32)
# client_4 : 0.4908126603934987
# F1 Score average for round 6 = 0.4908126603934987, Loss: 0.7801316380500793
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7683413, shape=(), dtype=float32)
# client_4 : 0.5203519274883903
# F1 Score average for round 7 = 0.5203519274883903, Loss: 0.7683413028717041
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.77691156, shape=(), dtype=float32)
# client_4 : 0.48691232108732646
# F1 Score average for round 8 = 0.48691232108732646, Loss: 0.7769115567207336
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.78474665, shape=(), dtype=float32)
# client_4 : 0.5133638356024892
# F1 Score average for round 9 = 0.5133638356024892, Loss: 0.7847466468811035
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7803862, shape=(), dtype=float32)
# client_4 : 0.49856622490893593
# F1 Score average for round 10 = 0.49856622490893593, Loss: 0.780386209487915
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.77835184, shape=(), dtype=float32)
# client_4 : 0.5022365321995428
# F1 Score average for round 11 = 0.5022365321995428, Loss: 0.7783518433570862
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7818355, shape=(), dtype=float32)
# client_4 : 0.4879297508918527
# F1 Score average for round 12 = 0.4879297508918527, Loss: 0.7818354964256287
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7800226, shape=(), dtype=float32)
# client_4 : 0.49856666881277356
# F1 Score average for round 13 = 0.49856666881277356, Loss: 0.7800226211547852
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.78306615, shape=(), dtype=float32)
# client_4 : 0.5046442100615548
# F1 Score average for round 14 = 0.5046442100615548, Loss: 0.7830661535263062
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7783064, shape=(), dtype=float32)
# client_4 : 0.5067518946001007
# F1 Score average for round 15 = 0.5067518946001007, Loss: 0.7783064246177673
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7936622, shape=(), dtype=float32)
# client_4 : 0.5018347531559467
# F1 Score average for round 16 = 0.5018347531559467, Loss: 0.7936621904373169
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.78812027, shape=(), dtype=float32)
# client_4 : 0.4889482231141014
# F1 Score average for round 17 = 0.4889482231141014, Loss: 0.7881202697753906
# CV Round complete
# TRAIN: [    0     2     3 ... 19410 19411 19412] TEST: [    1     5    11 ... 19404 19406 19413]
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.9276133, shape=(), dtype=float32)
# client_4 : 0.45083441222424187
# F1 Score average for round 0 = 0.45083441222424187, Loss: 0.9276133179664612
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.80334854, shape=(), dtype=float32)
# client_4 : 0.5010401662922291
# F1 Score average for round 1 = 0.5010401662922291, Loss: 0.8033485412597656
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.784695, shape=(), dtype=float32)
# client_4 : 0.4996600675878182
# F1 Score average for round 2 = 0.4996600675878182, Loss: 0.784695029258728
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.79008144, shape=(), dtype=float32)
# client_4 : 0.48867890953092746
# F1 Score average for round 3 = 0.48867890953092746, Loss: 0.7900814414024353
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7735435, shape=(), dtype=float32)
# client_4 : 0.4942556699916201
# F1 Score average for round 4 = 0.4942556699916201, Loss: 0.7735434770584106
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.78179145, shape=(), dtype=float32)
# client_4 : 0.49786246767077436
# F1 Score average for round 5 = 0.49786246767077436, Loss: 0.7817914485931396
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7903829, shape=(), dtype=float32)
# client_4 : 0.5072996250299235
# F1 Score average for round 6 = 0.5072996250299235, Loss: 0.7903829216957092
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7894143, shape=(), dtype=float32)
# client_4 : 0.5037191044791229
# F1 Score average for round 7 = 0.5037191044791229, Loss: 0.7894142866134644
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.78405774, shape=(), dtype=float32)
# client_4 : 0.5131492068887452
# F1 Score average for round 8 = 0.5131492068887452, Loss: 0.7840577363967896
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.77152425, shape=(), dtype=float32)
# client_4 : 0.5176362778739968
# F1 Score average for round 9 = 0.5176362778739968, Loss: 0.7715242505073547
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.775457, shape=(), dtype=float32)
# client_4 : 0.48830824136043915
# F1 Score average for round 10 = 0.48830824136043915, Loss: 0.7754570245742798
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.78309715, shape=(), dtype=float32)
# client_4 : 0.5131810012974427
# F1 Score average for round 11 = 0.5131810012974427, Loss: 0.7830971479415894
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7902033, shape=(), dtype=float32)
# client_4 : 0.4994605859093735
# F1 Score average for round 12 = 0.4994605859093735, Loss: 0.7902032732963562
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7896215, shape=(), dtype=float32)
# client_4 : 0.49868728727102013
# F1 Score average for round 13 = 0.49868728727102013, Loss: 0.7896214723587036
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.7845419, shape=(), dtype=float32)
# client_4 : 0.5092043371884113
# F1 Score average for round 14 = 0.5092043371884113, Loss: 0.7845419049263
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.78381634, shape=(), dtype=float32)
# client_4 : 0.49460748152036793
# F1 Score average for round 15 = 0.49460748152036793, Loss: 0.7838163375854492
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.8050048, shape=(), dtype=float32)
# client_4 : 0.49187657251954453
# F1 Score average for round 16 = 0.49187657251954453, Loss: 0.8050047755241394
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.81187093, shape=(), dtype=float32)
# client_4 : 0.49758893372333945
# F1 Score average for round 17 = 0.49758893372333945, Loss: 0.8118709325790405
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.80295914, shape=(), dtype=float32)
# client_4 : 0.503779986890325
# F1 Score average for round 18 = 0.503779986890325, Loss: 0.802959144115448
# client_1 Finished
# client_2 Finished
# client_3 Finished
# Loss:  tf.Tensor(0.80698776, shape=(), dtype=float32)
# client_4 : 0.509511792286253
# F1 Score average for round 19 = 0.509511792286253, Loss: 0.8069877624511719
# CV Round complete

# %% [markdown]
# # Results for Early Stopping when monitoring the average F1 Score value of all the clients using their own validation data

# %%
plt.subplot(2,1,1)
for i in range(len(loss_values_averages_all)):
    plt.plot(loss_values_averages_all[i])
plt.title('models\' loss')
plt.ylabel('loss')
plt.xlabel('Communication rounds')
plt.legend(['fold1', 'fold2','fold3', 'fold4', 'fold5'], loc='lower right')
plt.savefig("Model's Validation loss vs Communication Rounds - Third technique with F1-Score - 10 patience")

# %%
plt.subplot(2,1,1)
for i in range(len(f1_scores_averages_all)):
    plt.plot(f1_scores_averages_all[i])
plt.title('models\' F1 Score')
plt.ylabel('Loss')
plt.xlabel('Communication rounds')
plt.legend(['fold1', 'fold2','fold3', 'fold4', 'fold5'], loc='lower right')
plt.savefig("Model's F1-Score vs Communication Rounds - Third technique with F1-Score - 10 patience")

# %%
from sklearn.metrics import classification_report
average_f1_score = 0
#Confution Matrix and Classification Report
for i in range(len(best_models)):
    Y_pred = best_models[i][-1].predict(test_batches_CV[i])
    y_pred = np.where(Y_pred > 0.5, 1, 0)
    print('Confusion Matrix')
    y_pred = y_pred.max(axis=1)
    y_true = np.concatenate([y for x, y in test_batches_CV[i]], axis=0)
    print(confusion_matrix(y_true, y_pred, labels=[True, False]))
    f1_score_acc = f1_score(y_true, y_pred, average='macro')
    average_f1_score += f1_score_acc
    print("F1 Score: {}".format(f1_score_acc))
    print(classification_report(y_true, y_pred, target_names=['Class 0', 'Class 1']))
average_f1_score = average_f1_score / len(best_models)
print("Average F1 Score: {}".format(average_f1_score))
# Out:
# Confusion Matrix
# [[ 272  106]
#  [  18 3487]]
# F1 Score: 0.8984507738538139
#               precision    recall  f1-score   support
#
#      Class 0       0.97      0.99      0.98      3505
#      Class 1       0.94      0.72      0.81       378
#
#     accuracy                           0.97      3883
#    macro avg       0.95      0.86      0.90      3883
# weighted avg       0.97      0.97      0.97      3883
#
# Confusion Matrix
# [[ 258  120]
#  [  14 3491]]
# F1 Score: 0.8875076750118909
#               precision    recall  f1-score   support
#
#      Class 0       0.97      1.00      0.98      3505
#      Class 1       0.95      0.68      0.79       378
#
#     accuracy                           0.97      3883
#    macro avg       0.96      0.84      0.89      3883
# weighted avg       0.96      0.97      0.96      3883
#
# Confusion Matrix
# [[ 271  108]
#  [  24 3480]]
# F1 Score: 0.8927708907600155
#               precision    recall  f1-score   support
#
#      Class 0       0.97      0.99      0.98      3504
#      Class 1       0.92      0.72      0.80       379
#
#     accuracy                           0.97      3883
#    macro avg       0.94      0.85      0.89      3883
# weighted avg       0.96      0.97      0.96      3883
#
# WARNING:tensorflow:5 out of the last 65 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001B135324A60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Confusion Matrix
# [[ 254  125]
#  [  12 3492]]
# F1 Score: 0.8841790141398571
#               precision    recall  f1-score   support
#
#      Class 0       0.97      1.00      0.98      3504
#      Class 1       0.95      0.67      0.79       379
#
#     accuracy                           0.96      3883
#    macro avg       0.96      0.83      0.88      3883
# weighted avg       0.96      0.96      0.96      3883
#
# WARNING:tensorflow:6 out of the last 66 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001B1486CC1E0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Confusion Matrix
# [[ 239  139]
#  [   9 3495]]
# F1 Score: 0.871422087786468
#               precision    recall  f1-score   support
#
#      Class 0       0.96      1.00      0.98      3504
#      Class 1       0.96      0.63      0.76       378
#
#     accuracy                           0.96      3882
#    macro avg       0.96      0.81      0.87      3882
# weighted avg       0.96      0.96      0.96      3882
#
# Average F1 Score: 0.8868660883104089

# %%
import sklearn.metrics as metrics

for i in range(len(best_models)):
    Y_pred = best_models[i][-1].predict(test_batches_CV[i])
    y_pred = np.where(Y_pred > 0.5, 1, 0)
    y_pred = y_pred.max(axis=1)
    y_true = np.concatenate([y for x, y in test_batches_CV[i]], axis=0)
    fpr, tpr, threshold = metrics.roc_curve(y_true, y_pred)
    roc_auc = metrics.auc(fpr, tpr)
    print("FPR: ", fpr)
    print("TPR: ", tpr)
    # method I: plt
    plt.title('Receiver Operating Characteristic')
    plt.plot(fpr, tpr, 'b', label = 'AUC = %0.4f' % roc_auc)
    plt.legend(loc = 'lower right')
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([0, 1])
    plt.ylim([0, 1])
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()
# Out:
# FPR:  [0.         0.00513552 1.        ]
# TPR:  [0.         0.71957672 1.        ]
# FPR:  [0.         0.00399429 1.        ]
# TPR:  [0.         0.68253968 1.        ]
# FPR:  [0.         0.00684932 1.        ]
# TPR:  [0.         0.71503958 1.        ]
# FPR:  [0.         0.00342466 1.        ]
# TPR:  [0.        0.6701847 1.       ]
# FPR:  [0.         0.00256849 1.        ]
# TPR:  [0.         0.63227513 1.        ]

# %%
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import auc

for i in range(len(best_models)):
    Y_pred = best_models[i][-1].predict(test_batches_CV[i])
    y_pred = np.where(Y_pred > 0.5, 1, 0)
    y_pred = y_pred.max(axis=1)
    y_true = np.concatenate([y for x, y in test_batches_CV[i]], axis=0)
    lr_precision, lr_recall, _ = precision_recall_curve(y_true, y_pred)
    lr_f1, lr_auc = f1_score(y_true, y_pred, average='macro'), auc(lr_recall, lr_precision)
    # summarize scores
    print("Precision: ", lr_precision)
    print("Recall: ", lr_recall)
    print('Logistic: f1=%.3f auc=%.3f' % (lr_f1, lr_auc))
    # plot the precision-recall curves
    no_skill = len(y_true[y_true==1]) / len(y_true)
    plt.plot([0, 1], [no_skill, no_skill], linestyle='--')
    plt.plot(lr_recall, lr_precision, marker='.', label = 'AUC = %0.4f' % lr_auc)
    # axis labels
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    # show the legend
    plt.legend()
    # show the plot
    plt.show()
# Out:
# Precision:  [0.09734741 0.93793103 1.        ]
# Recall:  [1.         0.71957672 0.        ]
# Logistic: f1=0.898 auc=0.842
# Precision:  [0.09734741 0.94852941 1.        ]
# Recall:  [1.         0.68253968 0.        ]
# Logistic: f1=0.888 auc=0.831
# Precision:  [0.09760494 0.91864407 1.        ]
# Recall:  [1.         0.71503958 0.        ]
# Logistic: f1=0.893 auc=0.831
# Precision:  [0.09760494 0.95488722 1.        ]
# Recall:  [1.        0.6701847 0.       ]
# Logistic: f1=0.884 auc=0.829
# Precision:  [0.09737249 0.96370968 1.        ]
# Recall:  [1.         0.63227513 0.        ]
# Logistic: f1=0.871 auc=0.816
