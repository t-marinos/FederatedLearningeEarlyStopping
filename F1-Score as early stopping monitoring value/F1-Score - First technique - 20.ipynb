# %%
import pandas as pd
import numpy as np
import random
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.utils.vis_utils import plot_model
from tensorflow.keras.layers import LSTM, Dense, Input, add, concatenate
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K

RANDOM_SEED = 42
random.seed(RANDOM_SEED)

# %%
vitals = pd.read_csv('vitals.csv')  
labs = pd.read_csv('labs.csv')

# %% [markdown]
# Changing the date to datetime variable and setting indexes

# %%
vitals['charttime'] = pd.to_datetime(vitals['charttime'] , infer_datetime_format=True)
labs['charttime'] = pd.to_datetime(labs['charttime'] , infer_datetime_format=True)

# %%
vitals_48hours_grouped = vitals.groupby('icustay_id').tail(48)

# %%
labs_48hours_grouped = labs.groupby('icustay_id').tail(6)

# %%
print((vitals_48hours_grouped.icustay_id.value_counts() == 48).sum() == len(vitals_48hours_grouped) /48)
print((labs_48hours_grouped.icustay_id.value_counts() == 6).sum() == len(labs_48hours_grouped) /6)
# Out:
# True
# True

# %%
vitals_48hours_grouped = vitals_48hours_grouped.drop(['icustay_id','charttime'], axis=1)
labs_48hours_grouped = labs_48hours_grouped.drop(['icustay_id','charttime'], axis=1)

# %%
vitals_features = vitals_48hours_grouped.iloc[:,:-1]
vitals_labels = vitals_48hours_grouped.iloc[:,-1:].to_numpy().tolist()

# %%
labs_features = labs_48hours_grouped.iloc[:,:-1]
labs_labels = labs_48hours_grouped.iloc[:,-1:].to_numpy().tolist()

# %% [markdown]
# # Federated Learning Setup

# %%
def create_clients(labs_data, vitals_data, label_list, num_clients=4, initial='clients'):
    ''' return: a dictionary with keys clients' names and value as 
                data shards - tuple of images and label lists.
        args: 
            image_list: a list of numpy arrays of training images
            label_list:a list of binarized labels for each image
            num_client: number of fedrated members (clients)
            initials: the clients'name prefix, e.g, clients_1 
            
    '''

    #create a list of client names
    client_names = ['{}_{}'.format(initial, i+1) for i in range(num_clients)]

    #randomize the data
    data = list(zip(labs_data, vitals_data))
    data = list(zip(data, label_list))
    random.shuffle(data)

    #shard data and place at each client
    size = len(data)//num_clients
    shards = [data[i:i + size] for i in range(0, size*num_clients, size)]

    #number of clients must equal number of shards
    assert(len(shards) == len(client_names))
    
    return  {client_names[i] : shards[i] for i in range(len(client_names))}

# %% [markdown]
# ## Reshaping data and preparing them for cross validation

# %%
vitals_labels = np.array(vitals_labels)
labs_labels = np.array(labs_labels)


labs_labels_reshaped = np.reshape(labs_labels, (19414,6))
labs_labels_reshaped = np.amax(labs_labels_reshaped, axis=1)

vitals_labels_reshaped = np.reshape(vitals_labels, (19414,48))
vitals_labels_reshaped = np.amax(vitals_labels_reshaped, axis=1)
print(labs_labels_reshaped.shape)
print(vitals_labels_reshaped.shape)
# Out:
# (19414,)
# (19414,)

# %%
vitals_features_reshaped = np.reshape(vitals_features.values, (19414,48,7))
print(vitals_features_reshaped.shape)
labs_features_reshaped = np.reshape(labs_features.values, (19414,6,16))
print(labs_features_reshaped.shape)
# Out:
# (19414, 48, 7)
# (19414, 6, 16)

# %% [markdown]
# ### Batching clients and test data

# %%
def batch_data(data_shard, bs=64):
    '''Takes in a clients data shard and create a tfds object off it
    args:
        shard: a data, label constituting a client's data shard
        bs:batch size
    return:
        tfds object'''
    #seperate shard into data and labels lists
    data, label = zip(*data_shard)
    dataset = []
    X_train, X_test, y_train, y_test = train_test_split(data, label, test_size=0.15, random_state=RANDOM_SEED, stratify=label)
    X_labs_train , X_vitals_train = zip(*X_train)
    X_labs_test , X_vitals_test = zip(*X_test)

    #Reshaping to standardize the laboratory values
    X_labs_train = np.array(X_labs_train)
    X_labs_test = np.array(X_labs_test)
    samples_train, groupedBy_train, sample_values_train = X_labs_train.shape
    samples_test, groupedBy_test, sample_values_test = X_labs_test.shape
    X_labs_train_reshaped = np.reshape(X_labs_train, (samples_train*groupedBy_train, sample_values_train))
    X_labs_test_reshaped = np.reshape(X_labs_test, (samples_test*groupedBy_test, sample_values_test))
    #Standardizing the laboratory values
    scaler_labs = StandardScaler()
    scaler_labs = scaler_labs.fit(X_labs_train_reshaped)
    X_labs_train_reshaped = scaler_labs.transform(X_labs_train_reshaped)
    X_labs_test_reshaped = scaler_labs.transform(X_labs_test_reshaped)
    #Reshaping again
    X_labs_train = np.reshape(X_labs_train_reshaped,  (samples_train, groupedBy_train, sample_values_train))
    X_labs_test = np.reshape(X_labs_test_reshaped, (samples_test, groupedBy_test, sample_values_test))

    #Reshaping to standardize the laboratory values
    X_vitals_train = np.array(X_vitals_train)
    X_vitals_test = np.array(X_vitals_test)
    samples_train, groupedBy_train, sample_values_train = X_vitals_train.shape
    samples_test, groupedBy_test, sample_values_test = X_vitals_test.shape
    X_vitals_train_reshaped = np.reshape(X_vitals_train, (samples_train*groupedBy_train, sample_values_train))
    X_vitals_test_reshaped = np.reshape(X_vitals_test, (samples_test*groupedBy_test, sample_values_test))
    #Standardizing the laboratory values
    scaler_vitals = StandardScaler()
    scaler_vitals = scaler_vitals.fit(X_vitals_train_reshaped)
    X_vitals_train_reshaped = scaler_vitals.transform(X_vitals_train_reshaped)
    X_vitals_test_reshaped = scaler_vitals.transform(X_vitals_test_reshaped)
    #Reshaping again
    X_vitals_train = np.reshape(X_vitals_train_reshaped,  (samples_train, groupedBy_train, sample_values_train))
    X_vitals_test = np.reshape(X_vitals_test_reshaped, (samples_test, groupedBy_test, sample_values_test))

    combinedDatasetTraining = tf.data.Dataset.from_tensor_slices(({"Input_1": list(X_labs_train), "Input_2": list(X_vitals_train)}, list(y_train)))
    combinedDatasetTraining = combinedDatasetTraining.shuffle(len(y_train)).batch(bs)
    combinedDatasetTesting = tf.data.Dataset.from_tensor_slices(({"Input_1": list(X_labs_test), "Input_2": list(X_vitals_test)}, list(y_test)))
    combinedDatasetTesting = combinedDatasetTesting.shuffle(len(y_test)).batch(bs)
    
    dataset.append(combinedDatasetTraining)
    dataset.append(combinedDatasetTesting)
    return dataset

# %% [markdown]
# ### Creating the Model

# %%
class RNNModel:
    @staticmethod
    def build():
     input1 = Input(shape=(6,16), name='Input_1')
     fe1 = LSTM(16, input_shape= (6,16), return_sequences=True)(input1)
     fe2 = LSTM(16, return_sequences=True)(fe1)
     fe3 = LSTM(16)(fe2)
#sequence model
     input2 = Input(shape=(48,7), name='Input_2')
     se1 = LSTM(16, input_shape= (48,7), return_sequences=True)(input2)
     se2 = LSTM(16, return_sequences=True)(se1)
     se3 = LSTM(16)(se2)
#decoder model
     decoder1 = concatenate([fe3, se3])
     decoder2 = Dense(16, activation='relu')(decoder1)
     decoder3 = Dense(16, activation='relu')(decoder2)
     output = Dense(1, activation='sigmoid')(decoder3)
#connecting the two models
     model = Model(inputs=[input1, input2], outputs=output)
     return model

# %% [markdown]
# ### Federated Averaging

# %%
def weight_scalling_factor(clients_trn_data, client_name):
    '''Gets batch size and calculates total datapoints and how many data points the client has to scale it'''
    client_names = list(clients_trn_data.keys())
    #get the bs
    bs = list(clients_trn_data[client_name][0])[0][0]['Input_1'].shape[0]
    #first calculate the total training data points across clinets
    global_count = sum([tf.data.experimental.cardinality(clients_trn_data[client_name][0]).numpy() for client_name in client_names])*bs
    # get the total number of data points held by a client
    local_count = tf.data.experimental.cardinality(clients_trn_data[client_name][0]).numpy()*bs
    return local_count/global_count


def scale_model_weights(weight, scalar):
    '''function for scaling a models weights'''
    weight_final = []
    steps = len(weight)
    for i in range(steps):
        weight_final.append(scalar * weight[i])
    return weight_final



def sum_scaled_weights(scaled_weight_list):
    '''Return the sum of the listed scaled weights. The is equivalent to scaled avg of the weights'''
    avg_grad = list()
    #get the average grad accross all client gradients
    for grad_list_tuple in zip(*scaled_weight_list):
        layer_mean = tf.math.reduce_sum(grad_list_tuple, axis=0)
        avg_grad.append(layer_mean)
        
    return avg_grad


def test_model(X_test, Y_test,  model, comm_round):
    cce = tf.keras.losses.BinaryCrossentropy(from_logits=True)
    #logits = model.predict(X_test, batch_size=100)
    logits = model.predict(X_test)
    Y_test = np.reshape(Y_test, (len(Y_test),1))
    loss = cce(Y_test, logits)
    logits = np.where(logits > 0.5, 1, 0)
    f1_score_acc = f1_score(Y_test.max(axis=1), logits.max(axis=1), average='macro')
    print('comm_round: {} | f1_score: {:.3%} | global_loss: {}'.format(comm_round, f1_score_acc, loss))
    return f1_score_acc, loss

def evaluating_model_own_validation_data_F1(model, val_data):
    cce = tf.keras.losses.BinaryCrossentropy(from_logits=True)
    logits = model.predict(val_data)
    y_true = np.concatenate([y for x, y in val_data], axis=0)
    y_true = np.reshape(y_true, (len(y_true),1))
    loss = cce(y_true, logits)
    logits = np.where(logits > 0.5, 1, 0)
    f1_score_acc = f1_score(y_true.max(axis=1), logits.max(axis=1), average='macro')
    print("Loss: " , loss)
    return f1_score_acc, loss

# %%
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=RANDOM_SEED)
skf.get_n_splits(vitals_features_reshaped, vitals_labels_reshaped)
# Out:
# 5

# %% [markdown]
# ### Training the model - Each client validate on their own data

# %%
loss_CV = []
acc_CV = []
f1_scores_averages_all = []
loss_values_averages_all = []
clients_number = 4
patience = 20
best_models = []
early_stopping_applied = []
test_batches_CV = []
for train_index, test_index in skf.split(vitals_features_reshaped, vitals_labels_reshaped):
    print("TRAIN:", train_index, "TEST:", test_index)
    X_train_vitals, X_test_vitals = vitals_features_reshaped[train_index], vitals_features_reshaped[test_index]
    X_train_labs, X_test_labs = labs_features_reshaped[train_index], labs_features_reshaped[test_index]
    y_train, y_test = vitals_labels_reshaped[train_index], vitals_labels_reshaped[test_index]
    clients = create_clients(X_train_labs, X_train_vitals ,y_train, num_clients=clients_number, initial='client')
    #process and batch the training data for each client
    clients_batched = dict()
    for (client_name, data) in clients.items():
        clients_batched[client_name] = batch_data(data)
    #Standardizing the testing set based on all training data
    X_train_labs = np.array(X_train_labs)
    samples_train, groupedBy_train, sample_values_train = X_train_labs.shape
    X_train_labs = np.reshape(X_train_labs, (samples_train*groupedBy_train,sample_values_train))
    samples_test, groupedBy_test, sample_values_test = X_test_labs.shape
    X_test_labs = np.reshape(X_test_labs, (samples_test*groupedBy_test,sample_values_test))
    scaler_labs = StandardScaler()
    scaler_labs = scaler_labs.fit(X_train_labs)
    X_test_labs = scaler_labs.transform(X_test_labs)
    X_test_labs = np.reshape(X_test_labs, (samples_test,groupedBy_test,sample_values_test))


    X_train_vitals = np.array(X_train_vitals)
    samples_train, groupedBy_train, sample_values_train = X_train_vitals.shape
    X_train_vitals = np.reshape(X_train_vitals, (samples_train*groupedBy_train,sample_values_train))
    samples_test, groupedBy_test, sample_values_test = X_test_vitals.shape
    X_test_vitals = np.reshape(X_test_vitals, (samples_test*groupedBy_test,sample_values_test))
    scaler_labs = StandardScaler()
    scaler_labs = scaler_labs.fit(X_train_vitals)
    X_test_vitals = scaler_labs.transform(X_test_vitals)
    X_test_vitals = np.reshape(X_test_vitals, (samples_test,groupedBy_test,sample_values_test))

    #process and batch the test set  
    test_batched = tf.data.Dataset.from_tensor_slices(({"Input_1": list(X_test_labs), 
    "Input_2": list(X_test_vitals)}, list(y_test))).batch(len(y_test))
    test_batches_CV.append(test_batched)
    #initialize global model
    f1_scores_averages = []
    loss_values_averages = []
    models_CV = []
    best_score = 0
    rounds_worse_than_before = 0    
    rnn_global = RNNModel()
    global_model = rnn_global.build()
    comms_round = 300
    loss = 'binary_crossentropy'
    metrics = ['accuracy']
    global_loss = []
    global_acc = []
    learning_rate = 0.01
    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
    counter = 0
    #commence global training loop
    for comm_round in range(comms_round):
        if comm_round % 5 == 0 and comm_round > 0:
            learning_rate = learning_rate * 0.5
            optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
        # get the global model's weights - will serve as the initial weights for all local models
        global_weights = global_model.get_weights()
        
        #initial list to collect local model weights after scalling
        scaled_local_weight_list = list()

        #randomize client data - using keys
        client_names= list(clients_batched.keys())
        random.shuffle(client_names)
        
        #loop through each client and create new local model
        for client in client_names:
            rnn_local = RNNModel()
            local_model = rnn_local.build()
            local_model.compile(loss=loss, 
                        optimizer=optimizer, 
                        metrics=metrics)
            
            #set local model weight to the weight of the global model
            local_model.set_weights(global_weights)

            #fit local model with client's data
            local_model.fit(clients_batched[client][0], epochs=3, verbose=0, validation_data=clients_batched[client][1])
            
            #scale the model weights and add to list
            scaling_factor = weight_scalling_factor(clients_batched, client)
            scaled_weights = scale_model_weights(local_model.get_weights(), scaling_factor)
            scaled_local_weight_list.append(scaled_weights)
            
            #clear session to free memory after each communication round
            K.clear_session()
            
        #to get the average over all the local model, we simply take the sum of the scaled weights
        average_weights = sum_scaled_weights(scaled_local_weight_list)
        
        #update global model 
        global_model.set_weights(average_weights)

        #evaluating the current global model against each clients validation data
        f1_scores = 0
        loss_values = 0
        for client in client_names:
            rnn_local = RNNModel()
            local_model = rnn_local.build()
            local_model.compile(loss=loss, 
                        optimizer=optimizer, 
                        metrics=metrics)     
            #set local model weight to the weight of the global model
            local_model.set_weights(global_weights)
            f1_score_acc, loss_value = evaluating_model_own_validation_data_F1(local_model, clients_batched[client][1])
            f1_scores += f1_score_acc
            loss_values += loss_value
        f1_scores = f1_scores / clients_number
        loss_values = loss_values / clients_number
        print("F1 Score average for round {} = {}, Loss: {}".format(comm_round, f1_scores, loss_values))
        models_CV.append(global_model)
        f1_scores_averages.append(f1_scores)
        loss_values_averages.append(loss_values)
        if  len(f1_scores_averages) == 1:
            best_score = f1_scores_averages[0]
        #checks for early stopping according to f1 score and patience
        if len(f1_scores_averages) > 1:
            if f1_scores_averages[-1] <= best_score:
                rounds_worse_than_before += 1
            else:
                rounds_worse_than_before = 0
                best_score = f1_scores_averages[-1]
        if rounds_worse_than_before == patience:
            break

    if rounds_worse_than_before == patience:
        f1_scores_averages_all.append(f1_scores_averages[:-patience])
        loss_values_averages_all.append(loss_values_averages[:-patience])
        best_models.append(models_CV[:-patience])
        early_stopping_applied.append(True)
    else:
        f1_scores_averages_all.append(f1_scores_averages)
        loss_values_averages_all.append(loss_values_averages)
        best_models.append(models_CV) 
        early_stopping_applied.append(False)
    print("CV Round complete")
# Out:
# TRAIN: [    0     1     3 ... 19410 19411 19413] TEST: [    2     4    17 ... 19399 19400 19412]
# Loss:  tf.Tensor(0.92789173, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.93148714, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.9281031, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.9279651, shape=(), dtype=float32)
# F1 Score average for round 0 = 0.17660552217058811, Loss: 0.9288617372512817
# Loss:  tf.Tensor(0.72875184, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7278492, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.72655296, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.72705674, shape=(), dtype=float32)
# F1 Score average for round 1 = 0.4934123449737322, Loss: 0.7275527119636536
# Loss:  tf.Tensor(0.7389385, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7381151, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7340759, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73110545, shape=(), dtype=float32)
# F1 Score average for round 2 = 0.4985033653451846, Loss: 0.7355587482452393
# Loss:  tf.Tensor(0.7481944, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75151926, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74845564, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7525147, shape=(), dtype=float32)
# F1 Score average for round 3 = 0.4873903065389493, Loss: 0.7501710653305054
# Loss:  tf.Tensor(0.74513245, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73539877, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73585045, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7424108, shape=(), dtype=float32)
# F1 Score average for round 4 = 0.4978738666534522, Loss: 0.739698052406311
# Loss:  tf.Tensor(0.7348599, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7357456, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7365626, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7394043, shape=(), dtype=float32)
# F1 Score average for round 5 = 0.49258639631698997, Loss: 0.7366430759429932
# Loss:  tf.Tensor(0.7401042, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74184716, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74179167, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73919004, shape=(), dtype=float32)
# F1 Score average for round 6 = 0.49700764145006493, Loss: 0.74073326587677
# Loss:  tf.Tensor(0.74272543, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7342819, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7434687, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73474926, shape=(), dtype=float32)
# F1 Score average for round 7 = 0.48935163290015127, Loss: 0.7388063669204712
# Loss:  tf.Tensor(0.7374777, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7398567, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7383186, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7390074, shape=(), dtype=float32)
# F1 Score average for round 8 = 0.491533109805808, Loss: 0.7386651635169983
# Loss:  tf.Tensor(0.73727095, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7356117, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73093486, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73348045, shape=(), dtype=float32)
# F1 Score average for round 9 = 0.50892379337569, Loss: 0.7343244552612305
# Loss:  tf.Tensor(0.7390886, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7376151, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74038374, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73707634, shape=(), dtype=float32)
# F1 Score average for round 10 = 0.48973062667614053, Loss: 0.7385408878326416
# Loss:  tf.Tensor(0.73911136, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74043906, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7384165, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7392511, shape=(), dtype=float32)
# F1 Score average for round 11 = 0.502048763115868, Loss: 0.7393044829368591
# Loss:  tf.Tensor(0.7397204, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73840696, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74187976, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73231333, shape=(), dtype=float32)
# F1 Score average for round 12 = 0.5045620979787516, Loss: 0.7380801439285278
# Loss:  tf.Tensor(0.7409949, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74021953, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73823464, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74476635, shape=(), dtype=float32)
# F1 Score average for round 13 = 0.49174838135599586, Loss: 0.7410538196563721
# Loss:  tf.Tensor(0.74230546, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74154127, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7404135, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7410007, shape=(), dtype=float32)
# F1 Score average for round 14 = 0.4850513771253988, Loss: 0.7413151860237122
# Loss:  tf.Tensor(0.7430843, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7433216, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7380107, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7431528, shape=(), dtype=float32)
# F1 Score average for round 15 = 0.4886352089127972, Loss: 0.7418923377990723
# Loss:  tf.Tensor(0.74828136, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7436385, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7389172, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73847765, shape=(), dtype=float32)
# F1 Score average for round 16 = 0.4948856438935525, Loss: 0.7423287034034729
# Loss:  tf.Tensor(0.7374782, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74857914, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74479675, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73781073, shape=(), dtype=float32)
# F1 Score average for round 17 = 0.4930688797293047, Loss: 0.7421661615371704
# Loss:  tf.Tensor(0.73812616, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7423968, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7429524, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7375806, shape=(), dtype=float32)
# F1 Score average for round 18 = 0.5031299519474696, Loss: 0.7402639389038086
# Loss:  tf.Tensor(0.7455521, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7426065, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7326774, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7438063, shape=(), dtype=float32)
# F1 Score average for round 19 = 0.4940859126627393, Loss: 0.7411606311798096
# Loss:  tf.Tensor(0.7425787, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73572737, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74041325, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.
, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74591005, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74007, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7389396, shape=(), dtype=float32)
# F1 Score average for round 65 = 0.5117481358699375, Loss: 0.7412653565406799
# Loss:  tf.Tensor(0.732536, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74371713, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74907506, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7457976, shape=(), dtype=float32)
# F1 Score average for round 66 = 0.5022900860151356, Loss: 0.7427814602851868
# Loss:  tf.Tensor(0.74445486, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7484989, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7390796, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74516577, shape=(), dtype=float32)
# F1 Score average for round 67 = 0.494718981782248, Loss: 0.7442997694015503
# Loss:  tf.Tensor(0.7374084, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73318124, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74665064, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74931914, shape=(), dtype=float32)
# F1 Score average for round 68 = 0.5102748173186862, Loss: 0.7416398525238037
# Loss:  tf.Tensor(0.7482528, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7398555, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74802774, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7339811, shape=(), dtype=float32)
# F1 Score average for round 69 = 0.5029100690509611, Loss: 0.7425293326377869
# Loss:  tf.Tensor(0.74764866, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7382441, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74072844, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7466131, shape=(), dtype=float32)
# F1 Score average for round 70 = 0.4973486374310595, Loss: 0.7433085441589355
# Loss:  tf.Tensor(0.7348402, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74571943, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7459942, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74222666, shape=(), dtype=float32)
# F1 Score average for round 71 = 0.5069037150982731, Loss: 0.7421951293945312
# Loss:  tf.Tensor(0.74703145, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7367522, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7370986, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75054353, shape=(), dtype=float32)
# F1 Score average for round 72 = 0.5026966164113547, Loss: 0.742856502532959
# Loss:  tf.Tensor(0.7399214, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7482256, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7433558, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73947936, shape=(), dtype=float32)
# F1 Score average for round 73 = 0.5013799011186816, Loss: 0.7427455186843872
# Loss:  tf.Tensor(0.746107, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73989546, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7426769, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7456167, shape=(), dtype=float32)
# F1 Score average for round 74 = 0.49694503581349786, Loss: 0.7435740232467651
# Loss:  tf.Tensor(0.739529, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74101806, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7463985, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7434766, shape=(), dtype=float32)
# F1 Score average for round 75 = 0.5017135781769348, Loss: 0.7426055669784546
# Loss:  tf.Tensor(0.7416071, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74500686, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7478786, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74140084, shape=(), dtype=float32)
# F1 Score average for round 76 = 0.4968571183138496, Loss: 0.7439733743667603
# Loss:  tf.Tensor(0.7429621, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75366724, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7541973, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7442861, shape=(), dtype=float32)
# F1 Score average for round 77 = 0.4681039678125606, Loss: 0.7487781643867493
# Loss:  tf.Tensor(0.7393135, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7495744, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7450687, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7442372, shape=(), dtype=float32)
# F1 Score average for round 78 = 0.4895194732992279, Loss: 0.7445484399795532
# CV Round complete

# %% [markdown]
# # Results for Early Stopping when monitoring the average F1 Score value of all the clients using their own validation data

# %%
plt.subplot(2,1,1)
for i in range(len(loss_values_averages_all)):
    plt.plot(loss_values_averages_all[i])
plt.title('models\' loss')
plt.ylabel('loss')
plt.xlabel('Communication rounds')
plt.legend(['fold1', 'fold2','fold3', 'fold4', 'fold5'], loc='lower right')
plt.savefig("Model's Validation loss vs Communication Rounds - First technique with F1-Score - 20 patience")

# %%
plt.subplot(2,1,1)
for i in range(len(f1_scores_averages_all)):
    plt.plot(f1_scores_averages_all[i])
plt.title('models\' F1 Score')
plt.ylabel('Loss')
plt.xlabel('Communication rounds')
plt.legend(['fold1', 'fold2','fold3', 'fold4', 'fold5'], loc='lower right')
plt.savefig("Model's F1-Score vs Communication Rounds - First technique with F1-Score - 20 patience")

# %%
from sklearn.metrics import classification_report
average_f1_score = 0
#Confution Matrix and Classification Report
for i in range(len(best_models)):
    Y_pred = best_models[i][-1].predict(test_batches_CV[i])
    y_pred = np.where(Y_pred > 0.5, 1, 0)
    print('Confusion Matrix')
    y_pred = y_pred.max(axis=1)
    y_true = np.concatenate([y for x, y in test_batches_CV[i]], axis=0)
    print(confusion_matrix(y_true, y_pred, labels=[True, False]))
    f1_score_acc = f1_score(y_true, y_pred, average='macro')
    average_f1_score += f1_score_acc
    print("F1 Score: {}".format(f1_score_acc))
    print(classification_report(y_true, y_pred, target_names=['Class 0', 'Class 1']))
average_f1_score = average_f1_score / len(best_models)
print("Average F1 Score: {}".format(average_f1_score))
# Out:
# Confusion Matrix
# [[ 289   89]
#  [  91 3414]]
# F1 Score: 0.8684240250117468
#               precision    recall  f1-score   support
#
#      Class 0       0.97      0.97      0.97      3505
#      Class 1       0.76      0.76      0.76       378
#
#     accuracy                           0.95      3883
#    macro avg       0.87      0.87      0.87      3883
# weighted avg       0.95      0.95      0.95      3883
#
# Confusion Matrix
# [[ 308   70]
#  [  70 3435]]
# F1 Score: 0.8974216727426427
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.98      0.98      3505
#      Class 1       0.81      0.81      0.81       378
#
#     accuracy                           0.96      3883
#    macro avg       0.90      0.90      0.90      3883
# weighted avg       0.96      0.96      0.96      3883
#
# Confusion Matrix
# [[ 300   79]
#  [  82 3422]]
# F1 Score: 0.8827263424567209
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.98      0.98      3504
#      Class 1       0.79      0.79      0.79       379
#
#     accuracy                           0.96      3883
#    macro avg       0.88      0.88      0.88      3883
# weighted avg       0.96      0.96      0.96      3883
#
# WARNING:tensorflow:5 out of the last 14 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002040DAFA950> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Confusion Matrix
# [[ 291   88]
#  [  67 3437]]
# F1 Score: 0.8838182115457711
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.98      0.98      3504
#      Class 1       0.81      0.77      0.79       379
#
#     accuracy                           0.96      3883
#    macro avg       0.89      0.87      0.88      3883
# weighted avg       0.96      0.96      0.96      3883
#
# WARNING:tensorflow:6 out of the last 15 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002040F6160D0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Confusion Matrix
# [[ 286   92]
#  [  83 3421]]
# F1 Score: 0.8703950761003254
#               precision    recall  f1-score   support
#
#      Class 0       0.97      0.98      0.98      3504
#      Class 1       0.78      0.76      0.77       378
#
#     accuracy                           0.95      3882
#    macro avg       0.87      0.87      0.87      3882
# weighted avg       0.95      0.95      0.95      3882
#
# Average F1 Score: 0.8805570655714414

# %%
import sklearn.metrics as metrics

for i in range(len(best_models)):
    Y_pred = best_models[i][-1].predict(test_batches_CV[i])
    y_pred = np.where(Y_pred > 0.5, 1, 0)
    y_pred = y_pred.max(axis=1)
    y_true = np.concatenate([y for x, y in test_batches_CV[i]], axis=0)
    fpr, tpr, threshold = metrics.roc_curve(y_true, y_pred)
    roc_auc = metrics.auc(fpr, tpr)
    print("FPR: ", fpr)
    print("TPR: ", tpr)
    # method I: plt
    plt.title('Receiver Operating Characteristic')
    plt.plot(fpr, tpr, 'b', label = 'AUC = %0.4f' % roc_auc)
    plt.legend(loc = 'lower right')
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([0, 1])
    plt.ylim([0, 1])
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()
# Out:
# FPR:  [0.         0.02596291 1.        ]
# TPR:  [0.         0.76455026 1.        ]
# FPR:  [0.         0.01997147 1.        ]
# TPR:  [0.         0.81481481 1.        ]
# FPR:  [0.         0.02340183 1.        ]
# TPR:  [0.         0.79155673 1.        ]
# FPR:  [0.       0.019121 1.      ]
# TPR:  [0.         0.76781003 1.        ]
# FPR:  [0.         0.02368721 1.        ]
# TPR:  [0.         0.75661376 1.        ]

# %%
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import auc

for i in range(len(best_models)):
    Y_pred = best_models[i][-1].predict(test_batches_CV[i])
    y_pred = np.where(Y_pred > 0.5, 1, 0)
    y_pred = y_pred.max(axis=1)
    y_true = np.concatenate([y for x, y in test_batches_CV[i]], axis=0)
    lr_precision, lr_recall, _ = precision_recall_curve(y_true, y_pred)
    lr_f1, lr_auc = f1_score(y_true, y_pred, average='macro'), auc(lr_recall, lr_precision)
    # summarize scores
    print("Precision: ", lr_precision)
    print("Recall: ", lr_recall)
    print('Logistic: f1=%.3f auc=%.3f' % (lr_f1, lr_auc))
    # plot the precision-recall curves
    no_skill = len(y_true[y_true==1]) / len(y_true)
    plt.plot([0, 1], [no_skill, no_skill], linestyle='--')
    plt.plot(lr_recall, lr_precision, marker='.', label = 'AUC = %0.4f' % lr_auc)
    # axis labels
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    # show the legend
    plt.legend()
    # show the plot
    plt.show()
# Out:
# Precision:  [0.09734741 0.76052632 1.        ]
# Recall:  [1.         0.76455026 0.        ]
# Logistic: f1=0.868 auc=0.774
# Precision:  [0.09734741 0.81481481 1.        ]
# Recall:  [1.         0.81481481 0.        ]
# Logistic: f1=0.897 auc=0.824
# Precision:  [0.09760494 0.78534031 1.        ]
# Recall:  [1.         0.79155673 0.        ]
# Logistic: f1=0.883 auc=0.799
# Precision:  [0.09760494 0.81284916 1.        ]
# Recall:  [1.         0.76781003 0.        ]
# Logistic: f1=0.884 auc=0.802
# Precision:  [0.09737249 0.77506775 1.        ]
# Recall:  [1.         0.75661376 0.        ]
# Logistic: f1=0.870 auc=0.778
