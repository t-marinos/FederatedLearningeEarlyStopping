# %%
import pandas as pd
import numpy as np
import random
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.utils.vis_utils import plot_model
from tensorflow.keras.layers import LSTM, Dense, Input, add, concatenate
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K

RANDOM_SEED = 42
random.seed(RANDOM_SEED)
# Out:
# c:\Users\Theo\AppData\Local\Programs\Python\Python37\lib\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# c:\Users\Theo\AppData\Local\Programs\Python\Python37\lib\site-packages\numpy\.libs\libopenblas.IPBC74C7KURV7CB2PKT5Z5FNR3SIBV4J.gfortran-win_amd64.dll
# c:\Users\Theo\AppData\Local\Programs\Python\Python37\lib\site-packages\numpy\.libs\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll
#   stacklevel=1)

# %%
vitals = pd.read_csv('vitals.csv')  
labs = pd.read_csv('labs.csv')

# %% [markdown]
# Changing the date to datetime variable and setting indexes

# %%
vitals['charttime'] = pd.to_datetime(vitals['charttime'] , infer_datetime_format=True)
labs['charttime'] = pd.to_datetime(labs['charttime'] , infer_datetime_format=True)

# %%
vitals_48hours_grouped = vitals.groupby('icustay_id').tail(48)

# %%
labs_48hours_grouped = labs.groupby('icustay_id').tail(6)

# %%
print((vitals_48hours_grouped.icustay_id.value_counts() == 48).sum() == len(vitals_48hours_grouped) /48)
print((labs_48hours_grouped.icustay_id.value_counts() == 6).sum() == len(labs_48hours_grouped) /6)
# Out:
# True
# True

# %%
vitals_48hours_grouped = vitals_48hours_grouped.drop(['icustay_id','charttime'], axis=1)
labs_48hours_grouped = labs_48hours_grouped.drop(['icustay_id','charttime'], axis=1)

# %%
vitals_features = vitals_48hours_grouped.iloc[:,:-1]
vitals_labels = vitals_48hours_grouped.iloc[:,-1:].to_numpy().tolist()

# %%
labs_features = labs_48hours_grouped.iloc[:,:-1]
labs_labels = labs_48hours_grouped.iloc[:,-1:].to_numpy().tolist()

# %% [markdown]
# # Federated Learning Setup

# %%
def create_clients(labs_data, vitals_data, label_list, num_clients=4, initial='clients'):
    ''' return: a dictionary with keys clients' names and value as 
                data shards - tuple of images and label lists.
        args: 
            image_list: a list of numpy arrays of training images
            label_list:a list of binarized labels for each image
            num_client: number of fedrated members (clients)
            initials: the clients'name prefix, e.g, clients_1 
            
    '''

    #create a list of client names
    client_names = ['{}_{}'.format(initial, i+1) for i in range(num_clients)]

    #randomize the data
    data = list(zip(labs_data, vitals_data))
    data = list(zip(data, label_list))
    random.shuffle(data)

    #shard data and place at each client
    size = len(data)//num_clients
    shards = [data[i:i + size] for i in range(0, size*num_clients, size)]

    #number of clients must equal number of shards
    assert(len(shards) == len(client_names))
    
    return  {client_names[i] : shards[i] for i in range(len(client_names))}

# %% [markdown]
# ## Reshaping data and preparing them for cross validation

# %%
vitals_labels = np.array(vitals_labels)
labs_labels = np.array(labs_labels)


labs_labels_reshaped = np.reshape(labs_labels, (19414,6))
labs_labels_reshaped = np.amax(labs_labels_reshaped, axis=1)

vitals_labels_reshaped = np.reshape(vitals_labels, (19414,48))
vitals_labels_reshaped = np.amax(vitals_labels_reshaped, axis=1)
print(labs_labels_reshaped.shape)
print(vitals_labels_reshaped.shape)
# Out:
# (19414,)
# (19414,)

# %%
vitals_features_reshaped = np.reshape(vitals_features.values, (19414,48,7))
print(vitals_features_reshaped.shape)
labs_features_reshaped = np.reshape(labs_features.values, (19414,6,16))
print(labs_features_reshaped.shape)
# Out:
# (19414, 48, 7)
# (19414, 6, 16)

# %% [markdown]
# ### Batching clients and test data

# %%
def batch_data(data_shard, bs=64):
    '''Takes in a clients data shard and create a tfds object off it
    args:
        shard: a data, label constituting a client's data shard
        bs:batch size
    return:
        tfds object'''
    #seperate shard into data and labels lists
    data, label = zip(*data_shard)
    dataset = []
    X_train, X_test, y_train, y_test = train_test_split(data, label, test_size=0.15, random_state=RANDOM_SEED, stratify=label)
    X_labs_train , X_vitals_train = zip(*X_train)
    X_labs_test , X_vitals_test = zip(*X_test)

    #Reshaping to standardize the laboratory values
    X_labs_train = np.array(X_labs_train)
    X_labs_test = np.array(X_labs_test)
    samples_train, groupedBy_train, sample_values_train = X_labs_train.shape
    samples_test, groupedBy_test, sample_values_test = X_labs_test.shape
    X_labs_train_reshaped = np.reshape(X_labs_train, (samples_train*groupedBy_train, sample_values_train))
    X_labs_test_reshaped = np.reshape(X_labs_test, (samples_test*groupedBy_test, sample_values_test))
    #Standardizing the laboratory values
    scaler_labs = StandardScaler()
    scaler_labs = scaler_labs.fit(X_labs_train_reshaped)
    X_labs_train_reshaped = scaler_labs.transform(X_labs_train_reshaped)
    X_labs_test_reshaped = scaler_labs.transform(X_labs_test_reshaped)
    #Reshaping again
    X_labs_train = np.reshape(X_labs_train_reshaped,  (samples_train, groupedBy_train, sample_values_train))
    X_labs_test = np.reshape(X_labs_test_reshaped, (samples_test, groupedBy_test, sample_values_test))

    #Reshaping to standardize the laboratory values
    X_vitals_train = np.array(X_vitals_train)
    X_vitals_test = np.array(X_vitals_test)
    samples_train, groupedBy_train, sample_values_train = X_vitals_train.shape
    samples_test, groupedBy_test, sample_values_test = X_vitals_test.shape
    X_vitals_train_reshaped = np.reshape(X_vitals_train, (samples_train*groupedBy_train, sample_values_train))
    X_vitals_test_reshaped = np.reshape(X_vitals_test, (samples_test*groupedBy_test, sample_values_test))
    #Standardizing the laboratory values
    scaler_vitals = StandardScaler()
    scaler_vitals = scaler_vitals.fit(X_vitals_train_reshaped)
    X_vitals_train_reshaped = scaler_vitals.transform(X_vitals_train_reshaped)
    X_vitals_test_reshaped = scaler_vitals.transform(X_vitals_test_reshaped)
    #Reshaping again
    X_vitals_train = np.reshape(X_vitals_train_reshaped,  (samples_train, groupedBy_train, sample_values_train))
    X_vitals_test = np.reshape(X_vitals_test_reshaped, (samples_test, groupedBy_test, sample_values_test))

    combinedDatasetTraining = tf.data.Dataset.from_tensor_slices(({"Input_1": list(X_labs_train), "Input_2": list(X_vitals_train)}, list(y_train)))
    combinedDatasetTraining = combinedDatasetTraining.shuffle(len(y_train)).batch(bs)
    combinedDatasetTesting = tf.data.Dataset.from_tensor_slices(({"Input_1": list(X_labs_test), "Input_2": list(X_vitals_test)}, list(y_test)))
    combinedDatasetTesting = combinedDatasetTesting.shuffle(len(y_test)).batch(bs)
    
    dataset.append(combinedDatasetTraining)
    dataset.append(combinedDatasetTesting)
    return dataset

# %% [markdown]
# ### Creating the Model

# %%
class RNNModel:
    @staticmethod
    def build():
     input1 = Input(shape=(6,16), name='Input_1')
     fe1 = LSTM(16, input_shape= (6,16), return_sequences=True)(input1)
     fe2 = LSTM(16, return_sequences=True)(fe1)
     fe3 = LSTM(16)(fe2)
#sequence model
     input2 = Input(shape=(48,7), name='Input_2')
     se1 = LSTM(16, input_shape= (48,7), return_sequences=True)(input2)
     se2 = LSTM(16, return_sequences=True)(se1)
     se3 = LSTM(16)(se2)
#decoder model
     decoder1 = concatenate([fe3, se3])
     decoder2 = Dense(16, activation='relu')(decoder1)
     decoder3 = Dense(16, activation='relu')(decoder2)
     output = Dense(1, activation='sigmoid')(decoder3)
#connecting the two models
     model = Model(inputs=[input1, input2], outputs=output)
     return model

# %% [markdown]
# ### Federated Averaging

# %%
def weight_scalling_factor(clients_trn_data, client_name):
    '''Gets batch size and calculates total datapoints and how many data points the client has to scale it'''
    client_names = list(clients_trn_data.keys())
    #get the bs
    bs = list(clients_trn_data[client_name][0])[0][0]['Input_1'].shape[0]
    #first calculate the total training data points across clinets
    global_count = sum([tf.data.experimental.cardinality(clients_trn_data[client_name][0]).numpy() for client_name in client_names])*bs
    # get the total number of data points held by a client
    local_count = tf.data.experimental.cardinality(clients_trn_data[client_name][0]).numpy()*bs
    return local_count/global_count


def scale_model_weights(weight, scalar):
    '''function for scaling a models weights'''
    weight_final = []
    steps = len(weight)
    for i in range(steps):
        weight_final.append(scalar * weight[i])
    return weight_final



def sum_scaled_weights(scaled_weight_list):
    '''Return the sum of the listed scaled weights. The is equivalent to scaled avg of the weights'''
    avg_grad = list()
    #get the average grad accross all client gradients
    for grad_list_tuple in zip(*scaled_weight_list):
        layer_mean = tf.math.reduce_sum(grad_list_tuple, axis=0)
        avg_grad.append(layer_mean)
        
    return avg_grad


def test_model(X_test, Y_test,  model, comm_round):
    cce = tf.keras.losses.BinaryCrossentropy(from_logits=True)
    #logits = model.predict(X_test, batch_size=100)
    logits = model.predict(X_test)
    Y_test = np.reshape(Y_test, (len(Y_test),1))
    loss = cce(Y_test, logits)
    logits = np.where(logits > 0.5, 1, 0)
    f1_score_acc = f1_score(Y_test.max(axis=1), logits.max(axis=1), average='macro')
    print('comm_round: {} | f1_score: {:.3%} | global_loss: {}'.format(comm_round, f1_score_acc, loss))
    return f1_score_acc, loss

def evaluating_model_own_validation_data_F1(model, val_data):
    cce = tf.keras.losses.BinaryCrossentropy(from_logits=True)
    logits = model.predict(val_data)
    y_true = np.concatenate([y for x, y in val_data], axis=0)
    y_true = np.reshape(y_true, (len(y_true),1))
    loss = cce(y_true, logits)
    logits = np.where(logits > 0.5, 1, 0)
    f1_score_acc = f1_score(y_true.max(axis=1), logits.max(axis=1), average='macro')
    print("Loss: " , loss)
    return f1_score_acc, loss

# %%
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=RANDOM_SEED)
skf.get_n_splits(vitals_features_reshaped, vitals_labels_reshaped)
# Out:
# 5

# %% [markdown]
# ### Training the model - Each client validate on their own data

# %%
loss_CV = []
acc_CV = []
f1_scores_averages_all = []
loss_values_averages_all = []
clients_number = 4
patience = 40
best_models = []
early_stopping_applied = []
test_batches_CV = []
for train_index, test_index in skf.split(vitals_features_reshaped, vitals_labels_reshaped):
    print("TRAIN:", train_index, "TEST:", test_index)
    X_train_vitals, X_test_vitals = vitals_features_reshaped[train_index], vitals_features_reshaped[test_index]
    X_train_labs, X_test_labs = labs_features_reshaped[train_index], labs_features_reshaped[test_index]
    y_train, y_test = vitals_labels_reshaped[train_index], vitals_labels_reshaped[test_index]
    clients = create_clients(X_train_labs, X_train_vitals ,y_train, num_clients=clients_number, initial='client')
    #process and batch the training data for each client
    clients_batched = dict()
    for (client_name, data) in clients.items():
        clients_batched[client_name] = batch_data(data)
    #Standardizing the testing set based on all training data
    X_train_labs = np.array(X_train_labs)
    samples_train, groupedBy_train, sample_values_train = X_train_labs.shape
    X_train_labs = np.reshape(X_train_labs, (samples_train*groupedBy_train,sample_values_train))
    samples_test, groupedBy_test, sample_values_test = X_test_labs.shape
    X_test_labs = np.reshape(X_test_labs, (samples_test*groupedBy_test,sample_values_test))
    scaler_labs = StandardScaler()
    scaler_labs = scaler_labs.fit(X_train_labs)
    X_test_labs = scaler_labs.transform(X_test_labs)
    X_test_labs = np.reshape(X_test_labs, (samples_test,groupedBy_test,sample_values_test))


    X_train_vitals = np.array(X_train_vitals)
    samples_train, groupedBy_train, sample_values_train = X_train_vitals.shape
    X_train_vitals = np.reshape(X_train_vitals, (samples_train*groupedBy_train,sample_values_train))
    samples_test, groupedBy_test, sample_values_test = X_test_vitals.shape
    X_test_vitals = np.reshape(X_test_vitals, (samples_test*groupedBy_test,sample_values_test))
    scaler_labs = StandardScaler()
    scaler_labs = scaler_labs.fit(X_train_vitals)
    X_test_vitals = scaler_labs.transform(X_test_vitals)
    X_test_vitals = np.reshape(X_test_vitals, (samples_test,groupedBy_test,sample_values_test))

    #process and batch the test set  
    test_batched = tf.data.Dataset.from_tensor_slices(({"Input_1": list(X_test_labs), 
    "Input_2": list(X_test_vitals)}, list(y_test))).batch(len(y_test))
    test_batches_CV.append(test_batched)
    #initialize global model
    f1_scores_averages = []
    loss_values_averages = []
    models_CV = []
    best_score = 0
    rounds_worse_than_before = 0    
    rnn_global = RNNModel()
    global_model = rnn_global.build()
    comms_round = 300
    loss = 'binary_crossentropy'
    metrics = ['accuracy']
    global_loss = []
    global_acc = []
    learning_rate = 0.01
    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
    counter = 0
    #commence global training loop
    for comm_round in range(comms_round):
        if comm_round % 5 == 0 and comm_round > 0:
            learning_rate = learning_rate * 0.5
            optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
        # get the global model's weights - will serve as the initial weights for all local models
        global_weights = global_model.get_weights()
        
        #initial list to collect local model weights after scalling
        scaled_local_weight_list = list()

        #randomize client data - using keys
        client_names= list(clients_batched.keys())
        random.shuffle(client_names)
        
        #loop through each client and create new local model
        for client in client_names:
            rnn_local = RNNModel()
            local_model = rnn_local.build()
            local_model.compile(loss=loss, 
                        optimizer=optimizer, 
                        metrics=metrics)
            
            #set local model weight to the weight of the global model
            local_model.set_weights(global_weights)

            #fit local model with client's data
            local_model.fit(clients_batched[client][0], epochs=3, verbose=0, validation_data=clients_batched[client][1])
            
            #scale the model weights and add to list
            scaling_factor = weight_scalling_factor(clients_batched, client)
            scaled_weights = scale_model_weights(local_model.get_weights(), scaling_factor)
            scaled_local_weight_list.append(scaled_weights)
            
            #clear session to free memory after each communication round
            K.clear_session()
            
        #to get the average over all the local model, we simply take the sum of the scaled weights
        average_weights = sum_scaled_weights(scaled_local_weight_list)
        
        #update global model 
        global_model.set_weights(average_weights)

        #evaluating the current global model against each clients validation data
        f1_scores = 0
        loss_values = 0
        for client in client_names:
            rnn_local = RNNModel()
            local_model = rnn_local.build()
            local_model.compile(loss=loss, 
                        optimizer=optimizer, 
                        metrics=metrics)     
            #set local model weight to the weight of the global model
            local_model.set_weights(global_weights)
            f1_score_acc, loss_value = evaluating_model_own_validation_data_F1(local_model, clients_batched[client][1])
            f1_scores += f1_score_acc
            loss_values += loss_value
        f1_scores = f1_scores / clients_number
        loss_values = loss_values / clients_number
        print("F1 Score average for round {} = {}, Loss: {}".format(comm_round, f1_scores, loss_values))
        models_CV.append(global_model)
        f1_scores_averages.append(f1_scores)
        loss_values_averages.append(loss_values)
        if  len(f1_scores_averages) == 1:
            best_score = f1_scores_averages[0]
        #checks for early stopping according to f1 score and patience
        if len(f1_scores_averages) > 1:
            if f1_scores_averages[-1] <= best_score:
                rounds_worse_than_before += 1
            else:
                rounds_worse_than_before = 0
                best_score = f1_scores_averages[-1]
        if rounds_worse_than_before == patience:
            break

    if rounds_worse_than_before == patience:
        f1_scores_averages_all.append(f1_scores_averages[:-patience])
        loss_values_averages_all.append(loss_values_averages[:-patience])
        best_models.append(models_CV[:-patience])
        early_stopping_applied.append(True)
    else:
        f1_scores_averages_all.append(f1_scores_averages)
        loss_values_averages_all.append(loss_values_averages)
        best_models.append(models_CV) 
        early_stopping_applied.append(False)
    print("CV Round complete")
# Out:
# TRAIN: [    0     1     3 ... 19410 19411 19413] TEST: [    2     4    17 ... 19399 19400 19412]
# Loss:  tf.Tensor(0.9207953, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.9241134, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.9205956, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.92089874, shape=(), dtype=float32)
# F1 Score average for round 0 = 0.5094011531868334, Loss: 0.9216007590293884
# Loss:  tf.Tensor(0.7488024, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75564814, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7528921, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.752306, shape=(), dtype=float32)
# F1 Score average for round 1 = 0.49441600765019666, Loss: 0.7524121403694153
# Loss:  tf.Tensor(0.74403036, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74198353, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74103343, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7404129, shape=(), dtype=float32)
# F1 Score average for round 2 = 0.49761148905434993, Loss: 0.7418650984764099
# Loss:  tf.Tensor(0.73343444, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73095423, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7381669, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.731847, shape=(), dtype=float32)
# F1 Score average for round 3 = 0.49520392207769925, Loss: 0.7336006760597229
# Loss:  tf.Tensor(0.7306766, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7351694, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7325201, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73212373, shape=(), dtype=float32)
# F1 Score average for round 4 = 0.5110923240368124, Loss: 0.732622504234314
# Loss:  tf.Tensor(0.73778206, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7411037, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7328807, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73719966, shape=(), dtype=float32)
# F1 Score average for round 5 = 0.4917662688291028, Loss: 0.7372415065765381
# Loss:  tf.Tensor(0.7340149, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7347976, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74147564, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7442144, shape=(), dtype=float32)
# F1 Score average for round 6 = 0.5038160438629248, Loss: 0.7386256456375122
# Loss:  tf.Tensor(0.7371678, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7421241, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73187286, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7330635, shape=(), dtype=float32)
# F1 Score average for round 7 = 0.5093564990970576, Loss: 0.7360570430755615
# Loss:  tf.Tensor(0.7386146, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7403575, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7381031, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7397421, shape=(), dtype=float32)
# F1 Score average for round 8 = 0.4975966297187184, Loss: 0.7392043471336365
# Loss:  tf.Tensor(0.7397348, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73521936, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.734972, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7319019, shape=(), dtype=float32)
# F1 Score average for round 9 = 0.5085778467488035, Loss: 0.7354570031166077
# Loss:  tf.Tensor(0.737468, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74011517, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73521805, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7410976, shape=(), dtype=float32)
# F1 Score average for round 10 = 0.49292271651538533, Loss: 0.7384747266769409
# Loss:  tf.Tensor(0.74008334, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7501206, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7423744, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7428935, shape=(), dtype=float32)
# F1 Score average for round 11 = 0.48865398138967386, Loss: 0.7438679337501526
# Loss:  tf.Tensor(0.7393267, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73859227, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74229604, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7422159, shape=(), dtype=float32)
# F1 Score average for round 12 = 0.511107742544302, Loss: 0.740607738494873
# Loss:  tf.Tensor(0.7469689, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7338918, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73874533, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74053633, shape=(), dtype=float32)
# F1 Score average for round 13 = 0.5071000038885567, Loss: 0.7400355339050293
# Loss:  tf.Tensor(0.7299317, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7425548, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73957455, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74545854, shape=(), dtype=float32)
# F1 Score average for round 14 = 0.5163935913931091, Loss: 0.7393798828125
# Loss:  tf.Tensor(0.7379988, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7446858, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74658096, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73760223, shape=(), dtype=float32)
# F1 Score average for round 15 = 0.4940299773209615, Loss: 0.7417169809341431
# Loss:  tf.Tensor(0.7396007, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74780875, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7435055, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7476816, shape=(), dtype=float32)
# F1 Score average for round 16 = 0.488177450334483, Loss: 0.7446491718292236
# Loss:  tf.Tensor(0.7436156, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7434359, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7432975, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74359745, shape=(), dtype=float32)
# F1 Score average for round 17 = 0.49493784695401516, Loss: 0.7434866428375244
# Loss:  tf.Tensor(0.7426783, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7397357, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7437914, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74730927, shape=(), dtype=float32)
# F1 Score average for round 18 = 0.49423133030657407, Loss: 0.7433786392211914
# Loss:  tf.Tensor(0.7394577, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74489003, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74545413, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.740147, shape=(), dtype=float32)
# F1 Score average for round 19 = 0.4988764158028861, Loss: 0.7424871921539307
# Loss:  tf.Tensor(0.73015815, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73538405, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74120456, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7442162, shape=(), dtype=float32)
# F1 Score average for round 20 = 0.5206289863558118, Loss: 0.7377407550811768
# Loss:  tf.Tensor(0.7479497, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7431977, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7366198, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74274135, shape=(), dtype=float32)
# F1 Score average for round 21 = 0.4953267603300167, Loss: 0.7426271438598633
# Loss:  tf.Tensor(0.74047893, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74064505, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.744854, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74427325, shape=(), dtype=float32)
# F1 Score average for round 22 = 0.4939228445134434, Loss: 0.7425627708435059
# Loss:  tf.Tensor(0.73934525, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7498053, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7411439, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73835754, shape=(), dtype=float32)
# F1 Score average for round 23 = 0.4953067317294953, Loss: 0.7421630024909973
# Loss:  tf.Tensor(0.73892576, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7431956, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7352714, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7468995, shape=(), dtype=float32)
# F1 Score average for round 24 = 0.49517339163448476, Loss: 0.7410730123519897
# Loss:  tf.Tensor(0.7387604, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7440816, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7475671, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7358908, shape=(), dtype=float32)
# F1 Score average for round 25 = 0.49609409914412556, Loss: 0.7415750026702881
# Loss:  tf.Tensor(0.75002354, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7415486, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73561454, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7344182, shape=(), dtype=float32)
# F1 Score average for round 26 = 0.5099092028316217, Loss: 0.7404012084007263
# Loss:  tf.Tensor(0.7436761, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74965256, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74000806, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7383641, shape=(), dtype=float32)
# F1 Score average for round 27 = 0.4914369694801493, Loss: 0.7429251670837402
# Loss:  tf.Tensor(0.74941343, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7429017, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7350094, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7395069, shape=(), dtype=float32)
# F1 Score average for round 28 = 0.5000127914452729, Loss: 0.7417078614234924
# Loss:  tf.Tensor(0.7396863, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7342428, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74959475, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73279005, shape=(), dtype=float32)
# F1 Score average for round 29 = 0.5170616079448438, Loss: 0.7390784621238708
# Loss:  tf.Tensor(0.7426517, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74435276, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74343807, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7400681, shape=(), dtype=float32)
# F1 Score average for round 30 = 0.49410420792134657, Loss: 0.7426276206970215
# Loss:  tf.Tensor(0.75267047, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74016064, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7390368, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7392481, shape=(), dtype=float32)
# F1 Score average for round 31 = 0.497497008269437, Loss: 0.7427789568901062
# Loss:  tf.Tensor(0.7482731, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7403382, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73963, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7466352, shape=(), dtype=float32)
# F1 Score average for round 32 = 0.4917471587057023, Loss: 0.7437191009521484
# Loss:  tf.Tensor(0.7421601, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73772323, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7514441, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7483104, shape=(), dtype=float32)
# F1 Score average for round 33 = 0.4846628358817674, Loss: 0.7449094653129578
# Loss:  tf.Tensor(0.7419803, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7408535, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7376906, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7432706, shape=(), dtype=float32)
# F1 Score average for round 34 = 0.5080291726491024, Loss: 0.7409487962722778
# Loss:  tf.Tensor(0.7355437, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7414225, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7499688, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74364084, shape=(), dtype=float32)
# F1 Score average for round 35 = 0.49950158552476587, Loss: 0.7426439523696899
# Loss:  tf.Tensor(0.748227, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74546874, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7409612, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7413452, shape=(), dtype=float32)
# F1 Score average for round 36 = 0.49339766866011303, Loss: 0.7440004944801331
# Loss:  tf.Tensor(0.7455395, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7424077, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7471243, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7472519, shape=(), dtype=float32)
# F1 Score average for round 37 = 0.48331343228126955, Loss: 0.7455809116363525
# Loss:  tf.Tensor(0.7431943, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7393973, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7410438, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74831265, shape=(), dtype=float32)
# F1 Score average for round 38 = 0.5008427776647139, Loss: 0.7429870367050171
# Loss:  tf.Tensor(0.7343182, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7456003, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75202, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74236554, shape=(), dtype=float32)
# F1 Score average for round 39 = 0.49657834251433397, Loss: 0.7435759902000427
# Loss:  tf.Tensor(0.74287885, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7420561, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73725927, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7525013, shape=(), dtype=float32)
# F1 Score average for round 40 = 0.4963332500487728, Loss: 0.7436738610267639
# Loss:  tf.Tensor(0.73544, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7458176, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75032115, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7410265, shape=(), dtype=float32)
# F1 Score average for round 41 = 0.4981259915947649, Loss: 0.7431513071060181
# Loss:  tf.Tensor(0.733783, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7522563, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73968744, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73562545, shape=(), dtype=float32)
# F1 Score average for round 42 = 0.5163584277651578, Loss: 0.7403380274772644
# Loss:  tf.Tensor(0.7461675, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7391038, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74616003, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75564647, shape=(), dtype=float32)
# F1 Score average for round 43 = 0.4787633654796213, Loss: 0.7467694282531738
# Loss:  tf.Tensor(0.73921317, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.752133, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7402407, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7405853, shape=(), dtype=float32)
# F1 Score average for round 44 = 0.4986567656392811, Loss: 0.743043065071106
# Loss:  tf.Tensor(0.74890584, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7368996, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7405121, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7411993, shape=(), dtype=float32)
# F1 Score average for round 45 = 0.5057038040240094, Loss: 0.7418792247772217
# Loss:  tf.Tensor(0.7478286, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7341388, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7393124, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7437237, shape=(), dtype=float32)
# F1 Score average for round 46 = 0.5133946756368756, Loss: 0.7412508726119995
# Loss:  tf.Tensor(0.74743956, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.742899, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73752725, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74228215, shape=(), dtype=float32)
# F1 Score average for round 47 = 0.5027063591286862, Loss: 0.7425369620323181
# Loss:  tf.Tensor(0.735474, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7438597, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7548286, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7455666, shape=(), dtype=float32)
# F1 Score average for round 48 = 0.486934431277631, Loss: 0.744932234287262
# Loss:  tf.Tensor(0.7536741, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7430416, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7383751, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74202394, shape=(), dtype=float32)
# F1 Score average for round 49 = 0.49092778377390534, Loss: 0.7442786693572998
# Loss:  tf.Tensor(0.74398726, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.736751, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7397048, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74849534, shape=(), dtype=float32)
# F1 Score average for round 50 = 0.5052307842942605, Loss: 0.7422345876693726
# Loss:  tf.Tensor(0.7419298, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7477849, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7311032, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7409184, shape=(), dtype=float32)
# F1 Score average for round 51 = 0.5137278971078696, Loss: 0.7404341101646423
# Loss:  tf.Tensor(0.7509661, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7441652, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7405365, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73783404, shape=(), dtype=float32)
# F1 Score average for round 52 = 0.4984188541526984, Loss: 0.7433754205703735
# Loss:  tf.Tensor(0.749268, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7391646, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7396555, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74102974, shape=(), dtype=float32)
# F1 Score average for round 53 = 0.5029471546910945, Loss: 0.7422794699668884
# Loss:  tf.Tensor(0.74138236, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74567455, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7454479, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7480955, shape=(), dtype=float32)
# F1 Score average for round 54 = 0.4879917454296522, Loss: 0.745150089263916
# Loss:  tf.Tensor(0.7429576, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7451524, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.740514, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7420153, shape=(), dtype=float32)
# F1 Score average for round 55 = 0.4998197635198179, Loss: 0.742659866809845
# Loss:  tf.Tensor(0.7455014, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74155504, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7383702, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7496792, shape=(), dtype=float32)
# F1 Score average for round 56 = 0.49307740988417137, Loss: 0.7437764406204224
# Loss:  tf.Tensor(0.74618083, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7410573, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73644686, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74370646, shape=(), dtype=float32)
# F1 Score average for round 57 = 0.5074137211502696, Loss: 0.7418478727340698
# Loss:  tf.Tensor(0.74237174, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73126894, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7432051, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7403183, shape=(), dtype=float32)
# F1 Score average for round 58 = 0.5193887346789612, Loss: 0.7392910122871399
# Loss:  tf.Tensor(0.73425657, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7453984, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74326515, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75285006, shape=(), dtype=float32)
# F1 Score average for round 59 = 0.4932241561210665, Loss: 0.7439425587654114
# Loss:  tf.Tensor(0.7465435, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74169093, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7502123, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7383656, shape=(), dtype=float32)
# F1 Score average for round 60 = 0.4931161193504765, Loss: 0.7442030906677246
# CV Round complete
# TRAIN: [    1     2     4 ... 19410 19412 19413] TEST: [    0     3    15 ... 19405 19408 19411]
# Loss:  tf.Tensor(0.9310235, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.92643094, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.92127043, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.93071544, shape=(), dtype=float32)
# F1 Score average for round 0 = 0.31055967505668547, Loss: 0.9273600578308105
# Loss:  tf.Tensor(0.72354186, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73229223, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7293366, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73085606, shape=(), dtype=float32)
# F1 Score average for round 1 = 0.48793793915223505, Loss: 0.7290066480636597
# Loss:  tf.Tensor(0.75359654, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7379024, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7462841, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7380992, shape=(), dtype=float32)
# F1 Score average for round 2 = 0.4830436382577673, Loss: 0.743970513343811
# Loss:  tf.Tensor(0.73690474, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7312081, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74686766, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73678535, shape=(), dtype=float32)
# F1 Score average for round 3 = 0.49812045134378746, Loss: 0.7379415035247803
# Loss:  tf.Tensor(0.7362036, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74349177, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73493826, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73796755, shape=(), dtype=float32)
# F1 Score average for round 4 = 0.48436243637758375, Loss: 0.7381502389907837
# Loss:  tf.Tensor(0.73896456, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7379902, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7418941, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7458803, shape=(), dtype=float32)
# F1 Score average for round 5 = 0.4984170271725429, Loss: 0.741182267665863
# Loss:  tf.Tensor(0.73545426, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73876065, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7397347, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74759245, shape=(), dtype=float32)
# F1 Score average for round 6 = 0.4977064647831322, Loss: 0.7403855323791504
# Loss:  tf.Tensor(0.73157233, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7430485, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73453224, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7537523, shape=(), dtype=float32)
# F1 Score average for round 7 = 0.4923514543333502, Loss: 0.7407263517379761
# Loss:  tf.Tensor(0.7318486, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7373832, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73939776, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7423088, shape=(), dtype=float32)
# F1 Score average for round 8 = 0.5157204359297705, Loss: 0.7377346158027649
# Loss:  tf.Tensor(0.73328644, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73797846, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7342601, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7440212, shape=(), dtype=float32)
# F1 Score average for round 9 = 0.5174684363206338, Loss: 0.7373865246772766
# Loss:  tf.Tensor(0.73626053, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7358235, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74003255, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73325354, shape=(), dtype=float32)
# F1 Score average for round 10 = 0.510502591305162, Loss: 0.7363425493240356
# Loss:  tf.Tensor(0.7431654, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74686974, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73863876, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74275124, shape=(), dtype=float32)
# F1 Score average for round 11 = 0.48401886794921517, Loss: 0.7428562641143799
# Loss:  tf.Tensor(0.7478265, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7338728, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74001974, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7401331, shape=(), dtype=float32)
# F1 Score average for round 12 = 0.4992115776844964, Loss: 0.7404630184173584
# Loss:  tf.Tensor(0.74544996, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7327678, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7415455, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7413852, shape=(), dtype=float32)
# F1 Score average for round 13 = 0.5044604498033705, Loss: 0.7402871251106262
# Loss:  tf.Tensor(0.7366368, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7405291, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74775827, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75159574, shape=(), dtype=float32)
# F1 Score average for round 14 = 0.4775579540983069, Loss: 0.7441299557685852
# Loss:  tf.Tensor(0.74647516, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7298336, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74056405, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7311601, shape=(), dtype=float32)
# F1 Score average for round 15 = 0.5144057675496709, Loss: 0.737008273601532
# Loss:  tf.Tensor(0.75340664, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74208564, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7380881, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7395367, shape=(), dtype=float32)
# F1 Score average for round 16 = 0.49623296509061143, Loss: 0.7432792782783508
# Loss:  tf.Tensor(0.74859273, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74755526, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7342278, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73369247, shape=(), dtype=float32)
# F1 Score average for round 17 = 0.5083898726315578, Loss: 0.7410170435905457
# Loss:  tf.Tensor(0.7383168, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7452629, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7499422, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7339794, shape=(), dtype=float32)
# F1 Score average for round 18 = 0.5066490831295732, Loss: 0.7418753504753113
# Loss:  tf.Tensor(0.7475628, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73634595, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7304657, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7407665, shape=(), dtype=float32)
# F1 Score average for round 19 = 0.5183962156201359, Loss: 0.7387852668762207
# Loss:  tf.Tensor(0.73575574, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7385637, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74286073, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.740859, shape=(), dtype=float32)
# F1 Score average for round 20 = 0.5095812363312129, Loss: 0.7395098209381104
# Loss:  tf.Tensor(0.7399655, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74162996, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74428535, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7468688, shape=(), dtype=float32)
# F1 Score average for round 21 = 0.49850306113076576, Loss: 0.743187427520752
# Loss:  tf.Tensor(0.7457845, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74809486, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74133664, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7407896, shape=(), dtype=float32)
# F1 Score average for round 22 = 0.4940074821467201, Loss: 0.7440013885498047
# Loss:  tf.Tensor(0.7433111, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7522708, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7402088, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74263877, shape=(), dtype=float32)
# F1 Score average for round 23 = 0.49186310565353886, Loss: 0.7446073889732361
# Loss:  tf.Tensor(0.7414381, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74364406, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7393027, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75375, shape=(), dtype=float32)
# F1 Score average for round 24 = 0.48995095965344704, Loss: 0.7445337176322937
# Loss:  tf.Tensor(0.74223524, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7501423, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73623866, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73552394, shape=(), dtype=float32)
# F1 Score average for round 25 = 0.5124550479033801, Loss: 0.7410350441932678
# Loss:  tf.Tensor(0.75080264, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7461754, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74384254, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74260473, shape=(), dtype=float32)
# F1 Score average for round 26 = 0.4879286892734892, Loss: 0.7458563446998596
# Loss:  tf.Tensor(0.744852, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74544746, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7544016, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7404314, shape=(), dtype=float32)
# F1 Score average for round 27 = 0.488170092080068, Loss: 0.7462831735610962
# Loss:  tf.Tensor(0.74938893, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75020695, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73820823, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7371841, shape=(), dtype=float32)
# F1 Score average for round 28 = 0.5025799949609556, Loss: 0.7437470555305481
# Loss:  tf.Tensor(0.74764276, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7499384, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7425156, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74397767, shape=(), dtype=float32)
# F1 Score average for round 29 = 0.48734803636338586, Loss: 0.746018648147583
# Loss:  tf.Tensor(0.7566195, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74105453, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7494895, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73859555, shape=(), dtype=float32)
# F1 Score average for round 30 = 0.4896610301419643, Loss: 0.7464397549629211
# Loss:  tf.Tensor(0.7353579, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74837583, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.745632, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7421292, shape=(), dtype=float32)
# F1 Score average for round 31 = 0.510531513032859, Loss: 0.7428736686706543
# Loss:  tf.Tensor(0.7477354, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7400343, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7589048, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7425492, shape=(), dtype=float32)
# F1 Score average for round 32 = 0.48669803215744467, Loss: 0.7473059296607971
# Loss:  tf.Tensor(0.74613684, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73759425, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7535366, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74513185, shape=(), dtype=float32)
# F1 Score average for round 33 = 0.4955492308019176, Loss: 0.7455998659133911
# Loss:  tf.Tensor(0.7516349, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7416001, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7493413, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74190444, shape=(), dtype=float32)
# F1 Score average for round 34 = 0.49472581019989614, Loss: 0.7461202144622803
# Loss:  tf.Tensor(0.74524635, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75067943, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74887973, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7364816, shape=(), dtype=float32)
# F1 Score average for round 35 = 0.497194289966925, Loss: 0.7453218102455139
# Loss:  tf.Tensor(0.7446334, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7533548, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7367447, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7467498, shape=(), dtype=float32)
# F1 Score average for round 36 = 0.49993079350951136, Loss: 0.7453706860542297
# Loss:  tf.Tensor(0.74276835, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74404466, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7495307, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7499546, shape=(), dtype=float32)
# F1 Score average for round 37 = 0.4914461745661178, Loss: 0.7465746402740479
# Loss:  tf.Tensor(0.75636387, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7468938, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7389122, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74286723, shape=(), dtype=float32)
# F1 Score average for round 38 = 0.49564752414212077, Loss: 0.7462592720985413
# Loss:  tf.Tensor(0.74970233, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7476833, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73732895, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74094975, shape=(), dtype=float32)
# F1 Score average for round 39 = 0.5067650694126472, Loss: 0.7439160346984863
# Loss:  tf.Tensor(0.74691683, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73908937, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7367921, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7581499, shape=(), dtype=float32)
# F1 Score average for round 40 = 0.5013174839113366, Loss: 0.7452370524406433
# Loss:  tf.Tensor(0.74466515, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7546709, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7500296, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.741373, shape=(), dtype=float32)
# F1 Score average for round 41 = 0.4879321123927045, Loss: 0.7476846575737
# Loss:  tf.Tensor(0.7365743, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7510841, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74759126, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74372494, shape=(), dtype=float32)
# F1 Score average for round 42 = 0.5017919651367206, Loss: 0.7447435855865479
# Loss:  tf.Tensor(0.74479437, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7500336, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7508422, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7476449, shape=(), dtype=float32)
# F1 Score average for round 43 = 0.48385148391585925, Loss: 0.7483288049697876
# Loss:  tf.Tensor(0.7405832, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74185157, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7464778, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74607503, shape=(), dtype=float32)
# F1 Score average for round 44 = 0.5077192413521165, Loss: 0.7437468767166138
# Loss:  tf.Tensor(0.7467238, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7419819, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7542963, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7466294, shape=(), dtype=float32)
# F1 Score average for round 45 = 0.48991542385177955, Loss: 0.747407853603363
# Loss:  tf.Tensor(0.7430779, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.741511, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74749756, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7508981, shape=(), dtype=float32)
# F1 Score average for round 46 = 0.4935278166718511, Loss: 0.7457461357116699
# Loss:  tf.Tensor(0.73750734, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7470291, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75302285, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73715425, shape=(), dtype=float32)
# F1 Score average for round 47 = 0.5100398495933491, Loss: 0.7436783909797668
# Loss:  tf.Tensor(0.751279, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7452947, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7418005, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73534226, shape=(), dtype=float32)
# F1 Score average for round 48 = 0.5123530565381402, Loss: 0.7434291243553162
# Loss:  tf.Tensor(0.74179107, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7577079, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7421589, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7419032, shape=(), dtype=float32)
# F1 Score average for round 49 = 0.4980033254696805, Loss: 0.7458902597427368
# Loss:  tf.Tensor(0.745341, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7556284, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7484468, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73868215, shape=(), dtype=float32)
# F1 Score average for round 50 = 0.49081502964603535, Loss: 0.747024655342102
# Loss:  tf.Tensor(0.75298226, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74286735, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7453466, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7435975, shape=(), dtype=float32)
# F1 Score average for round 51 = 0.4969331883727222, Loss: 0.7461984157562256
# Loss:  tf.Tensor(0.74139845, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7415459, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7383618, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75478023, shape=(), dtype=float32)
# F1 Score average for round 52 = 0.5075532653522926, Loss: 0.7440215945243835
# Loss:  tf.Tensor(0.74559236, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7413471, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74228716, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7350138, shape=(), dtype=float32)
# F1 Score average for round 53 = 0.5233562544218653, Loss: 0.7410600781440735
# Loss:  tf.Tensor(0.7396444, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75262403, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74201316, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7419604, shape=(), dtype=float32)
# F1 Score average for round 54 = 0.5071600497251779, Loss: 0.7440605163574219
# Loss:  tf.Tensor(0.743655, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7352184, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75406665, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7463901, shape=(), dtype=float32)
# F1 Score average for round 55 = 0.5030942892787975, Loss: 0.7448325753211975
# Loss:  tf.Tensor(0.7559356, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74220663, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7417194, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74496436, shape=(), dtype=float32)
# F1 Score average for round 56 = 0.4955873535354923, Loss: 0.746206521987915
# Loss:  tf.Tensor(0.75163835, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7438519, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.743225, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7498903, shape=(), dtype=float32)
# F1 Score average for round 57 = 0.4894164540861653, Loss: 0.7471513748168945
# Loss:  tf.Tensor(0.7483817, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7368184, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7597319, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7440363, shape=(), dtype=float32)
# F1 Score average for round 58 = 0.4920017610731217, Loss: 0.7472420930862427
# Loss:  tf.Tensor(0.7614946, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74128526, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74067444, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7518603, shape=(), dtype=float32)
# F1 Score average for round 59 = 0.4822310091796942, Loss: 0.748828649520874
# Loss:  tf.Tensor(0.7402351, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7432395, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7540341, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7348745, shape=(), dtype=float32)
# F1 Score average for round 60 = 0.5120847767150839, Loss: 0.7430958151817322
# Loss:  tf.Tensor(0.76161706, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74362516, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74145836, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7382462, shape=(), dtype=float32)
# F1 Score average for round 61 = 0.49601812634680226, Loss: 0.7462366819381714
# Loss:  tf.Tensor(0.7467561, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7342968, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7488129, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7512761, shape=(), dtype=float32)
# F1 Score average for round 62 = 0.5002405040157268, Loss: 0.7452854514122009
# Loss:  tf.Tensor(0.7546731, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7422044, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74205637, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7419358, shape=(), dtype=float32)
# F1 Score average for round 63 = 0.5024732211232948, Loss: 0.7452174425125122
# Loss:  tf.Tensor(0.73495996, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7593725, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74514085, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7439887, shape=(), dtype=float32)
# F1 Score average for round 64 = 0.4994142776789913, Loss: 0.745865523815155
# Loss:  tf.Tensor(0.7444783, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7352005, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7485953, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.76086766, shape=(), dtype=float32)
# F1 Score average for round 65 = 0.4925284100911887, Loss: 0.7472854256629944
# Loss:  tf.Tensor(0.7502524, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7505878, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7377254, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74909633, shape=(), dtype=float32)
# F1 Score average for round 66 = 0.48998958413828947, Loss: 0.7469154596328735
# Loss:  tf.Tensor(0.74225754, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7564638, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7426956, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74017316, shape=(), dtype=float32)
# F1 Score average for round 67 = 0.5029998701413618, Loss: 0.7453975081443787
# Loss:  tf.Tensor(0.7418232, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7420983, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7463751, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7547542, shape=(), dtype=float32)
# F1 Score average for round 68 = 0.4953479980781481, Loss: 0.7462626695632935
# Loss:  tf.Tensor(0.7432415, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7497385, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7384521, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75017446, shape=(), dtype=float32)
# F1 Score average for round 69 = 0.4997786321618627, Loss: 0.7454016208648682
# Loss:  tf.Tensor(0.75816816, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73427075, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7439667, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7437753, shape=(), dtype=float32)
# F1 Score average for round 70 = 0.5039250709184115, Loss: 0.7450452446937561
# Loss:  tf.Tensor(0.73541987, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7423075, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74172044, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74685425, shape=(), dtype=float32)
# F1 Score average for round 71 = 0.5216655683238671, Loss: 0.7415755391120911
# Loss:  tf.Tensor(0.7422656, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7515446, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73581636, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.745626, shape=(), dtype=float32)
# F1 Score average for round 72 = 0.5099816139359215, Loss: 0.743813157081604
# Loss:  tf.Tensor(0.7468525, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7472678, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74931896, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7403073, shape=(), dtype=float32)
# F1 Score average for round 73 = 0.49676419352783197, Loss: 0.7459366321563721
# Loss:  tf.Tensor(0.7501882, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7512728, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.742629, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7395015, shape=(), dtype=float32)
# F1 Score average for round 74 = 0.49498054536171965, Loss: 0.7458978891372681
# Loss:  tf.Tensor(0.7473794, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7487295, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7470578, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73676264, shape=(), dtype=float32)
# F1 Score average for round 75 = 0.5020889293460421, Loss: 0.7449823617935181
# Loss:  tf.Tensor(0.74669653, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74020964, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7581914, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74740946, shape=(), dtype=float32)
# F1 Score average for round 76 = 0.48608559907264187, Loss: 0.748126745223999
# Loss:  tf.Tensor(0.74168754, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73749137, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74821204, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73367006, shape=(), dtype=float32)
# F1 Score average for round 77 = 0.5298455464744694, Loss: 0.7402652502059937
# Loss:  tf.Tensor(0.7471586, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7451399, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7423477, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7334531, shape=(), dtype=float32)
# F1 Score average for round 78 = 0.5195777875362078, Loss: 0.742024838924408
# Loss:  tf.Tensor(0.7402786, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7527675, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7423234, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7468341, shape=(), dtype=float32)
# F1 Score average for round 79 = 0.5001460848782912, Loss: 0.7455508708953857
# Loss:  tf.Tensor(0.7474166, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7401492, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74924725, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73804635, shape=(), dtype=float32)
# F1 Score average for round 80 = 0.5086395652697433, Loss: 0.7437148690223694
# Loss:  tf.Tensor(0.7367152, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74298203, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75015897, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7448092, shape=(), dtype=float32)
# F1 Score average for round 81 = 0.5099816139359216, Loss: 0.7436663508415222
# Loss:  tf.Tensor(0.74031055, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74809366, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7441078, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7475266, shape=(), dtype=float32)
# F1 Score average for round 82 = 0.5036500611156346, Loss: 0.7450096607208252
# Loss:  tf.Tensor(0.7470134, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74906033, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7418573, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7562136, shape=(), dtype=float32)
# F1 Score average for round 83 = 0.48300784034372984, Loss: 0.7485361695289612
# Loss:  tf.Tensor(0.75749207, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7389118, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74524236, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7467487, shape=(), dtype=float32)
# F1 Score average for round 84 = 0.49085404389955206, Loss: 0.7470987439155579
# Loss:  tf.Tensor(0.7422284, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7496051, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74857104, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73527145, shape=(), dtype=float32)
# F1 Score average for round 85 = 0.5100295520393, Loss: 0.7439190149307251
# Loss:  tf.Tensor(0.75568455, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7418601, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74516255, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7416005, shape=(), dtype=float32)
# F1 Score average for round 86 = 0.4955873535354924, Loss: 0.7460769414901733
# Loss:  tf.Tensor(0.7333035, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7530525, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7449962, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74803174, shape=(), dtype=float32)
# F1 Score average for round 87 = 0.5033182627446389, Loss: 0.744845986366272
# Loss:  tf.Tensor(0.7457195, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75133437, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7467085, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.738417, shape=(), dtype=float32)
# F1 Score average for round 88 = 0.4998419522567441, Loss: 0.7455449104309082
# Loss:  tf.Tensor(0.7422063, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74847627, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74664986, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7564643, shape=(), dtype=float32)
# F1 Score average for round 89 = 0.48300784034372984, Loss: 0.7484491467475891
# Loss:  tf.Tensor(0.7350329, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74581707, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7420533, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75775, shape=(), dtype=float32)
# F1 Score average for round 90 = 0.5037490355559487, Loss: 0.7451633214950562
# Loss:  tf.Tensor(0.7422681, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74360746, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75135416, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7428237, shape=(), dtype=float32)
# F1 Score average for round 91 = 0.5017072166478836, Loss: 0.7450133562088013
# Loss:  tf.Tensor(0.75132674, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7449622, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74234504, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7411224, shape=(), dtype=float32)
# F1 Score average for round 92 = 0.5019945102086065, Loss: 0.7449391484260559
# Loss:  tf.Tensor(0.73507994, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75638133, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7387926, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.743224, shape=(), dtype=float32)
# F1 Score average for round 93 = 0.5137141189419848, Loss: 0.743369460105896
# Loss:  tf.Tensor(0.7503012, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7566943, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73684347, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7390947, shape=(), dtype=float32)
# F1 Score average for round 94 = 0.4990003439285057, Loss: 0.745733380317688
# Loss:  tf.Tensor(0.7431414, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7452758, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74230486, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.760815, shape=(), dtype=float32)
# F1 Score average for round 95 = 0.4862305353925504, Loss: 0.7478842735290527
# Loss:  tf.Tensor(0.7436125, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7349233, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75768316, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7440626, shape=(), dtype=float32)
# F1 Score average for round 96 = 0.5039250709184117, Loss: 0.7450703978538513
# Loss:  tf.Tensor(0.75251174, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7451143, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7431801, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74163175, shape=(), dtype=float32)
# F1 Score average for round 97 = 0.49730768160672334, Loss: 0.7456094622612
# Loss:  tf.Tensor(0.7474574, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7445534, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74013734, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73774457, shape=(), dtype=float32)
# F1 Score average for round 98 = 0.5150467219428574, Loss: 0.7424731850624084
# Loss:  tf.Tensor(0.7496298, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75081784, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74197304, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7349475, shape=(), dtype=float32)
# F1 Score average for round 99 = 0.5067743008786039, Loss: 0.744342029094696
# Loss:  tf.Tensor(0.7422608, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7512923, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74497974, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74209946, shape=(), dtype=float32)
# F1 Score average for round 100 = 0.5019945102086064, Loss: 0.7451581358909607
# Loss:  tf.Tensor(0.7401298, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7497616, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7503072, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.743838, shape=(), dtype=float32)
# F1 Score average for round 101 = 0.4971162642527577, Loss: 0.7460091710090637
# Loss:  tf.Tensor(0.7416453, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7384487, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74569225, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7614968, shape=(), dtype=float32)
# F1 Score average for round 102 = 0.49415286195566266, Loss: 0.7468207478523254
# Loss:  tf.Tensor(0.75405014, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74237967, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7401124, shape=(), dtype=float32)
# ...
# Loss:  tf.Tensor(0.73738885, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7398536, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7470574, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73548543, shape=(), dtype=float32)
# F1 Score average for round 10 = 0.49533976487721354, Loss: 0.7399463653564453
# Loss:  tf.Tensor(0.7437837, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.730107, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73335654, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7494753, shape=(), dtype=float32)
# F1 Score average for round 11 = 0.5013681908787481, Loss: 0.7391806244850159
# Loss:  tf.Tensor(0.74669814, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74067885, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7407233, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7473569, shape=(), dtype=float32)
# F1 Score average for round 12 = 0.47782384280176204, Loss: 0.7438642978668213
# Loss:  tf.Tensor(0.73578566, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7334558, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.738628, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7442745, shape=(), dtype=float32)
# F1 Score average for round 13 = 0.5137074562470012, Loss: 0.7380359172821045
# Loss:  tf.Tensor(0.7388909, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7433159, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7463632, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7316644, shape=(), dtype=float32)
# F1 Score average for round 14 = 0.49097161426244984, Loss: 0.7400586009025574
# Loss:  tf.Tensor(0.7438696, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74167097, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74418694, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7351605, shape=(), dtype=float32)
# F1 Score average for round 15 = 0.4925833257377493, Loss: 0.7412220239639282
# Loss:  tf.Tensor(0.7359805, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7438549, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73181796, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74644065, shape=(), dtype=float32)
# F1 Score average for round 16 = 0.5054312023916245, Loss: 0.7395234704017639
# Loss:  tf.Tensor(0.73058975, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7433504, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7463151, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74348295, shape=(), dtype=float32)
# F1 Score average for round 17 = 0.4953837871722072, Loss: 0.7409346103668213
# Loss:  tf.Tensor(0.72726774, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74434125, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74877703, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7469234, shape=(), dtype=float32)
# F1 Score average for round 18 = 0.4913860791185257, Loss: 0.7418273687362671
# Loss:  tf.Tensor(0.7474134, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7498272, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7431776, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7328871, shape=(), dtype=float32)
# F1 Score average for round 19 = 0.4896984189293055, Loss: 0.7433263063430786
# Loss:  tf.Tensor(0.746982, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7414872, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74723774, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73134774, shape=(), dtype=float32)
# F1 Score average for round 20 = 0.4992303839278468, Loss: 0.7417636513710022
# Loss:  tf.Tensor(0.75374573, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7514691, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7352879, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73588395, shape=(), dtype=float32)
# F1 Score average for round 21 = 0.49326594478754604, Loss: 0.7440966963768005
# Loss:  tf.Tensor(0.7466413, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7348564, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7431529, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75061965, shape=(), dtype=float32)
# F1 Score average for round 22 = 0.4947161097147041, Loss: 0.7438175678253174
# Loss:  tf.Tensor(0.7370054, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75337434, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.746999, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7331429, shape=(), dtype=float32)
# F1 Score average for round 23 = 0.5023938269565984, Loss: 0.7426304221153259
# Loss:  tf.Tensor(0.7330432, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7411729, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.739799, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7468105, shape=(), dtype=float32)
# F1 Score average for round 24 = 0.5189357649831212, Loss: 0.7402063608169556
# Loss:  tf.Tensor(0.7340162, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75017583, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74628615, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74495405, shape=(), dtype=float32)
# F1 Score average for round 25 = 0.4975015487116541, Loss: 0.7438580989837646
# Loss:  tf.Tensor(0.75110745, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7441766, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75187916, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7329694, shape=(), dtype=float32)
# F1 Score average for round 26 = 0.4949850176945476, Loss: 0.7450331449508667
# Loss:  tf.Tensor(0.74603426, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7453013, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7494678, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74041176, shape=(), dtype=float32)
# F1 Score average for round 27 = 0.4944984908533772, Loss: 0.7453038096427917
# Loss:  tf.Tensor(0.75203204, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7369908, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7477333, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75366056, shape=(), dtype=float32)
# F1 Score average for round 28 = 0.4837533916044816, Loss: 0.7476041316986084
# Loss:  tf.Tensor(0.7522061, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74271125, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7358755, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7493373, shape=(), dtype=float32)
# F1 Score average for round 29 = 0.49607052273724933, Loss: 0.745032548904419
# Loss:  tf.Tensor(0.7523761, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73753905, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7507535, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74372905, shape=(), dtype=float32)
# F1 Score average for round 30 = 0.4909163929743797, Loss: 0.7460994720458984
# Loss:  tf.Tensor(0.7319261, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74464184, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75283045, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7479405, shape=(), dtype=float32)
# F1 Score average for round 31 = 0.5056293426886331, Loss: 0.7443347573280334
# Loss:  tf.Tensor(0.73673534, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7480068, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7460763, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.753866, shape=(), dtype=float32)
# F1 Score average for round 32 = 0.4949189102473419, Loss: 0.7461711168289185
# Loss:  tf.Tensor(0.7420519, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7339879, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7549077, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7525224, shape=(), dtype=float32)
# F1 Score average for round 33 = 0.49867728374626996, Loss: 0.7458674907684326
# Loss:  tf.Tensor(0.7505954, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73555815, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7373142, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74983686, shape=(), dtype=float32)
# F1 Score average for round 34 = 0.5126001191801907, Loss: 0.7433261871337891
# Loss:  tf.Tensor(0.75393486, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7408524, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7409149, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74808073, shape=(), dtype=float32)
# F1 Score average for round 35 = 0.4975998411971253, Loss: 0.7459456920623779
# Loss:  tf.Tensor(0.7494351, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7372374, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7490505, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7553283, shape=(), dtype=float32)
# F1 Score average for round 36 = 0.486097827294521, Loss: 0.7477627992630005
# Loss:  tf.Tensor(0.7405526, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74235535, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.746546, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7462506, shape=(), dtype=float32)
# F1 Score average for round 37 = 0.5061616845268366, Loss: 0.7439261674880981
# Loss:  tf.Tensor(0.73271734, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7477248, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7536681, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7489175, shape=(), dtype=float32)
# F1 Score average for round 38 = 0.4987415817225827, Loss: 0.7457569241523743
# Loss:  tf.Tensor(0.7387521, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75783545, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7589565, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.743413, shape=(), dtype=float32)
# F1 Score average for round 39 = 0.4749765175376629, Loss: 0.7497392296791077
# Loss:  tf.Tensor(0.75186396, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74083525, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7374592, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7493586, shape=(), dtype=float32)
# F1 Score average for round 40 = 0.5024396036248822, Loss: 0.7448792457580566
# Loss:  tf.Tensor(0.757754, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75348264, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7406465, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73293614, shape=(), dtype=float32)
# F1 Score average for round 41 = 0.49660718421772243, Loss: 0.7462047934532166
# Loss:  tf.Tensor(0.7388819, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75943756, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74927264, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73777944, shape=(), dtype=float32)
# F1 Score average for round 42 = 0.4956289195996201, Loss: 0.7463428378105164
# Loss:  tf.Tensor(0.7427273, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.734868, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7438213, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75123525, shape=(), dtype=float32)
# F1 Score average for round 43 = 0.5142549973698777, Loss: 0.743162989616394
# Loss:  tf.Tensor(0.74636614, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74081004, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.747712, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.742689, shape=(), dtype=float32)
# F1 Score average for round 44 = 0.5058138823149061, Loss: 0.7443943023681641
# Loss:  tf.Tensor(0.74675536, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7467254, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7460699, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73388773, shape=(), dtype=float32)
# F1 Score average for round 45 = 0.5137004668142129, Loss: 0.7433595657348633
# Loss:  tf.Tensor(0.74745136, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.751153, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74069154, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7474933, shape=(), dtype=float32)
# F1 Score average for round 46 = 0.49102638013169064, Loss: 0.7466973066329956
# Loss:  tf.Tensor(0.74761766, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7579172, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.758213, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7381096, shape=(), dtype=float32)
# F1 Score average for round 47 = 0.4717304517035761, Loss: 0.7504643797874451
# Loss:  tf.Tensor(0.74433655, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7407871, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74822533, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75640815, shape=(), dtype=float32)
# F1 Score average for round 48 = 0.4898634904277346, Loss: 0.7474392652511597
# Loss:  tf.Tensor(0.7339715, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7458453, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74744684, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75339025, shape=(), dtype=float32)
# F1 Score average for round 49 = 0.502483799763919, Loss: 0.7451635003089905
# Loss:  tf.Tensor(0.75829697, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7410476, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74755496, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73288965, shape=(), dtype=float32)
# F1 Score average for round 50 = 0.5059541156688322, Loss: 0.7449473142623901
# Loss:  tf.Tensor(0.74096435, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74251354, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73829883, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7537921, shape=(), dtype=float32)
# F1 Score average for round 51 = 0.5087932618979916, Loss: 0.7438921928405762
# Loss:  tf.Tensor(0.7478433, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7356336, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7458874, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75317174, shape=(), dtype=float32)
# F1 Score average for round 52 = 0.4995680144146704, Loss: 0.7456340193748474
# Loss:  tf.Tensor(0.74973255, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75825673, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7407399, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75112987, shape=(), dtype=float32)
# F1 Score average for round 53 = 0.47541149645022124, Loss: 0.7499647736549377
# Loss:  tf.Tensor(0.73229915, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7502925, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7507346, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75334054, shape=(), dtype=float32)
# F1 Score average for round 54 = 0.49544379709084724, Loss: 0.746666669845581
# Loss:  tf.Tensor(0.74259996, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7532155, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75400865, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.734025, shape=(), dtype=float32)
# F1 Score average for round 55 = 0.5004822532325032, Loss: 0.7459622621536255
# Loss:  tf.Tensor(0.73083514, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74573386, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74378926, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7533087, shape=(), dtype=float32)
# F1 Score average for round 56 = 0.5145980312579475, Loss: 0.7434167265892029
# Loss:  tf.Tensor(0.7529502, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7445946, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7465505, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.73912144, shape=(), dtype=float32)
# F1 Score average for round 57 = 0.4989665452217591, Loss: 0.7458041906356812
# Loss:  tf.Tensor(0.7509801, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74998623, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7387401, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7485552, shape=(), dtype=float32)
# F1 Score average for round 58 = 0.49176385192805777, Loss: 0.7470654249191284
# Loss:  tf.Tensor(0.74612105, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7550013, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.740816, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7444546, shape=(), dtype=float32)
# F1 Score average for round 59 = 0.4941276178481241, Loss: 0.7465982437133789
# Loss:  tf.Tensor(0.7420338, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74608886, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.738953, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75353056, shape=(), dtype=float32)
# F1 Score average for round 60 = 0.5040085776093898, Loss: 0.7451515197753906
# Loss:  tf.Tensor(0.733971, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7550309, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74950415, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.74275357, shape=(), dtype=float32)
# F1 Score average for round 61 = 0.5027542040477886, Loss: 0.74531489610672
# Loss:  tf.Tensor(0.74992406, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7446915, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7514298, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7331949, shape=(), dtype=float32)
# F1 Score average for round 62 = 0.5047293938091665, Loss: 0.7448100447654724
# Loss:  tf.Tensor(0.739554, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7504163, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7373633, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7578855, shape=(), dtype=float32)
# F1 Score average for round 63 = 0.497848106194342, Loss: 0.7463047504425049
# Loss:  tf.Tensor(0.74815583, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7537329, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.75294673, shape=(), dtype=float32)
# Loss:  tf.Tensor(0.7352714, shape=(), dtype=float32)
# F1 Score average for round 64 = 0.4903522280927078, Loss: 0.7475267648696899
# CV Round complete

# %% [markdown]
# # Results for Early Stopping when monitoring the average F1 Score value of all the clients using their own validation data

# %%
plt.subplot(2,1,1)
for i in range(len(loss_values_averages_all)):
    plt.plot(loss_values_averages_all[i])
plt.title('models\' loss')
plt.ylabel('loss')
plt.xlabel('Communication rounds')
plt.legend(['fold1', 'fold2','fold3', 'fold4', 'fold5'], loc='lower right')
plt.savefig("Model's Validation loss vs Communication Rounds - First technique with F1-Score - 40 patience")

# %%
plt.subplot(2,1,1)
for i in range(len(f1_scores_averages_all)):
    plt.plot(f1_scores_averages_all[i])
plt.title('models\' F1 Score')
plt.ylabel('Loss')
plt.xlabel('Communication rounds')
plt.legend(['fold1', 'fold2','fold3', 'fold4', 'fold5'], loc='lower right')
plt.savefig("Model's F1-Score vs Communication Rounds - First technique with F1-Score - 40 patience")

# %%
from sklearn.metrics import classification_report
average_f1_score = 0
#Confution Matrix and Classification Report
for i in range(len(best_models)):
    Y_pred = best_models[i][-1].predict(test_batches_CV[i])
    y_pred = np.where(Y_pred > 0.5, 1, 0)
    print('Confusion Matrix')
    y_pred = y_pred.max(axis=1)
    y_true = np.concatenate([y for x, y in test_batches_CV[i]], axis=0)
    print(confusion_matrix(y_true, y_pred, labels=[True, False]))
    f1_score_acc = f1_score(y_true, y_pred, average='macro')
    average_f1_score += f1_score_acc
    print("F1 Score: {}".format(f1_score_acc))
    print(classification_report(y_true, y_pred, target_names=['Class 0', 'Class 1']))
average_f1_score = average_f1_score / len(best_models)
print("Average F1 Score: {}".format(average_f1_score))
# Out:
# Confusion Matrix
# [[ 294   84]
#  [  82 3423]]
# F1 Score: 0.8780835732908043
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.98      0.98      3505
#      Class 1       0.78      0.78      0.78       378
#
#     accuracy                           0.96      3883
#    macro avg       0.88      0.88      0.88      3883
# weighted avg       0.96      0.96      0.96      3883
#
# Confusion Matrix
# [[ 311   67]
#  [  71 3434]]
# F1 Score: 0.899361825202458
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.98      0.98      3505
#      Class 1       0.81      0.82      0.82       378
#
#     accuracy                           0.96      3883
#    macro avg       0.90      0.90      0.90      3883
# weighted avg       0.96      0.96      0.96      3883
#
# Confusion Matrix
# [[ 302   77]
#  [  88 3416]]
# F1 Score: 0.8809270478728297
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.97      0.98      3504
#      Class 1       0.77      0.80      0.79       379
#
#     accuracy                           0.96      3883
#    macro avg       0.88      0.89      0.88      3883
# weighted avg       0.96      0.96      0.96      3883
#
# WARNING:tensorflow:5 out of the last 14 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000020B73645598> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Confusion Matrix
# [[ 297   82]
#  [  79 3425]]
# F1 Score: 0.8818955265188761
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.98      0.98      3504
#      Class 1       0.79      0.78      0.79       379
#
#     accuracy                           0.96      3883
#    macro avg       0.88      0.88      0.88      3883
# weighted avg       0.96      0.96      0.96      3883
#
# WARNING:tensorflow:6 out of the last 15 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000020B73645378> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Confusion Matrix
# [[ 287   91]
#  [  82 3422]]
# F1 Score: 0.8718762752306075
#               precision    recall  f1-score   support
#
#      Class 0       0.97      0.98      0.98      3504
#      Class 1       0.78      0.76      0.77       378
#
#     accuracy                           0.96      3882
#    macro avg       0.88      0.87      0.87      3882
# weighted avg       0.95      0.96      0.96      3882
#
# Average F1 Score: 0.8824288496231152

# %%
import sklearn.metrics as metrics

for i in range(len(best_models)):
    Y_pred = best_models[i][-1].predict(test_batches_CV[i])
    y_pred = np.where(Y_pred > 0.5, 1, 0)
    y_pred = y_pred.max(axis=1)
    y_true = np.concatenate([y for x, y in test_batches_CV[i]], axis=0)
    fpr, tpr, threshold = metrics.roc_curve(y_true, y_pred)
    roc_auc = metrics.auc(fpr, tpr)
    print("FPR: ", fpr)
    print("TPR: ", tpr)
    # method I: plt
    plt.title('Receiver Operating Characteristic')
    plt.plot(fpr, tpr, 'b', label = 'AUC = %0.4f' % roc_auc)
    plt.legend(loc = 'lower right')
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([0, 1])
    plt.ylim([0, 1])
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()
# Out:
# FPR:  [0.         0.02339515 1.        ]
# TPR:  [0.         0.77777778 1.        ]
# FPR:  [0.         0.02025678 1.        ]
# TPR:  [0.         0.82275132 1.        ]
# FPR:  [0.         0.02511416 1.        ]
# TPR:  [0.         0.79683377 1.        ]
# FPR:  [0.         0.02254566 1.        ]
# TPR:  [0.         0.78364116 1.        ]
# FPR:  [0.         0.02340183 1.        ]
# TPR:  [0.         0.75925926 1.        ]

# %%
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import auc

for i in range(len(best_models)):
    Y_pred = best_models[i][-1].predict(test_batches_CV[i])
    y_pred = np.where(Y_pred > 0.5, 1, 0)
    y_pred = y_pred.max(axis=1)
    y_true = np.concatenate([y for x, y in test_batches_CV[i]], axis=0)
    lr_precision, lr_recall, _ = precision_recall_curve(y_true, y_pred)
    lr_f1, lr_auc = f1_score(y_true, y_pred, average='macro'), auc(lr_recall, lr_precision)
    # summarize scores
    print("Precision: ", lr_precision)
    print("Recall: ", lr_recall)
    print('Logistic: f1=%.3f auc=%.3f' % (lr_f1, lr_auc))
    # plot the precision-recall curves
    no_skill = len(y_true[y_true==1]) / len(y_true)
    plt.plot([0, 1], [no_skill, no_skill], linestyle='--')
    plt.plot(lr_recall, lr_precision, marker='.', label = 'AUC = %0.4f' % lr_auc)
    # axis labels
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    # show the legend
    plt.legend()
    # show the plot
    plt.show()
# Out:
# Precision:  [0.09734741 0.78191489 1.        ]
# Recall:  [1.         0.77777778 0.        ]
# Logistic: f1=0.878 auc=0.791
# Precision:  [0.09734741 0.81413613 1.        ]
# Recall:  [1.         0.82275132 0.        ]
# Logistic: f1=0.899 auc=0.827
# Precision:  [0.09760494 0.77435897 1.        ]
# Recall:  [1.         0.79683377 0.        ]
# Logistic: f1=0.881 auc=0.796
# Precision:  [0.09760494 0.78989362 1.        ]
# Recall:  [1.         0.78364116 0.        ]
# Logistic: f1=0.882 auc=0.797
# Precision:  [0.09737249 0.77777778 1.        ]
# Recall:  [1.         0.75925926 0.        ]
# Logistic: f1=0.872 auc=0.780
